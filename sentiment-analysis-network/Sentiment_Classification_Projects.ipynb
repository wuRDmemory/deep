# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
for label, review in zip(labels, reviews):
    words = review.split(' ')
    for word in words:
        if label == 'NEGATIVE':
            negative_counts[word]+=1
        else:
            positive_counts[word]+=1
        total_counts[word]+=1

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('', 1260590),
#  ('the', 346648),
#  ('and', 179444),
#  ('a', 167376),
#  ('.', 159654),
#  ('of', 153710),
#  ('to', 133492),
#  ('is', 114490),
#  ('in', 100430),
#  ('br', 98470),
#  ('it', 96050),
#  ('i', 81486),
#  ('that', 71260),
#  ('this', 70160),
#  ('s', 67630),
#  ('as', 52616),
#  ('with', 46494),
#  ('for', 44832),
#  ('was', 43834),
#  ('film', 41874),
#  ('but', 41644),
#  ('movie', 38148),
#  ('his', 34454),
#  ('on', 34016),
#  ('you', 33362),
#  ('he', 32564),
#  ('are', 29614),
#  ('not', 28544),
#  ('t', 27440),
#  ('one', 27310),
#  ('have', 25174),
#  ('be', 24832),
#  ('by', 23994),
#  ('all', 23884),
#  ('who', 22928),
#  ('an', 22588),
#  ('at', 22468),
#  ('from', 21534),
#  ('her', 20948),
#  ('they', 19790),
#  ('has', 18372),
#  ('so', 18308),
#  ('like', 18076),
#  ('about', 16626),
#  ('very', 16610),
#  ('out', 16268),
#  ('there', 16114),
#  ('she', 15558),
#  ('what', 15474),
#  ('or', 15464),
#  ('good', 15440),
#  ('more', 15042),
#  ('when', 14912),
#  ('some', 14882),
#  ('if', 14570),
#  ('just', 14304),
#  ('can', 14002),
#  ('story', 13560),
#  ('time', 13030),
#  ('my', 12976),
#  ('great', 12838),
#  ('well', 12810),
#  ('up', 12642),
#  ('which', 12534),
#  ('their', 12214),
#  ('see', 12052),
#  ('also', 11100),
#  ('we', 11062),
#  ('really', 10952),
#  ('would', 10800),
#  ('will', 10436),
#  ('me', 10334),
#  ('had', 10296),
#  ('only', 10274),
#  ('him', 10036),
#  ('even', 9928),
#  ('most', 9728),
#  ('other', 9716),
#  ('were', 9564),
#  ('first', 9510),
#  ('than', 9472),
#  ('much', 9370),
#  ('its', 9244),
#  ('no', 9148),
#  ('into', 9088),
#  ('people', 8958),
#  ('best', 8638),
#  ('love', 8602),
#  ('get', 8544),
#  ('how', 8426),
#  ('life', 8398),
#  ('been', 8378),
#  ('because', 8158),
#  ('way', 8072),
#  ('do', 7882),
#  ('made', 7646),
#  ('films', 7626),
#  ('them', 7610),
#  ('after', 7600),
#  ('many', 7532),
#  ('two', 7466),
#  ('too', 7318),
#  ('think', 7310),
#  ('movies', 7172),
#  ('characters', 7120),
#  ('character', 7028),
#  ('don', 6936),
#  ('man', 6920),
#  ('show', 6864),
#  ('watch', 6848),
#  ('seen', 6828),
#  ('then', 6716),
#  ('little', 6682),
#  ('still', 6680),
#  ('make', 6606),
#  ('could', 6474),
#  ('never', 6452),
#  ('being', 6434),
#  ('where', 6346),
#  ('does', 6138),
#  ('over', 6034),
#  ('any', 6004),
#  ('while', 5798),
#  ('know', 5666),
#  ('did', 5580),
#  ('years', 5516),
#  ('here', 5480),
#  ('ever', 5468),
#  ('end', 5392),
#  ('these', 5388),
#  ('such', 5180),
#  ('real', 5136),
#  ('scene', 5134),
#  ('back', 5094),
#  ('those', 4970),
#  ('though', 4950),
#  ('off', 4926),
#  ('new', 4916),
#  ('your', 4906),
#  ('go', 4880),
#  ('acting', 4874),
#  ('plot', 4864),
#  ('world', 4858),
#  ('scenes', 4854),
#  ('say', 4828),
#  ('through', 4818),
#  ('makes', 4780),
#  ('better', 4762),
#  ('now', 4736),
#  ('work', 4692),
#  ('young', 4686),
#  ('old', 4622),
#  ('ve', 4614),
#  ('find', 4544),
#  ('both', 4496),
#  ('before', 4354),
#  ('us', 4324),
#  ('again', 4316),
#  ('series', 4306),
#  ('quite', 4286),
#  ('something', 4270),
#  ('cast', 4266),
#  ('should', 4242),
#  ('part', 4196),
#  ('always', 4176),
#  ('lot', 4174),
#  ('another', 4150),
#  ('actors', 4094),
#  ('director', 4080),
#  ('family', 4064),
#  ('between', 4032),
#  ('own', 4032),
#  ('m', 3996),
#  ('may', 3994),
#  ('same', 3944),
#  ('role', 3934),
#  ('watching', 3932),
#  ('every', 3908),
#  ('funny', 3906),
#  ('doesn', 3870),
#  ('performance', 3856),
#  ('few', 3836),
#  ('bad', 3814),
#  ('look', 3800),
#  ('re', 3768),
#  ('why', 3710),
#  ('things', 3698),
#  ('times', 3664),
#  ('big', 3630),
#  ('however', 3590),
#  ('actually', 3580),
#  ('action', 3578),
#  ('going', 3566),
#  ('bit', 3514),
#  ('comedy', 3484),
#  ('down', 3480),
#  ('music', 3476),
#  ('must', 3456),
#  ('take', 3418),
#  ('saw', 3384),
#  ('long', 3380),
#  ('right', 3376),
#  ('fun', 3372),
#  ('fact', 3368),
#  ('excellent', 3366),
#  ('around', 3348),
#  ('didn', 3344),
#  ('without', 3342),
#  ('thing', 3324),
#  ('thought', 3278),
#  ('got', 3270),
#  ('each', 3260),
#  ('day', 3228),
#  ('feel', 3194),
#  ('seems', 3192),
#  ('come', 3188),
#  ('done', 3172),
#  ('beautiful', 3160),
#  ('especially', 3144),
#  ('played', 3142),
#  ('almost', 3132),
#  ('want', 3124),
#  ('yet', 3112),
#  ('give', 3106),
#  ('pretty', 3098),
#  ('last', 3086),
#  ('since', 3038),
#  ('different', 3008),
#  ('although', 3002),
#  ('gets', 2980),
#  ('true', 2974),
#  ('interesting', 2962),
#  ('job', 2940),
#  ('enough', 2910),
#  ('our', 2908),
#  ('shows', 2894),
#  ('horror', 2882),
#  ('woman', 2878),
#  ('tv', 2800),
#  ('probably', 2796),
#  ('father', 2790),
#  ('original', 2786),
#  ('girl', 2780),
#  ('point', 2758),
#  ('plays', 2756),
#  ('wonderful', 2744),
#  ('far', 2716),
#  ('course', 2716),
#  ('john', 2700),
#  ('rather', 2680),
#  ('isn', 2656),
#  ('ll', 2652),
#  ('later', 2648),
#  ('dvd', 2648),
#  ('whole', 2620),
#  ('war', 2620),
#  ('d', 2614),
#  ('found', 2612),
#  ('away', 2612),
#  ('screen', 2610),
#  ('nothing', 2600),
#  ('year', 2594),
#  ('once', 2592),
#  ('hard', 2588),
#  ('together', 2560),
#  ('set', 2554),
#  ('am', 2554),
#  ('having', 2532),
#  ('making', 2530),
#  ('place', 2526),
#  ('might', 2520),
#  ('comes', 2520),
#  ('sure', 2506),
#  ('american', 2496),
#  ('play', 2490),
#  ('kind', 2488),
#  ('perfect', 2484),
#  ('takes', 2484),
#  ('performances', 2474),
#  ('himself', 2460),
#  ('worth', 2442),
#  ('everyone', 2442),
#  ('anyone', 2428),
#  ('actor', 2406),
#  ('three', 2402),
#  ('wife', 2392),
#  ('classic', 2384),
#  ('goes', 2372),
#  ('ending', 2356),
#  ('version', 2336),
#  ('star', 2298),
#  ('enjoy', 2292),
#  ('book', 2284),
#  ('nice', 2264),
#  ('everything', 2256),
#  ('during', 2248),
#  ('put', 2236),
#  ('seeing', 2222),
#  ('least', 2204),
#  ('house', 2200),
#  ('high', 2190),
#  ('watched', 2188),
#  ('loved', 2174),
#  ('men', 2174),
#  ('night', 2164),
#  ('anything', 2150),
#  ('believe', 2142),
#  ('guy', 2142),
#  ('top', 2126),
#  ('amazing', 2116),
#  ('hollywood', 2112),
#  ('looking', 2106),
#  ('main', 2088),
#  ('definitely', 2086),
#  ('gives', 2062),
#  ('home', 2058),
#  ('seem', 2056),
#  ('episode', 2046),
#  ('audience', 2040),
#  ('sense', 2040),
#  ('truly', 2034),
#  ('special', 2022),
#  ('second', 2018),
#  ('short', 2018),
#  ('fan', 2018),
#  ('mind', 2010),
#  ('human', 2002),
#  ('recommend', 1998),
#  ('full', 1992),
#  ('black', 1990),
#  ('help', 1982),
#  ('along', 1978),
#  ('trying', 1974),
#  ('small', 1972),
#  ('death', 1970),
#  ('friends', 1962),
#  ('remember', 1948),
#  ('often', 1940),
#  ('said', 1932),
#  ('favorite', 1924),
#  ('heart', 1918),
#  ('early', 1914),
#  ('left', 1912),
#  ('until', 1910),
#  ('script', 1908),
#  ('let', 1908),
#  ('maybe', 1874),
#  ('today', 1872),
#  ('live', 1868),
#  ('less', 1868),
#  ('moments', 1866),
#  ('others', 1858),
#  ('brilliant', 1852),
#  ('shot', 1850),
#  ('liked', 1846),
#  ('become', 1832),
#  ('won', 1830),
#  ('used', 1820),
#  ('style', 1814),
#  ('mother', 1790),
#  ('lives', 1788),
#  ('came', 1786),
#  ('stars', 1780),
#  ('cinema', 1778),
#  ('looks', 1770),
#  ('perhaps', 1768),
#  ('read', 1764),
#  ('enjoyed', 1758),
#  ('boy', 1750),
#  ('drama', 1746),
#  ('highly', 1742),
#  ('given', 1740),
#  ('playing', 1734),
#  ('use', 1728),
#  ('next', 1718),
#  ('women', 1716),
#  ('fine', 1714),
#  ('effects', 1712),
#  ('kids', 1708),
#  ('entertaining', 1706),
#  ('need', 1704),
#  ('line', 1700),
#  ('works', 1696),
#  ('someone', 1694),
#  ('mr', 1672),
#  ('simply', 1670),
#  ('picture', 1666),
#  ('children', 1666),
#  ('face', 1662),
#  ('keep', 1662),
#  ('friend', 1662),
#  ('dark', 1660),
#  ('overall', 1656),
#  ('certainly', 1656),
#  ('minutes', 1654),
#  ('wasn', 1648),
#  ('history', 1644),
#  ('finally', 1640),
#  ('couple', 1632),
#  ('against', 1630),
#  ('son', 1618),
#  ('understand', 1616),
#  ('lost', 1614),
#  ('michael', 1610),
#  ('else', 1602),
#  ('throughout', 1596),
#  ('fans', 1594),
#  ('city', 1584),
#  ('reason', 1578),
#  ('written', 1574),
#  ('production', 1574),
#  ('several', 1568),
#  ('school', 1566),
#  ('based', 1562),
#  ('rest', 1562),
#  ('try', 1560),
#  ('dead', 1552),
#  ('hope', 1550),
#  ('strong', 1536),
#  ('white', 1530),
#  ('tell', 1518),
#  ('itself', 1516),
#  ('half', 1506),
#  ('person', 1498),
#  ('sometimes', 1492),
#  ('past', 1488),
#  ('start', 1488),
#  ('genre', 1486),
#  ('beginning', 1478),
#  ('final', 1478),
#  ('town', 1476),
#  ('art', 1468),
#  ('humor', 1464),
#  ('game', 1464),
#  ('yes', 1462),
#  ('idea', 1462),
#  ('late', 1460),
#  ('becomes', 1458),
#  ('despite', 1458),
#  ('able', 1452),
#  ('case', 1452),
#  ('money', 1446),
#  ('child', 1442),
#  ('completely', 1442),
#  ('side', 1438),
#  ('camera', 1432),
#  ('getting', 1428),
#  ('instead', 1424),
#  ('soon', 1404),
#  ('under', 1400),
#  ('viewer', 1398),
#  ('age', 1394),
#  ('days', 1392),
#  ('stories', 1392),
#  ('felt', 1388),
#  ('simple', 1388),
#  ('roles', 1386),
#  ('video', 1376),
#  ('name', 1366),
#  ('either', 1366),
#  ('doing', 1354),
#  ('turns', 1348),
#  ('wants', 1342),
#  ('close', 1342),
#  ('title', 1338),
#  ('wrong', 1336),
#  ('went', 1332),
#  ('james', 1330),
#  ('evil', 1318),
#  ('budget', 1314),
#  ('episodes', 1314),
#  ('relationship', 1310),
#  ('fantastic', 1306),
#  ('piece', 1306),
#  ('david', 1302),
#  ('turn', 1296),
#  ('murder', 1292),
#  ('parts', 1290),
#  ('brother', 1288),
#  ('absolutely', 1286),
#  ('head', 1286),
#  ('experience', 1284),
#  ('eyes', 1282),
#  ('sex', 1276),
#  ('direction', 1274),
#  ('called', 1274),
#  ('directed', 1272),
#  ('lines', 1268),
#  ('behind', 1266),
#  ('sort', 1264),
#  ('actress', 1262),
#  ('lead', 1260),
#  ('oscar', 1256),
#  ('including', 1254),
#  ('example', 1254),
#  ('known', 1250),
#  ('musical', 1250),
#  ('chance', 1242),
#  ('score', 1240),
#  ('already', 1238),
#  ('feeling', 1238),
#  ('hit', 1238),
#  ('voice', 1230),
#  ('moment', 1224),
#  ('living', 1224),
#  ('low', 1220),
#  ('supporting', 1220),
#  ('ago', 1218),
#  ('themselves', 1216),
#  ('reality', 1210),
#  ('hilarious', 1210),
#  ('jack', 1208),
#  ('told', 1206),
#  ('hand', 1202),
#  ('quality', 1200),
#  ('moving', 1200),
#  ('dialogue', 1200),
#  ('song', 1198),
#  ('happy', 1198),
#  ('matter', 1196),
#  ('paul', 1196),
#  ('light', 1188),
#  ('future', 1186),
#  ('entire', 1184),
#  ('finds', 1182),
#  ('gave', 1178),
#  ('laugh', 1174),
#  ('released', 1172),
#  ('expect', 1168),
#  ('fight', 1162),
#  ('particularly', 1160),
#  ('cinematography', 1158),
#  ('police', 1158),
#  ('whose', 1156),
#  ('type', 1156),
#  ('sound', 1156),
#  ('view', 1146),
#  ('enjoyable', 1146),
#  ('number', 1144),
#  ('romantic', 1144),
#  ('husband', 1144),
#  ('daughter', 1144),
#  ('documentary', 1142),
#  ('self', 1140),
#  ('superb', 1138),
#  ('modern', 1138),
#  ('took', 1138),
#  ('robert', 1138),
#  ('mean', 1132),
#  ('shown', 1126),
#  ('coming', 1122),
#  ('important', 1120),
#  ('king', 1118),
#  ('leave', 1118),
#  ('change', 1116),
#  ('somewhat', 1110),
#  ('wanted', 1110),
#  ('tells', 1108),
#  ('events', 1104),
#  ('run', 1104),
#  ('career', 1104),
#  ('country', 1104),
#  ('heard', 1100),
#  ('season', 1100),
#  ('greatest', 1098),
#  ('girls', 1098),
#  ('etc', 1094),
#  ('care', 1092),
#  ('starts', 1090),
#  ('english', 1084),
#  ('killer', 1082),
#  ('tale', 1080),
#  ('guys', 1080),
#  ('totally', 1080),
#  ('animation', 1080),
#  ('usual', 1078),
#  ('miss', 1070),
#  ('opinion', 1070),
#  ('easy', 1062),
#  ('violence', 1062),
#  ('songs', 1060),
#  ('british', 1056),
#  ('says', 1052),
#  ('realistic', 1050),
#  ('writing', 1048),
#  ('writer', 1044),
#  ('act', 1044),
#  ('comic', 1042),
#  ('thriller', 1038),
#  ('television', 1034),
#  ('power', 1032),
#  ('ones', 1030),
#  ('kid', 1028),
#  ('york', 1026),
#  ('novel', 1026),
#  ('alone', 1024),
#  ('problem', 1024),
#  ('attention', 1018),
#  ('involved', 1016),
#  ('kill', 1014),
#  ('extremely', 1014),
#  ('seemed', 1012),
#  ('hero', 1010),
#  ('french', 1010),
#  ('rock', 1008),
#  ('stuff', 1002),
#  ('wish', 998),
#  ('begins', 996),
#  ('taken', 994),
#  ('sad', 994),
#  ('ways', 992),
#  ('richard', 990),
#  ('knows', 988),
#  ('atmosphere', 986),
#  ('similar', 982),
#  ('surprised', 982),
#  ('taking', 982),
#  ('car', 982),
#  ('george', 980),
#  ('perfectly', 980),
#  ('across', 978),
#  ('team', 978),
#  ('eye', 978),
#  ('sequence', 978),
#  ('room', 976),
#  ('due', 976),
#  ('among', 976),
#  ('serious', 976),
#  ('powerful', 976),
#  ('strange', 974),
#  ('order', 974),
#  ('cannot', 974),
#  ('b', 974),
#  ('beauty', 972),
#  ('famous', 970),
#  ('happened', 968),
#  ('tries', 968),
#  ('herself', 968),
#  ('myself', 968),
#  ('class', 966),
#  ('four', 964),
#  ('cool', 962),
#  ('release', 958),
#  ('anyway', 958),
#  ('theme', 958),
#  ('opening', 956),
#  ('entertainment', 954),
#  ('slow', 950),
#  ('ends', 950),
#  ('unique', 950),
#  ('exactly', 950),
#  ('easily', 948),
#  ('level', 948),
#  ('o', 948),
#  ('red', 948),
#  ('interest', 944),
#  ('happen', 942),
#  ('crime', 940),
#  ('viewing', 936),
#  ('sets', 934),
#  ('memorable', 934),
#  ('stop', 932),
#  ('group', 932),
#  ('problems', 926),
#  ('dance', 926),
#  ('working', 926),
#  ('sister', 926),
#  ('message', 926),
#  ('knew', 924),
#  ('mystery', 922),
#  ('nature', 922),
#  ('bring', 920),
#  ('believable', 918),
#  ('thinking', 918),
#  ('brought', 918),
#  ('mostly', 916),
#  ('disney', 914),
#  ('couldn', 914),
#  ('society', 912),
#  ('lady', 910),
#  ('within', 910),
#  ('blood', 908),
#  ('parents', 906),
#  ('upon', 906),
#  ('viewers', 906),
#  ('meets', 904),
#  ('form', 904),
#  ('peter', 904),
#  ('tom', 904),
#  ('usually', 904),
#  ('soundtrack', 904),
#  ('local', 900),
#  ('certain', 896),
#  ('follow', 896),
#  ('whether', 894),
#  ('possible', 892),
#  ('emotional', 890),
#  ('killed', 888),
#  ('above', 888),
#  ('de', 888),
#  ('god', 886),
#  ('middle', 886),
#  ('needs', 884),
#  ('happens', 884),
#  ('flick', 884),
#  ('masterpiece', 882),
#  ('period', 880),
#  ('major', 880),
#  ('named', 878),
#  ('haven', 878),
#  ('particular', 876),
#  ('th', 876),
#  ('earth', 874),
#  ('feature', 874),
#  ('stand', 872),
#  ('words', 870),
#  ('typical', 870),
#  ('elements', 866),
#  ('obviously', 866),
#  ('romance', 862),
#  ('jane', 860),
#  ('yourself', 854),
#  ('showing', 854),
#  ('brings', 852),
#  ('fantasy', 852),
#  ('guess', 846),
#  ('america', 846),
#  ('unfortunately', 844),
#  ('huge', 844),
#  ('indeed', 842),
#  ('running', 842),
#  ('talent', 840),
#  ('stage', 838),
#  ('started', 836),
#  ('leads', 834),
#  ('sweet', 834),
#  ('japanese', 834),
#  ('poor', 832),
#  ('deal', 832),
#  ('incredible', 826),
#  ('personal', 826),
#  ('fast', 824),
#  ('became', 820),
#  ('deep', 820),
#  ('hours', 818),
#  ('giving', 816),
#  ('nearly', 816),
#  ('dream', 816),
#  ('clearly', 814),
#  ('turned', 814),
#  ('obvious', 812),
#  ('near', 812),
#  ('cut', 810),
#  ('surprise', 810),
#  ('era', 808),
#  ('body', 808),
#  ('hour', 806),
#  ('female', 806),
#  ('five', 806),
#  ('note', 798),
#  ('learn', 796),
#  ('truth', 796),
#  ('except', 794),
#  ('feels', 794),
#  ('match', 794),
#  ('tony', 794),
#  ('filmed', 788),
#  ('clear', 788),
#  ('complete', 788),
#  ('street', 786),
#  ('eventually', 786),
#  ('keeps', 786),
#  ('older', 786),
#  ('lots', 786),
#  ('buy', 784),
#  ('william', 782),
#  ('stewart', 782),
#  ('fall', 780),
#  ('joe', 780),
#  ('meet', 780),
#  ('unlike', 778),
#  ('talking', 778),
#  ('shots', 778),
#  ('rating', 778),
#  ('difficult', 778),
#  ('dramatic', 776),
#  ('means', 776),
#  ('situation', 772),
#  ('wonder', 772),
#  ('present', 772),
#  ('appears', 772),
#  ('subject', 772),
#  ('comments', 770),
#  ('general', 766),
#  ('sequences', 766),
#  ('lee', 766),
#  ('points', 764),
#  ('earlier', 764),
#  ('gone', 758),
#  ('check', 758),
#  ('suspense', 756),
#  ('recommended', 756),
#  ('ten', 756),
#  ('third', 754),
#  ('business', 754),
#  ('talk', 750),
#  ('leaves', 750),
#  ('beyond', 750),
#  ('portrayal', 748),
#  ('beautifully', 746),
#  ('single', 744),
#  ('bill', 744),
#  ('plenty', 742),
#  ('word', 742),
#  ('whom', 740),
#  ('falls', 740),
#  ('scary', 738),
#  ('non', 738),
#  ('figure', 738),
#  ('battle', 738),
#  ('using', 736),
#  ('return', 736),
#  ('doubt', 734),
#  ('add', 734),
#  ('hear', 732),
#  ('solid', 732),
#  ('success', 732),
#  ('jokes', 730),
#  ('oh', 730),
#  ('touching', 730),
#  ('political', 730),
#  ('hell', 728),
#  ('awesome', 728),
#  ('boys', 728),
#  ('sexual', 724),
#  ('recently', 724),
#  ('dog', 724),
#  ('please', 722),
#  ('wouldn', 722),
#  ('straight', 722),
#  ('features', 722),
#  ('forget', 720),
#  ('setting', 720),
#  ('lack', 720),
#  ('married', 718),
#  ('mark', 718),
#  ('social', 714),
#  ('interested', 712),
#  ('adventure', 712),
#  ('actual', 710),
#  ('terrific', 710),
#  ('sees', 710),
#  ('brothers', 710),
#  ('move', 708),
#  ('call', 708),
#  ('various', 706),
#  ('theater', 706),
#  ('dr', 706),
#  ('animated', 704),
#  ('western', 702),
#  ('baby', 700),
#  ('space', 700),
#  ('leading', 696),
#  ('disappointed', 696),
#  ('portrayed', 692),
#  ('aren', 692),
#  ('screenplay', 690),
#  ('smith', 690),
#  ('towards', 688),
#  ('hate', 688),
#  ('noir', 686),
#  ('outstanding', 684),
#  ('decent', 684),
#  ('kelly', 684),
#  ('directors', 682),
#  ('journey', 682),
#  ('none', 680),
#  ('looked', 680),
#  ('effective', 680),
#  ('storyline', 678),
#  ('caught', 678),
#  ('sci', 678),
#  ('fi', 678),
#  ('cold', 678),
#  ('mary', 678),
#  ('rich', 676),
#  ('charming', 676),
#  ('popular', 674),
#  ('rare', 674),
#  ('manages', 674),
#  ('harry', 674),
#  ('spirit', 672),
#  ('appreciate', 670),
#  ('open', 670),
#  ('moves', 668),
#  ('basically', 668),
#  ('acted', 668),
#  ('inside', 666),
#  ('boring', 666),
#  ('century', 666),
#  ('mention', 666),
#  ('deserves', 666),
#  ('subtle', 666),
#  ('pace', 666),
#  ('familiar', 664),
#  ('background', 664),
#  ('ben', 662),
#  ('creepy', 660),
#  ('supposed', 660),
#  ('secret', 658),
#  ('die', 656),
#  ('jim', 656),
#  ('question', 654),
#  ('effect', 654),
#  ('natural', 654),
#  ('impressive', 652),
#  ('rate', 652),
#  ('language', 652),
#  ('saying', 650),
#  ('intelligent', 650),
#  ('telling', 648),
#  ('realize', 648),
#  ('material', 648),
#  ('scott', 648),
#  ('singing', 646),
#  ('dancing', 644),
#  ('visual', 642),
#  ('adult', 642),
#  ('imagine', 642),
#  ('kept', 640),
#  ('office', 640),
#  ('uses', 638),
#  ('pure', 636),
#  ('wait', 636),
#  ('stunning', 636),
#  ('review', 634),
#  ('previous', 634),
#  ('copy', 634),
#  ('seriously', 634),
#  ('reading', 632),
#  ('create', 632),
#  ('hot', 632),
#  ('created', 632),
#  ('magic', 632),
#  ('somehow', 632),
#  ('stay', 630),
#  ('attempt', 630),
#  ('escape', 630),
#  ('crazy', 630),
#  ('air', 630),
#  ('frank', 630),
#  ('hands', 628),
#  ('filled', 626),
#  ('expected', 624),
#  ('average', 624),
#  ('surprisingly', 624),
#  ('complex', 622),
#  ('quickly', 620),
#  ('successful', 620),
#  ('studio', 620),
#  ('plus', 618),
#  ('male', 618),
#  ('co', 614),
#  ('images', 612),
#  ('casting', 612),
#  ('following', 612),
#  ('minute', 612),
#  ('exciting', 612),
#  ('members', 610),
#  ('follows', 610),
#  ('themes', 610),
#  ('german', 610),
#  ('reasons', 610),
#  ('e', 610),
#  ('touch', 608),
#  ('edge', 608),
#  ('free', 608),
#  ('cute', 608),
#  ('genius', 608),
#  ('outside', 606),
#  ('reviews', 604),
#  ('admit', 604),
#  ('ok', 604),
#  ('younger', 604),
#  ('fighting', 602),
#  ('odd', 602),
#  ('master', 602),
#  ('recent', 600),
#  ('thanks', 600),
#  ('break', 600),
#  ('comment', 600),
#  ('apart', 598),
#  ('emotions', 596),
#  ('lovely', 596),
#  ('begin', 596),
#  ('doctor', 594),
#  ('party', 594),
#  ('italian', 594),
#  ('la', 592),
#  ('missed', 592),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('', 1290462),
#  ('the', 326778),
#  ('.', 167538),
#  ('a', 158642),
#  ('and', 148770),
#  ('of', 138018),
#  ('to', 137948),
#  ('br', 105274),
#  ('is', 100166),
#  ('it', 96654),
#  ('i', 93760),
#  ('in', 87506),
#  ('this', 81840),
#  ('that', 75230),
#  ('s', 63092),
#  ('was', 52582),
#  ('movie', 49930),
#  ('for', 43854),
#  ('but', 43562),
#  ('with', 41756),
#  ('as', 41250),
#  ('t', 40722),
#  ('film', 38436),
#  ('you', 35098),
#  ('on', 34384),
#  ('not', 32708),
#  ('have', 30288),
#  ('are', 29246),
#  ('be', 29082),
#  ('he', 27712),
#  ('one', 26268),
#  ('they', 26022),
#  ('at', 24558),
#  ('his', 24294),
#  ('all', 24072),
#  ('so', 22926),
#  ('like', 22476),
#  ('there', 21550),
#  ('just', 21238),
#  ('by', 21098),
#  ('or', 20544),
#  ('an', 20532),
#  ('who', 19938),
#  ('from', 19462),
#  ('if', 19036),
#  ('about', 18122),
#  ('out', 17958),
#  ('what', 16844),
#  ('some', 16612),
#  ('no', 16286),
#  ('her', 15894),
#  ('even', 15374),
#  ('can', 15306),
#  ('has', 15208),
#  ('good', 14846),
#  ('bad', 14802),
#  ('would', 14072),
#  ('up', 13940),
#  ('only', 13562),
#  ('more', 13460),
#  ('when', 13452),
#  ('she', 12888),
#  ('really', 12524),
#  ('time', 12418),
#  ('had', 12284),
#  ('my', 12030),
#  ('were', 12002),
#  ('which', 11560),
#  ('very', 11528),
#  ('me', 11212),
#  ('see', 10904),
#  ('don', 10672),
#  ('we', 10656),
#  ('their', 10556),
#  ('do', 10472),
#  ('story', 10416),
#  ('than', 10366),
#  ('been', 10200),
#  ('much', 10156),
#  ('get', 10074),
#  ('because', 9932),
#  ('people', 9612),
#  ('then', 9522),
#  ('make', 9444),
#  ('how', 9376),
#  ('could', 9372),
#  ('any', 9316),
#  ('into', 9134),
#  ('made', 9082),
#  ('first', 8612),
#  ('other', 8610),
#  ('well', 8508),
#  ('too', 8348),
#  ('them', 8330),
#  ('plot', 8308),
#  ('movies', 8160),
#  ('acting', 8112),
#  ('will', 7986),
#  ('way', 7978),
#  ('most', 7838),
#  ('him', 7716),
#  ('after', 7676),
#  ('its', 7310),
#  ('think', 7286),
#  ('also', 7216),
#  ('characters', 7200),
#  ('off', 7134),
#  ('watch', 7100),
#  ('character', 7012),
#  ('did', 7012),
#  ('why', 6926),
#  ('being', 6786),
#  ('better', 6716),
#  ('know', 6668),
#  ('over', 6632),
#  ('seen', 6530),
#  ('ever', 6526),
#  ('never', 6518),
#  ('your', 6466),
#  ('where', 6438),
#  ('two', 6346),
#  ('little', 6192),
#  ('films', 6154),
#  ('here', 6054),
#  ('m', 6000),
#  ('nothing', 5980),
#  ('say', 5964),
#  ('end', 5908),
#  ('something', 5884),
#  ('should', 5840),
#  ('many', 5818),
#  ('does', 5742),
#  ('thing', 5732),
#  ('show', 5724),
#  ('ve', 5658),
#  ('scene', 5632),
#  ('scenes', 5570),
#  ('these', 5448),
#  ('go', 5434),
#  ('didn', 5292),
#  ('great', 5280),
#  ('watching', 5280),
#  ('re', 5240),
#  ('doesn', 5202),
#  ('through', 5120),
#  ('such', 5088),
#  ('man', 5032),
#  ('worst', 4960),
#  ('actually', 4898),
#  ('actors', 4874),
#  ('life', 4858),
#  ('back', 4848),
#  ('while', 4836),
#  ('director', 4810),
#  ('funny', 4672),
#  ('going', 4638),
#  ('still', 4566),
#  ('another', 4508),
#  ('look', 4494),
#  ('now', 4474),
#  ('old', 4430),
#  ('those', 4424),
#  ('real', 4340),
#  ('few', 4316),
#  ('love', 4304),
#  ('horror', 4300),
#  ('before', 4294),
#  ('want', 4282),
#  ('minutes', 4252),
#  ('pretty', 4230),
#  ('best', 4188),
#  ('though', 4182),
#  ('same', 4162),
#  ('script', 4148),
#  ('work', 4054),
#  ('every', 4050),
#  ('seems', 4046),
#  ('least', 4022),
#  ('enough', 3994),
#  ('down', 3976),
#  ('original', 3966),
#  ('guy', 3928),
#  ('got', 3904),
#  ('around', 3886),
#  ('part', 3884),
#  ('lot', 3784),
#  ('anything', 3748),
#  ('find', 3720),
#  ('new', 3708),
#  ('again', 3698),
#  ('isn', 3698),
#  ('point', 3690),
#  ('things', 3678),
#  ('fact', 3678),
#  ('give', 3646),
#  ('makes', 3628),
#  ('take', 3600),
#  ('thought', 3596),
#  ('d', 3540),
#  ('whole', 3536),
#  ('long', 3522),
#  ('years', 3518),
#  ('however', 3480),
#  ('gets', 3428),
#  ('making', 3390),
#  ('cast', 3388),
#  ('big', 3324),
#  ('might', 3316),
#  ('interesting', 3296),
#  ('money', 3276),
#  ('us', 3256),
#  ('right', 3250),
#  ('far', 3238),
#  ('quite', 3192),
#  ('without', 3190),
#  ('come', 3190),
#  ('almost', 3148),
#  ('ll', 3134),
#  ('action', 3132),
#  ('awful', 3114),
#  ('kind', 3078),
#  ('reason', 3068),
#  ('am', 3060),
#  ('looks', 3056),
#  ('must', 3044),
#  ('done', 3020),
#  ('comedy', 3008),
#  ('someone', 2980),
#  ('trying', 2972),
#  ('wasn', 2968),
#  ('poor', 2962),
#  ('boring', 2956),
#  ('instead', 2956),
#  ('saw', 2950),
#  ('away', 2938),
#  ('girl', 2926),
#  ('probably', 2888),
#  ('believe', 2868),
#  ('sure', 2866),
#  ('looking', 2860),
#  ('stupid', 2856),
#  ('anyone', 2836),
#  ('times', 2812),
#  ('maybe', 2808),
#  ('world', 2808),
#  ('rather', 2788),
#  ('terrible', 2782),
#  ('may', 2780),
#  ('last', 2780),
#  ('since', 2776),
#  ('let', 2770),
#  ('tv', 2764),
#  ('hard', 2748),
#  ('between', 2748),
#  ('waste', 2716),
#  ('woman', 2712),
#  ('feel', 2708),
#  ('effects', 2696),
#  ('half', 2682),
#  ('own', 2666),
#  ('young', 2634),
#  ('music', 2632),
#  ('idea', 2624),
#  ('sense', 2612),
#  ('bit', 2596),
#  ('having', 2560),
#  ('book', 2556),
#  ('found', 2534),
#  ('put', 2526),
#  ('series', 2526),
#  ('goes', 2512),
#  ('worse', 2498),
#  ('said', 2460),
#  ('comes', 2448),
#  ('role', 2444),
#  ('main', 2440),
#  ('else', 2398),
#  ('everything', 2394),
#  ('yet', 2392),
#  ('low', 2378),
#  ('screen', 2376),
#  ('supposed', 2372),
#  ('actor', 2370),
#  ('either', 2366),
#  ('budget', 2358),
#  ('ending', 2358),
#  ('audience', 2356),
#  ('set', 2354),
#  ('family', 2340),
#  ('left', 2338),
#  ('completely', 2336),
#  ('both', 2316),
#  ('wrong', 2310),
#  ('always', 2302),
#  ('course', 2296),
#  ('place', 2296),
#  ('seem', 2294),
#  ('watched', 2284),
#  ('day', 2264),
#  ('simply', 2260),
#  ('shot', 2252),
#  ('mean', 2234),
#  ('special', 2204),
#  ('dead', 2202),
#  ('three', 2188),
#  ('house', 2170),
#  ('oh', 2168),
#  ('night', 2166),
#  ('read', 2164),
#  ('less', 2134),
#  ('high', 2132),
#  ('year', 2128),
#  ('camera', 2122),
#  ('worth', 2114),
#  ('our', 2112),
#  ('try', 2102),
#  ('horrible', 2092),
#  ('sex', 2092),
#  ('video', 2086),
#  ('black', 2078),
#  ('although', 2072),
#  ('couldn', 2072),
#  ('once', 2066),
#  ('rest', 2044),
#  ('dvd', 2042),
#  ('line', 2036),
#  ('played', 2034),
#  ('fun', 2014),
#  ('during', 2012),
#  ('production', 2006),
#  ('everyone', 2004),
#  ('play', 1986),
#  ('mind', 1980),
#  ('version', 1978),
#  ('kids', 1978),
#  ('seeing', 1976),
#  ('american', 1960),
#  ('given', 1956),
#  ('used', 1938),
#  ('performance', 1936),
#  ('especially', 1926),
#  ('together', 1926),
#  ('tell', 1918),
#  ('women', 1916),
#  ('start', 1912),
#  ('need', 1910),
#  ('second', 1906),
#  ('takes', 1900),
#  ('each', 1900),
#  ('wife', 1888),
#  ('dialogue', 1884),
#  ('use', 1880),
#  ('problem', 1876),
#  ('star', 1868),
#  ('unfortunately', 1862),
#  ('himself', 1858),
#  ('doing', 1852),
#  ('death', 1844),
#  ('name', 1842),
#  ('lines', 1838),
#  ('killer', 1828),
#  ('getting', 1826),
#  ('help', 1810),
#  ('couple', 1804),
#  ('fan', 1804),
#  ('head', 1796),
#  ('crap', 1790),
#  ('guess', 1776),
#  ('piece', 1768),
#  ('nice', 1760),
#  ('different', 1756),
#  ('school', 1752),
#  ('later', 1750),
#  ('entire', 1738),
#  ('shows', 1720),
#  ('next', 1716),
#  ('john', 1716),
#  ('short', 1714),
#  ('seemed', 1714),
#  ('hollywood', 1700),
#  ('home', 1696),
#  ('true', 1692),
#  ('person', 1692),
#  ('absolutely', 1684),
#  ('sort', 1680),
#  ('care', 1678),
#  ('understand', 1672),
#  ('plays', 1670),
#  ('felt', 1668),
#  ('written', 1658),
#  ('title', 1656),
#  ('men', 1644),
#  ('until', 1642),
#  ('flick', 1632),
#  ('decent', 1630),
#  ('face', 1628),
#  ('friends', 1620),
#  ('stars', 1614),
#  ('job', 1614),
#  ('case', 1614),
#  ('itself', 1608),
#  ('yes', 1602),
#  ('perhaps', 1600),
#  ('went', 1594),
#  ('wanted', 1594),
#  ('called', 1592),
#  ('annoying', 1590),
#  ('ridiculous', 1580),
#  ('tries', 1580),
#  ('laugh', 1576),
#  ('evil', 1574),
#  ('along', 1572),
#  ('top', 1570),
#  ('hour', 1568),
#  ('full', 1566),
#  ('came', 1560),
#  ('writing', 1560),
#  ('keep', 1540),
#  ('totally', 1534),
#  ('playing', 1532),
#  ('god', 1530),
#  ('won', 1528),
#  ('guys', 1526),
#  ('already', 1524),
#  ('gore', 1514),
#  ('direction', 1496),
#  ('save', 1492),
#  ('lost', 1490),
#  ('example', 1488),
#  ('sound', 1484),
#  ('war', 1482),
#  ('attempt', 1470),
#  ('car', 1466),
#  ('except', 1466),
#  ('moments', 1464),
#  ('blood', 1464),
#  ('obviously', 1460),
#  ('act', 1458),
#  ('remember', 1456),
#  ('kill', 1454),
#  ('truly', 1452),
#  ('white', 1452),
#  ('father', 1452),
#  ('b', 1450),
#  ('thinking', 1440),
#  ('ok', 1432),
#  ('finally', 1432),
#  ('turn', 1422),
#  ('quality', 1402),
#  ('lack', 1396),
#  ('style', 1388),
#  ('wouldn', 1386),
#  ('cheap', 1382),
#  ('none', 1380),
#  ('kid', 1372),
#  ('please', 1372),
#  ('boy', 1370),
#  ('seriously', 1368),
#  ('lead', 1360),
#  ('dull', 1354),
#  ('children', 1352),
#  ('starts', 1350),
#  ('stuff', 1346),
#  ('hope', 1344),
#  ('looked', 1340),
#  ('recommend', 1338),
#  ('under', 1336),
#  ('run', 1334),
#  ('killed', 1334),
#  ('enjoy', 1332),
#  ('others', 1332),
#  ('etc', 1326),
#  ('myself', 1326),
#  ('beginning', 1324),
#  ('girls', 1324),
#  ('against', 1324),
#  ('obvious', 1320),
#  ('small', 1320),
#  ('hell', 1318),
#  ('slow', 1314),
#  ('hand', 1312),
#  ('wonder', 1304),
#  ('lame', 1304),
#  ('becomes', 1302),
#  ('picture', 1302),
#  ('based', 1300),
#  ('early', 1296),
#  ('behind', 1292),
#  ('poorly', 1288),
#  ('avoid', 1284),
#  ('apparently', 1280),
#  ('complete', 1280),
#  ('happens', 1278),
#  ('anyway', 1276),
#  ('classic', 1274),
#  ('several', 1272),
#  ('despite', 1270),
#  ('certainly', 1270),
#  ('episode', 1270),
#  ('often', 1262),
#  ('cut', 1260),
#  ('writer', 1260),
#  ('mother', 1256),
#  ('predictable', 1256),
#  ('gave', 1256),
#  ('become', 1254),
#  ('close', 1250),
#  ('fans', 1248),
#  ('saying', 1242),
#  ('scary', 1238),
#  ('stop', 1236),
#  ('live', 1236),
#  ('wants', 1234),
#  ('self', 1230),
#  ('mr', 1224),
#  ('jokes', 1222),
#  ('friend', 1222),
#  ('cannot', 1220),
#  ('overall', 1218),
#  ('cinema', 1208),
#  ('child', 1206),
#  ('silly', 1202),
#  ('beautiful', 1192),
#  ('human', 1190),
#  ('expect', 1188),
#  ('liked', 1186),
#  ('happened', 1184),
#  ('bunch', 1180),
#  ('entertaining', 1180),
#  ('actress', 1176),
#  ('final', 1176),
#  ('says', 1168),
#  ('performances', 1168),
#  ('turns', 1154),
#  ('humor', 1154),
#  ('themselves', 1152),
#  ('eyes', 1152),
#  ('hours', 1148),
#  ('happen', 1146),
#  ('basically', 1144),
#  ('days', 1144),
#  ('running', 1142),
#  ('involved', 1138),
#  ('disappointed', 1138),
#  ('call', 1138),
#  ('directed', 1136),
#  ('group', 1136),
#  ('fight', 1134),
#  ('daughter', 1132),
#  ('talking', 1132),
#  ('body', 1132),
#  ('badly', 1130),
#  ('sorry', 1130),
#  ('throughout', 1126),
#  ('viewer', 1126),
#  ('yourself', 1124),
#  ('extremely', 1124),
#  ('interest', 1122),
#  ('heard', 1122),
#  ('violence', 1122),
#  ('shots', 1118),
#  ('side', 1114),
#  ('word', 1112),
#  ('art', 1110),
#  ('possible', 1108),
#  ('dark', 1102),
#  ('game', 1102),
#  ('hero', 1100),
#  ('alone', 1098),
#  ('son', 1094),
#  ('type', 1094),
#  ('leave', 1094),
#  ('gives', 1092),
#  ('parts', 1092),
#  ('single', 1092),
#  ('started', 1090),
#  ('female', 1086),
#  ('rating', 1082),
#  ('mess', 1082),
#  ('voice', 1082),
#  ('aren', 1080),
#  ('town', 1080),
#  ('drama', 1076),
#  ('definitely', 1074),
#  ('unless', 1072),
#  ('review', 1068),
#  ('effort', 1066),
#  ('weak', 1066),
#  ('able', 1066),
#  ('took', 1062),
#  ('non', 1060),
#  ('five', 1060),
#  ('matter', 1058),
#  ('usually', 1058),
#  ('michael', 1056),
#  ('feeling', 1052),
#  ('huge', 1046),
#  ('sequel', 1044),
#  ('soon', 1042),
#  ('exactly', 1040),
#  ('past', 1038),
#  ('turned', 1036),
#  ('police', 1036),
#  ('tried', 1030),
#  ('middle', 1026),
#  ('talent', 1026),
#  ('genre', 1024),
#  ('zombie', 1020),
#  ('ends', 1018),
#  ('history', 1018),
#  ('straight', 1006),
#  ('opening', 1002),
#  ('serious', 1002),
#  ('coming', 1002),
#  ('moment', 1000),
#  ('lives', 998),
#  ('sad', 998),
#  ('dialog', 996),
#  ('particularly', 996),
#  ('editing', 986),
#  ('clearly', 984),
#  ('beyond', 982),
#  ('earth', 982),
#  ('taken', 980),
#  ('cool', 980),
#  ('level', 978),
#  ('dumb', 978),
#  ('okay', 976),
#  ('major', 974),
#  ('fast', 970),
#  ('premise', 970),
#  ('joke', 968),
#  ('stories', 968),
#  ('wasted', 966),
#  ('minute', 966),
#  ('across', 964),
#  ('mostly', 964),
#  ('rent', 964),
#  ('late', 962),
#  ('falls', 962),
#  ('fails', 962),
#  ('mention', 956),
#  ('theater', 950),
#  ('stay', 944),
#  ('sometimes', 944),
#  ('hit', 936),
#  ('talk', 934),
#  ('fine', 934),
#  ('die', 932),
#  ('storyline', 930),
#  ('pointless', 930),
#  ('taking', 928),
#  ('order', 924),
#  ('brother', 922),
#  ('whatever', 920),
#  ('told', 920),
#  ('wish', 916),
#  ('room', 912),
#  ('career', 910),
#  ('appears', 910),
#  ('write', 910),
#  ('known', 908),
#  ('husband', 908),
#  ('living', 902),
#  ('sit', 900),
#  ('ten', 900),
#  ('words', 898),
#  ('monster', 896),
#  ('chance', 896),
#  ('hate', 888),
#  ('novel', 888),
#  ('add', 886),
#  ('english', 886),
#  ('somehow', 882),
#  ('strange', 880),
#  ('imdb', 876),
#  ('actual', 876),
#  ('total', 874),
#  ('material', 874),
#  ('killing', 874),
#  ('ones', 874),
#  ('knew', 872),
#  ('king', 868),
#  ('number', 868),
#  ('using', 866),
#  ('lee', 862),
#  ('power', 862),
#  ('shown', 862),
#  ('works', 862),
#  ('giving', 862),
#  ('points', 860),
#  ('possibly', 860),
#  ('kept', 860),
#  ('four', 858),
#  ('local', 854),
#  ('usual', 852),
#  ('including', 850),
#  ('problems', 848),
#  ('ago', 848),
#  ('opinion', 848),
#  ('nudity', 846),
#  ('age', 844),
#  ('due', 842),
#  ('roles', 840),
#  ('writers', 838),
#  ('decided', 838),
#  ('near', 836),
#  ('flat', 836),
#  ('easily', 836),
#  ('murder', 834),
#  ('experience', 834),
#  ('reviews', 832),
#  ('imagine', 830),
#  ('feels', 826),
#  ('plain', 822),
#  ('somewhat', 822),
#  ('class', 820),
#  ('score', 820),
#  ('song', 818),
#  ('bring', 818),
#  ('whether', 818),
#  ('otherwise', 816),
#  ('whose', 816),
#  ('average', 816),
#  ('pathetic', 814),
#  ('nearly', 814),
#  ('knows', 814),
#  ('zombies', 814),
#  ('cinematography', 812),
#  ('cheesy', 812),
#  ('upon', 812),
#  ('city', 810),
#  ('space', 810),
#  ('credits', 808),
#  ('james', 806),
#  ('lots', 806),
#  ('change', 806),
#  ('entertainment', 804),
#  ('nor', 804),
#  ('wait', 802),
#  ('released', 800),
#  ('needs', 798),
#  ('shame', 796),
#  ('attention', 792),
#  ('comments', 788),
#  ('bored', 786),
#  ('free', 786),
#  ('lady', 786),
#  ('expected', 784),
#  ('needed', 784),
#  ('clear', 784),
#  ('view', 782),
#  ('development', 780),
#  ('check', 780),
#  ('doubt', 780),
#  ('figure', 778),
#  ('mystery', 778),
#  ('excellent', 776),
#  ('garbage', 776),
#  ('sequence', 772),
#  ('television', 772),
#  ('o', 770),
#  ('sets', 770),
#  ('laughable', 768),
#  ('potential', 768),
#  ('robert', 764),
#  ('light', 764),
#  ('country', 764),
#  ('documentary', 764),
#  ('reality', 764),
#  ('general', 762),
#  ('ask', 762),
#  ('comic', 760),
#  ('fall', 760),
#  ('begin', 760),
#  ('footage', 758),
#  ('stand', 758),
#  ('forced', 758),
#  ('trash', 758),
#  ('remake', 758),
#  ('thriller', 756),
#  ('songs', 756),
#  ('gay', 754),
#  ('within', 754),
#  ('hardly', 752),
#  ('above', 750),
#  ('gone', 750),
#  ('george', 748),
#  ('means', 746),
#  ('sounds', 746),
#  ('directing', 744),
#  ('move', 744),
#  ('david', 744),
#  ('buy', 744),
#  ('rock', 742),
#  ('forward', 742),
#  ('important', 742),
#  ('hot', 740),
#  ('haven', 740),
#  ('filmed', 740),
#  ('british', 740),
#  ('heart', 738),
#  ('reading', 738),
#  ('fake', 738),
#  ('incredibly', 736),
#  ('weird', 736),
#  ('hear', 736),
#  ('enjoyed', 734),
#  ('hilarious', 734),
#  ('cop', 734),
#  ('musical', 734),
#  ('message', 732),
#  ('happy', 732),
#  ('pay', 732),
#  ('laughs', 730),
#  ('box', 730),
#  ('suspense', 726),
#  ('sadly', 726),
#  ('eye', 724),
#  ('third', 722),
#  ('similar', 722),
#  ('named', 722),
#  ('modern', 720),
#  ('failed', 718),
#  ('events', 718),
#  ('forget', 716),
#  ('question', 716),
#  ('male', 714),
#  ('finds', 714),
#  ('perfect', 712),
#  ('spent', 710),
#  ('sister', 710),
#  ('feature', 708),
#  ('result', 708),
#  ('comment', 706),
#  ('girlfriend', 706),
#  ('sexual', 704),
#  ('attempts', 702),
#  ('neither', 702),
#  ('richard', 702),
#  ('screenplay', 700),
#  ('elements', 700),
#  ('spoilers', 698),
#  ('brain', 696),
#  ('filmmakers', 696),
#  ('showing', 696),
#  ('miss', 694),
#  ('dr', 694),
#  ('christmas', 694),
#  ('cover', 690),
#  ('red', 688),
#  ('sequences', 688),
#  ('typical', 686),
#  ('excuse', 686),
#  ('crazy', 684),
#  ('ideas', 684),
#  ('baby', 684),
#  ('loved', 682),
#  ('meant', 682),
#  ('worked', 680),
#  ('fire', 680),
#  ('unbelievable', 678),
#  ('follow', 678),
#  ('theme', 674),
#  ('barely', 672),
#  ('producers', 672),
#  ('twist', 672),
#  ('plus', 672),
#  ('appear', 672),
#  ('directors', 670),
#  ('team', 670),
#  ('viewers', 666),
#  ('leads', 664),
#  ('tom', 664),
#  ('slasher', 664),
#  ('wrote', 662),
#  ('villain', 662),
#  ('gun', 662),
#  ('working', 662),
#  ('island', 660),
#  ('strong', 660),
#  ('open', 660),
#  ('realize', 660),
#  ('positive', 658),
#  ('disappointing', 658),
#  ('yeah', 658),
#  ('quickly', 658),
#  ('weren', 656),
#  ('release', 656),
#  ('simple', 656),
#  ('honestly', 656),
#  ('eventually', 654),
#  ('period', 654),
#  ('tells', 654),
#  ('kills', 654),
#  ('doctor', 654),
#  ('nowhere', 652),
#  ('list', 652),
#  ('acted', 652),
#  ('herself', 652),
#  ('dog', 652),
#  ('walk', 650),
#  ('air', 648),
#  ('apart', 648),
#  ('makers', 646),
#  ('subject', 646),
#  ('learn', 644),
#  ('fi', 644),
#  ('sci', 638),
#  ('bother', 638),
#  ('admit', 638),
#  ('jack', 636),
#  ('disappointment', 636),
#  ('hands', 636),
#  ('note', 636),
#  ('certain', 634),
#  ('e', 634),
#  ('value', 634),
#  ('casting', 634),
#  ('grade', 632),
#  ('peter', 632),
#  ('suddenly', 630),
#  ('missing', 630),
#  ('form', 626),
#  ('stick', 626),
#  ('previous', 626),
#  ('break', 626),
#  ('soundtrack', 624),
#  ('surprised', 622),
#  ('front', 622),
#  ('expecting', 622),
#  ('parents', 620),
#  ('surprise', 620),
#  ('relationship', 620),
#  ('shoot', 618),
#  ('today', 618),
#  ('painful', 616),
#  ('ways', 616),
#  ('leaves', 616),
#  ('ended', 616),
#  ('creepy', 616),
#  ('concept', 616),
#  ('somewhere', 616),
#  ('vampire', 616),
#  ('spend', 614),
#  ('th', 614),
#  ('future', 612),
#  ('difficult', 612),
#  ('effect', 612),
#  ('fighting', 612),
#  ('street', 612),
#  ('c', 610),
#  ('america', 610),
#  ('accent', 608),
#  ('truth', 604),
#  ('project', 604),
#  ('joe', 602),
#  ('f', 602),
#  ('deal', 602),
#  ('indeed', 602),
#  ('biggest', 600),
#  ('rate', 600),
#  ('paul', 598),
#  ('japanese', 598),
#  ('utterly', 596),
#  ('begins', 596),
#  ('redeeming', 596),
#  ('college', 596),
#  ('york', 594),
#  ('fairly', 594),
#  ('disney', 594),
#  ('crew', 592),
#  ('create', 592),
#  ('cartoon', 592),
#  ('revenge', 592),
#  ('co', 590),
#  ('outside', 590),
#  ('computer', 590),
#  ('interested', 590),
#  ('stage', 590),
#  ('considering', 588),
#  ('speak', 588),
#  ('among', 588),
#  ('towards', 586),
#  ('channel', 586),
#  ('sick', 586),
#  ('talented', 584),
#  ('cause', 584),
#  ('particular', 584),
#  ('van', 584),
#  ('hair', 584),
#  ('bottom', 582),
#  ('reasons', 582),
#  ('mediocre', 580),
#  ('cat', 580),
#  ('telling', 580),
#  ('supporting', 578),
#  ('store', 578),
#  ('hoping', 576),
#  ('waiting', 576),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
#       Consider words to be "common" if they've been used at least 100 times
for word in total_counts:
    if word in positive_counts and word in negative_counts:
        pos_neg_ratios[word] = positive_counts[word]/(negative_counts[word]+1)

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.060802560752068
# Pos-to-neg ratio for 'amazing' = 4.0304761904761905
# Pos-to-neg ratio for 'terrible' = 0.17750628817822495

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
# TODO: Convert ratios to logs
for word, ratio in pos_neg_ratios.items():
    pos_neg_ratios[word] = np.log(ratio)

# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05902575442851183
# Pos-to-neg ratio for 'amazing' = 1.3938845303865663
# Pos-to-neg ratio for 'terrible' = -1.7287492443379682

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('paulie', 4.3652195163575005),
#  ('gundam', 3.6054978451748854),
#  ('iturbi', 3.5648268054439574),
#  ('giovanna', 3.4657359027997265),
#  ('feinstone', 3.4657359027997265),
#  ('luzhin', 3.4011973816621555),
#  ('philo', 3.355735007585398),
#  ('lindy', 3.332204510175204),
#  ('felix', 3.258096538021482),
#  ('clutter', 3.258096538021482),
#  ('anchors', 3.2321210516182215),
#  ('capote', 3.1945831322991562),
#  ('excellently', 3.1612467120315646),
#  ('korda', 3.1498829533812494),
#  ('fido', 3.1416861861770706),
#  ('callahan', 3.120895416507997),
#  ('deanna', 3.109060958860994),
#  ('hayworth', 3.109060958860994),
#  ('aiello', 3.091042453358316),
#  ('vance', 3.077970371790963),
#  ('kolchak', 3.0647251450409425),
#  ('sammo', 3.0349529867072724),
#  ('bake', 3.028522096376982),
#  ('laputa', 3.0155349008501706),
#  ('hickock', 2.995732273553991),
#  ('ashraf', 2.995732273553991),
#  ('aviv', 2.995732273553991),
#  ('eustache', 2.995732273553991),
#  ('sox', 2.9667447366807385),
#  ('beery', 2.9618307218783095),
#  ('dench', 2.9618307218783095),
#  ('partition', 2.9618307218783095),
#  ('conroy', 2.9618307218783095),
#  ('alvin', 2.951929650895598),
#  ('biko', 2.9385738597140425),
#  ('myrtle', 2.9338568698359038),
#  ('adele', 2.9338568698359038),
#  ('gackt', 2.9338568698359038),
#  ('pang', 2.9267394020670396),
#  ('polanski', 2.9103724246028344),
#  ('mathieu', 2.906120114864304),
#  ('bernsen', 2.8903717578961645),
#  ('fricker', 2.8903717578961645),
#  ('emil', 2.8903717578961645),
#  ('gannon', 2.8903717578961645),
#  ('katsu', 2.8903717578961645),
#  ('dev', 2.8903717578961645),
#  ('matthau', 2.8638801424491884),
#  ('gilliam', 2.8581108956779433),
#  ('saura', 2.8526314299133175),
#  ('unpretentious', 2.772588722239781),
#  ('harriet', 2.772588722239781),
#  ('lupino', 2.772588722239781),
#  ('chavez', 2.772588722239781),
#  ('blackadder', 2.772588722239781),
#  ('perdition', 2.772588722239781),
#  ('binder', 2.772588722239781),
#  ('yuzna', 2.772588722239781),
#  ('ratso', 2.7586024802650413),
#  ('ultimatum', 2.7362210780689065),
#  ('abbey', 2.7300291078209855),
#  ('judi', 2.7300291078209855),
#  ('mahatma', 2.7300291078209855),
#  ('jonestown', 2.7300291078209855),
#  ('godmother', 2.7300291078209855),
#  ('mcnally', 2.7300291078209855),
#  ('zu', 2.7212954278522306),
#  ('abu', 2.7212954278522306),
#  ('sammi', 2.7212954278522306),
#  ('warhols', 2.7212954278522306),
#  ('victoria', 2.714923080389972),
#  ('rosenstrasse', 2.6946271807700692),
#  ('radiant', 2.6855773452501515),
#  ('noriko', 2.6855773452501515),
#  ('woronov', 2.6855773452501515),
#  ('waterman', 2.6855773452501515),
#  ('pike', 2.6855773452501515),
#  ('stockwell', 2.6855773452501515),
#  ('mildred', 2.667228206581955),
#  ('delightfully', 2.659260036932778),
#  ('corbett', 2.6548056865833978),
#  ('mclaglen', 2.6519607344511664),
#  ('reservations', 2.6390573296152584),
#  ('johnston', 2.6390573296152584),
#  ('brisson', 2.6390573296152584),
#  ('taker', 2.6390573296152584),
#  ('schmid', 2.6390573296152584),
#  ('marylee', 2.6390573296152584),
#  ('creasy', 2.6390573296152584),
#  ('oberon', 2.6390573296152584),
#  ('durbin', 2.6100697927420065),
#  ('braveheart', 2.606796467397037),
#  ('vonnegut', 2.597384633214691),
#  ('gandhi', 2.596132284898225),
#  ('sirk', 2.5941059417529924),
#  ('kazan', 2.5902671654458267),
#  ('jud', 2.5902671654458267),
#  ('montrose', 2.5902671654458267),
#  ('ungar', 2.5902671654458267),
#  ('manny', 2.5902671654458267),
#  ('bannister', 2.5902671654458267),
#  ('hundstage', 2.5902671654458267),
#  ('girlfight', 2.5902671654458267),
#  ('homeward', 2.5902671654458267),
#  ('natali', 2.575878427993727),
#  ('pita', 2.5494451709255714),
#  ('mccoy', 2.5437471498109336),
#  ('sweetly', 2.538973871058276),
#  ('linklater', 2.538973871058276),
#  ('zentropa', 2.538973871058276),
#  ('mccartney', 2.538973871058276),
#  ('hickok', 2.538973871058276),
#  ('gigi', 2.538973871058276),
#  ('tully', 2.538973871058276),
#  ('elia', 2.538973871058276),
#  ('aborigines', 2.538973871058276),
#  ('othello', 2.5226469777708473),
#  ('cheadle', 2.521274293958875),
#  ('novak', 2.5102244577722903),
#  ('flawless', 2.5022983924998696),
#  ('elsa', 2.4849066497880004),
#  ('treasured', 2.4849066497880004),
#  ('quartier', 2.4849066497880004),
#  ('squire', 2.4849066497880004),
#  ('tigerland', 2.4849066497880004),
#  ('christy', 2.4849066497880004),
#  ('hatcher', 2.4849066497880004),
#  ('flamenco', 2.4849066497880004),
#  ('fuller', 2.4720032449520923),
#  ('ramones', 2.4720032449520923),
#  ('cal', 2.466214516775848),
#  ('jabba', 2.46080909820894),
#  ('aunts', 2.451005098112319),
#  ('olympia', 2.451005098112319),
#  ('sullavan', 2.451005098112319),
#  ('coop', 2.436116485618568),
#  ('sailing', 2.4277482359480516),
#  ('anand', 2.4277482359480516),
#  ('cartwright', 2.4277482359480516),
#  ('province', 2.4277482359480516),
#  ('leung', 2.4277482359480516),
#  ('spellbinding', 2.4277482359480516),
#  ('brodie', 2.4277482359480516),
#  ('mahoney', 2.4277482359480516),
#  ('pressburger', 2.4277482359480516),
#  ('kennel', 2.4277482359480516),
#  ('curr', 2.4277482359480516),
#  ('speakeasy', 2.4277482359480516),
#  ('winchester', 2.4223862928066664),
#  ('tomlinson', 2.4159137783010487),
#  ('fagin', 2.4107986776342782),
#  ('hanzo', 2.4107986776342782),
#  ('rea', 2.407945608651872),
#  ('haines', 2.407945608651872),
#  ('colman', 2.407945608651872),
#  ('chamberlain', 2.406125771934886),
#  ('beetle', 2.3848231912310176),
#  ('complement', 2.379546134130174),
#  ('raoul', 2.379546134130174),
#  ('magnificently', 2.379546134130174),
#  ('benet', 2.379546134130174),
#  ('genesis', 2.367123614131617),
#  ('mores', 2.367123614131617),
#  ('yang', 2.367123614131617),
#  ('tackled', 2.367123614131617),
#  ('boothe', 2.367123614131617),
#  ('braun', 2.367123614131617),
#  ('loomis', 2.367123614131617),
#  ('janeway', 2.367123614131617),
#  ('lupin', 2.367123614131617),
#  ('influential', 2.3581549441488563),
#  ('kalifornia', 2.3581549441488563),
#  ('northam', 2.3460702049337847),
#  ('marvelously', 2.341805806147327),
#  ('carla', 2.341805806147327),
#  ('iris', 2.341805806147327),
#  ('weir', 2.341805806147327),
#  ('vertigo', 2.330755969960742),
#  ('sabrina', 2.328902401311419),
#  ('stardust', 2.324563999712821),
#  ('peters', 2.3158303197440664),
#  ('finely', 2.302585092994046),
#  ('superbly', 2.302585092994046),
#  ('goa', 2.302585092994046),
#  ('patekar', 2.302585092994046),
#  ('milton', 2.302585092994046),
#  ('dearly', 2.302585092994046),
#  ('richness', 2.302585092994046),
#  ('stevenson', 2.302585092994046),
#  ('stubby', 2.302585092994046),
#  ('broomsticks', 2.302585092994046),
#  ('donnell', 2.302585092994046),
#  ('kinnear', 2.302585092994046),
#  ('cheung', 2.302585092994046),
#  ('silvio', 2.302585092994046),
#  ('sasha', 2.302585092994046),
#  ('tenant', 2.302585092994046),
#  ('tetsuo', 2.302585092994046),
#  ('ephemeral', 2.302585092994046),
#  ('accomplishes', 2.302585092994046),
#  ('kessler', 2.302585092994046),
#  ('saffron', 2.302585092994046),
#  ('wodehouse', 2.302585092994046),
#  ('gilley', 2.302585092994046),
#  ('laird', 2.302585092994046),
#  ('archibald', 2.302585092994046),
#  ('brokedown', 2.302585092994046),
#  ('stalkers', 2.302585092994046),
#  ('celine', 2.2735975561207935),
#  ('abbot', 2.2617630984737906),
#  ('footlight', 2.2617630984737906),
#  ('iago', 2.2617630984737906),
#  ('romy', 2.2617630984737906),
#  ('raines', 2.2617630984737906),
#  ('devos', 2.2617630984737906),
#  ('fez', 2.2617630984737906),
#  ('enchanting', 2.257122718917288),
#  ('vulnerability', 2.243744592971112),
#  ('hark', 2.243744592971112),
#  ('marjorie', 2.243744592971112),
#  ('darius', 2.243744592971112),
#  ('georges', 2.23907168727172),
#  ('slipper', 2.2335922215070942),
#  ('trebor', 2.2335922215070942),
#  ('carre', 2.2335922215070942),
#  ('pecker', 2.2335922215070942),
#  ('preity', 2.2335922215070942),
#  ('wegener', 2.2335922215070942),
#  ('argentine', 2.2335922215070942),
#  ('collinwood', 2.2335922215070942),
#  ('cratchit', 2.2335922215070942),
#  ('gingold', 2.2335922215070942),
#  ('meena', 2.2335922215070942),
#  ('noll', 2.2335922215070942),
#  ('mala', 2.2335922215070942),
#  ('aames', 2.2335922215070942),
#  ('quotable', 2.2192034840549946),
#  ('tintin', 2.2192034840549946),
#  ('curtiz', 2.2192034840549946),
#  ('duchess', 2.2192034840549946),
#  ('rukh', 2.216642663193321),
#  ('benoit', 2.2129729343043585),
#  ('duryea', 2.2129729343043585),
#  ('devotion', 2.209494669928034),
#  ('trier', 2.205735267004128),
#  ('perfection', 2.1933858010290535),
#  ('dixon', 2.1913594578838214),
#  ('fairytale', 2.181224235989778),
#  ('tel', 2.181224235989778),
#  ('askey', 2.181224235989778),
#  ('ella', 2.181224235989778),
#  ('miyazaki', 2.17742195004004),
#  ('astaire', 2.1764338076671454),
#  ('frailty', 2.174751721484161),
#  ('pawn', 2.174751721484161),
#  ('bozz', 2.174751721484161),
#  ('egan', 2.174751721484161),
#  ('pickpocket', 2.174751721484161),
#  ('observant', 2.159484249353372),
#  ('blindness', 2.159484249353372),
#  ('butterflies', 2.159484249353372),
#  ('aborigine', 2.159484249353372),
#  ('lucile', 2.159484249353372),
#  ('collaborators', 2.159484249353372),
#  ('ozzie', 2.159484249353372),
#  ('paget', 2.159484249353372),
#  ('stealer', 2.159484249353372),
#  ('ellie', 2.159484249353372),
#  ('flik', 2.159484249353372),
#  ('impressionist', 2.159484249353372),
#  ('coccio', 2.159484249353372),
#  ('bulimia', 2.159484249353372),
#  ('borowczyk', 2.159484249353372),
#  ('lyman', 2.159484249353372),
#  ('spellbound', 2.159484249353372),
#  ('solicitor', 2.159484249353372),
#  ('ronda', 2.159484249353372),
#  ('iberia', 2.159484249353372),
#  ('lucienne', 2.159484249353372),
#  ('kher', 2.159484249353372),
#  ('maslin', 2.159484249353372),
#  ('cheech', 2.159484249353372),
#  ('kumari', 2.159484249353372),
#  ('cassavettes', 2.159484249353372),
#  ('schygulla', 2.159484249353372),
#  ('rolle', 2.159484249353372),
#  ('bettany', 2.159484249353372),
#  ('blaine', 2.1484344131667874),
#  ('malone', 2.1365999555197845),
#  ('oshii', 2.128231705849268),
#  ('ida', 2.128231705849268),
#  ('bafta', 2.128231705849268),
#  ('stairway', 2.128231705849268),
#  ('refreshingly', 2.128231705849268),
#  ('strathairn', 2.128231705849268),
#  ('francois', 2.128231705849268),
#  ('edith', 2.12389330425067),
#  ('venezuela', 2.114532861491106),
#  ('mol', 2.112231364502827),
#  ('clarence', 2.10684051586795),
#  ('scoop', 2.0959708436310462),
#  ('pickford', 2.0959708436310462),
#  ('sumptuous', 2.0794415416798357),
#  ('transcends', 2.0794415416798357),
#  ('heightens', 2.0794415416798357),
#  ('zorro', 2.0794415416798357),
#  ('travers', 2.0794415416798357),
#  ('uproarious', 2.0794415416798357),
#  ('breathes', 2.0794415416798357),
#  ('finlay', 2.0794415416798357),
#  ('runyon', 2.0794415416798357),
#  ('strides', 2.0794415416798357),
#  ('nan', 2.0794415416798357),
#  ('enforced', 2.0794415416798357),
#  ('firefighters', 2.0794415416798357),
#  ('wtc', 2.0794415416798357),
#  ('exquisitely', 2.0794415416798357),
#  ('linden', 2.0794415416798357),
#  ('advent', 2.0794415416798357),
#  ('weismuller', 2.0794415416798357),
#  ('zandalee', 2.0794415416798357),
#  ('demunn', 2.0794415416798357),
#  ('singin', 2.0794415416798357),
#  ('rogen', 2.0794415416798357),
#  ('rathbone', 2.0794415416798357),
#  ('mischa', 2.0794415416798357),
#  ('colonialism', 2.0794415416798357),
#  ('nicolai', 2.0794415416798357),
#  ('perseverance', 2.0794415416798357),
#  ('leisen', 2.0794415416798357),
#  ('rafael', 2.0794415416798357),
#  ('tumultuous', 2.0794415416798357),
#  ('patric', 2.0794415416798357),
#  ('pabst', 2.0794415416798357),
#  ('dedlock', 2.0794415416798357),
#  ('auer', 2.0794415416798357),
#  ('skagway', 2.0794415416798357),
#  ('bhandarkar', 2.0794415416798357),
#  ('trejo', 2.0794415416798357),
#  ('bearer', 2.0794415416798357),
#  ('corsaut', 2.0794415416798357),
#  ('jong', 2.0794415416798357),
#  ('britton', 2.0794415416798357),
#  ('conor', 2.0794415416798357),
#  ('geddes', 2.0794415416798357),
#  ('nath', 2.0794415416798357),
#  ('tadashi', 2.0794415416798357),
#  ('lumire', 2.0794415416798357),
#  ('voight', 2.0693912058263346),
#  ('dandy', 2.0626344233634546),
#  ('captures', 2.0588222544771004),
#  ('enthralling', 2.05127066471314),
#  ('mostel', 2.05127066471314),
#  ('henderson', 2.05127066471314),
#  ('heartbreaking', 2.049588578530155),
#  ('lighten', 2.043073897508961),
#  ('adelaide', 2.043073897508961),
#  ('turturro', 2.043073897508961),
#  ('wonderfully', 2.035141282783256),
#  ('siu', 2.028148247292285),
#  ('electrifying', 2.028148247292285),
#  ('teri', 2.028148247292285),
#  ('splendidly', 2.028148247292285),
#  ('uncompromising', 2.028148247292285),
#  ('twisty', 2.028148247292285),
#  ('prix', 2.028148247292285),
#  ('hardwicke', 2.028148247292285),
#  ('wang', 2.02537432040956),
#  ('corbin', 2.0222831278398874),
#  ('lila', 2.0222831278398874),
#  ('truman', 2.0104486701928845),
#  ('superlative', 2.005333569526114),
#  ('labyrinth', 2.005333569526114),
#  ('sunrise', 1.9993988340062996),
#  ('powell', 1.9977635106655687),
#  ('hawke', 1.9972034434428638),
#  ('rail', 1.992430164690206),
#  ('sg', 1.992430164690206),
#  ('kibbee', 1.992430164690206),
#  ('masterful', 1.992430164690206),
#  ('warms', 1.992430164690206),
#  ('perceptions', 1.992430164690206),
#  ('coveted', 1.992430164690206),
#  ('masterson', 1.992430164690206),
#  ('cameroon', 1.992430164690206),
#  ('nunsploitation', 1.992430164690206),
#  ('expansion', 1.992430164690206),
#  ('mavens', 1.992430164690206),
#  ('lassick', 1.992430164690206),
#  ('rediscovered', 1.992430164690206),
#  ('chang', 1.992430164690206),
#  ('pension', 1.992430164690206),
#  ('expressionistic', 1.992430164690206),
#  ('booker', 1.992430164690206),
#  ('minton', 1.992430164690206),
#  ('rippner', 1.992430164690206),
#  ('sternberg', 1.992430164690206),
#  ('albuquerque', 1.992430164690206),
#  ('snare', 1.992430164690206),
#  ('friel', 1.992430164690206),
#  ('montand', 1.992430164690206),
#  ('gallows', 1.992430164690206),
#  ('birdie', 1.992430164690206),
#  ('borden', 1.992430164690206),
#  ('apollonia', 1.992430164690206),
#  ('gorshin', 1.992430164690206),
#  ('eduardo', 1.992430164690206),
#  ('brosnan', 1.9865477947871395),
#  ('expertly', 1.9740810260220096),
#  ('examines', 1.9740810260220096),
#  ('raja', 1.9740810260220096),
#  ('talespin', 1.9740810260220096),
#  ('robust', 1.9740810260220096),
#  ('celebrates', 1.9740810260220096),
#  ('prem', 1.9740810260220096),
#  ('champions', 1.9740810260220096),
#  ('franks', 1.9740810260220096),
#  ('undying', 1.9740810260220096),
#  ('mower', 1.9740810260220096),
#  ('trotta', 1.9740810260220096),
#  ('brock', 1.9661128563728327),
#  ('abby', 1.9661128563728327),
#  ('zelda', 1.9661128563728327),
#  ('guiness', 1.9661128563728327),
#  ('morbius', 1.9661128563728327),
#  ('mendes', 1.9661128563728327),
#  ('sematary', 1.9616585060234524),
#  ('busby', 1.9588135538912212),
#  ('holt', 1.9588135538912212),
#  ('informer', 1.9588135538912212),
#  ('tomei', 1.9568392195875035),
#  ('europa', 1.9542783987258299),
#  ('lily', 1.9502298101998297),
#  ('darren', 1.9390841839849136),
#  ('cypher', 1.9363406980391626),
#  ('greene', 1.9348603128687283),
#  ('bakshi', 1.9328380674879606),
#  ('keeler', 1.9299098077088723),
#  ('connolly', 1.9299098077088723),
#  ('carface', 1.9299098077088723),
#  ('zabriskie', 1.9299098077088723),
#  ('batwoman', 1.9299098077088723),
#  ('rory', 1.9252908618525775),
#  ('parisian', 1.9252908618525775),
#  ('strangler', 1.9252908618525775),
#  ('shemp', 1.9252908618525775),
#  ('culp', 1.9252908618525775),
#  ('lincoln', 1.9234372932032546),
#  ('axel', 1.916922612182061),
#  ('carrell', 1.916922612182061),
#  ('silhouette', 1.916922612182061),
#  ('entranced', 1.916922612182061),
#  ('deft', 1.916922612182061),
#  ('bureaucracy', 1.916922612182061),
#  ('provo', 1.916922612182061),
#  ('ilona', 1.916922612182061),
#  ('caprice', 1.916922612182061),
#  ('vulcan', 1.916922612182061),
#  ('pegg', 1.916922612182061),
#  ('shefali', 1.916922612182061),
#  ('dell', 1.916922612182061),
#  ('ullman', 1.916922612182061),
#  ('hoon', 1.916922612182061),
#  ('stepsisters', 1.916922612182061),
#  ('radium', 1.916922612182061),
#  ('kovacs', 1.916922612182061),
#  ('custer', 1.916922612182061),
#  ('vincenzo', 1.9061698204057993),
#  ('carell', 1.9014583864844796),
#  ('shanks', 1.8971199848858813),
#  ('leia', 1.8971199848858813),
#  ('crouse', 1.8971199848858813),
#  ('priorities', 1.8971199848858813),
#  ('mcgrath', 1.8971199848858813),
#  ('summertime', 1.8971199848858813),
#  ('considerations', 1.8971199848858813),
#  ('outstandingly', 1.8971199848858813),
#  ('duets', 1.8971199848858813),
#  ('sorbonne', 1.8971199848858813),
#  ('regency', 1.8971199848858813),
#  ('prelude', 1.8971199848858813),
#  ('funhouse', 1.8971199848858813),
#  ('judson', 1.8971199848858813),
#  ('mammy', 1.8971199848858813),
#  ('witherspoon', 1.8971199848858813),
#  ('competitor', 1.8971199848858813),
#  ('monarchy', 1.8971199848858813),
#  ('taft', 1.8971199848858813),
#  ('glacier', 1.8971199848858813),
#  ('noire', 1.8971199848858813),
#  ('zenith', 1.8971199848858813),
#  ('congrats', 1.8971199848858813),
#  ('moulin', 1.8971199848858813),
#  ('panda', 1.8971199848858813),
#  ('duc', 1.8971199848858813),
#  ('orphaned', 1.8971199848858813),
#  ('internationally', 1.8971199848858813),
#  ('humanism', 1.8971199848858813),
#  ('synthesis', 1.8971199848858813),
#  ('ponderosa', 1.8971199848858813),
#  ('hahk', 1.8971199848858813),
#  ('eytan', 1.8971199848858813),
#  ('grasshopper', 1.8971199848858813),
#  ('bloch', 1.8971199848858813),
#  ('restrictive', 1.8971199848858813),
#  ('serrault', 1.8971199848858813),
#  ('roshan', 1.8971199848858813),
#  ('florinda', 1.8971199848858813),
#  ('roberta', 1.8971199848858813),
#  ('kabal', 1.8971199848858813),
#  ('patten', 1.8971199848858813),
#  ('taka', 1.8971199848858813),
#  ('cocktails', 1.8971199848858813),
#  ('anansa', 1.8971199848858813),
#  ('meloni', 1.8971199848858813),
#  ('breakdancing', 1.8971199848858813),
#  ('nunez', 1.8971199848858813),
#  ('retriever', 1.8971199848858813),
#  ('montana', 1.8931119634883424),
#  ('parrot', 1.889397938791971),
#  ('precise', 1.889397938791971),
#  ('miners', 1.8827312474337816),
#  ('reginald', 1.8827312474337816),
#  ('todesking', 1.8827312474337816),
#  ('lemmon', 1.8797282421740122),
#  ('marcus', 1.8787708462176849),
#  ('walsh', 1.875141078167106),
#  ('refreshing', 1.8731998011682294),
#  ('breathtaking', 1.870091312497962),
#  ('bourne', 1.8672670217362002),
#  ('massey', 1.8658674413817768),
#  ('evans', 1.8658674413817768),
#  ('friendships', 1.8632184332102),
#  ('foch', 1.8632184332102),
#  ('maclean', 1.8632184332102),
#  ('explores', 1.8595820655668163),
#  ('steele', 1.8595820655668163),
#  ('romanticized', 1.8562979903656263),
#  ('schmidt', 1.8562979903656263),
#  ('krabbe', 1.8562979903656263),
#  ('muller', 1.8562979903656263),
#  ('sceptical', 1.8562979903656263),
#  ('janice', 1.8562979903656263),
#  ('jerome', 1.8562979903656263),
#  ('scola', 1.8562979903656263),
#  ('bulldog', 1.8562979903656263),
#  ('crashers', 1.8562979903656263),
#  ('petition', 1.8562979903656263),
#  ('doodlebops', 1.8562979903656263),
#  ('textile', 1.8562979903656263),
#  ('caleb', 1.8562979903656263),
#  ('mvp', 1.8562979903656263),
#  ('apartheid', 1.8505999692509885),
#  ('civilized', 1.8382794848629478),
#  ('mastery', 1.8382794848629478),
#  ('partnership', 1.8382794848629478),
#  ('delon', 1.8382794848629478),
#  ('buttgereit', 1.8382794848629478),
#  ('extravagant', 1.8382794848629478),
#  ('doolittle', 1.8382794848629478),
#  ('connecticut', 1.8382794848629478),
#  ('criterion', 1.8382794848629478),
#  ('poirot', 1.8382794848629478),
#  ('paperhouse', 1.8281271133989299),
#  ('flynn', 1.8237622003142289),
#  ('scorpion', 1.821612432377736),
#  ('bittersweet', 1.817077277212345),
#  ('cedric', 1.817077277212345),
#  ('chess', 1.816150922352214),
#  ('ira', 1.8137383759468304),
#  ('deliciously', 1.8137383759468304),
#  ('delightful', 1.8131735637318716),
#  ('homer', 1.8031881650516777),
#  ('andrews', 1.7994815153219654),
#  ('bracelet', 1.791759469228055),
#  ('murdoch', 1.791759469228055),
#  ('mammoth', 1.791759469228055),
#  ('permits', 1.791759469228055),
#  ('composure', 1.791759469228055),
#  ('hoodlums', 1.791759469228055),
#  ('accustomed', 1.791759469228055),
#  ('tart', 1.791759469228055),
#  ('escalates', 1.791759469228055),
#  ('tapestry', 1.791759469228055),
#  ('unrestrained', 1.791759469228055),
#  ('pendleton', 1.791759469228055),
#  ('weaves', 1.791759469228055),
#  ('progressing', 1.791759469228055),
#  ('starlets', 1.791759469228055),
#  ('celeste', 1.791759469228055),
#  ('perceptive', 1.791759469228055),
#  ('quintessential', 1.791759469228055),
#  ('rarer', 1.791759469228055),
#  ('vigorous', 1.791759469228055),
#  ('myrna', 1.791759469228055),
#  ('soccer', 1.791759469228055),
#  ('affection', 1.791759469228055),
#  ('bagdad', 1.791759469228055),
#  ('paxinou', 1.791759469228055),
#  ('advancing', 1.791759469228055),
#  ('barrie', 1.791759469228055),
#  ('demolished', 1.791759469228055),
#  ('duplicated', 1.791759469228055),
#  ('amsterdam', 1.791759469228055),
#  ('introverted', 1.791759469228055),
#  ('proposes', 1.791759469228055),
#  ('candid', 1.791759469228055),
#  ('structures', 1.791759469228055),
#  ('shia', 1.791759469228055),
#  ('interacted', 1.791759469228055),
#  ('underscored', 1.791759469228055),
#  ('riotous', 1.791759469228055),
#  ('fai', 1.791759469228055),
#  ('predicaments', 1.791759469228055),
#  ('attest', 1.791759469228055),
#  ('erected', 1.791759469228055),
#  ('te', 1.791759469228055),
#  ('spatula', 1.791759469228055),
#  ('tinker', 1.791759469228055),
#  ('agamemnon', 1.791759469228055),
#  ('holm', 1.791759469228055),
#  ('optical', 1.791759469228055),
#  ('henri', 1.791759469228055),
#  ('hermann', 1.791759469228055),
#  ('rosalind', 1.791759469228055),
#  ('resonant', 1.791759469228055),
#  ('voicing', 1.791759469228055),
#  ('pawns', 1.791759469228055),
#  ('lydia', 1.791759469228055),
#  ('intercontinental', 1.791759469228055),
#  ('moonstruck', 1.791759469228055),
#  ('yokozuna', 1.791759469228055),
#  ('inexorably', 1.791759469228055),
#  ('dahlia', 1.791759469228055),
#  ('carne', 1.791759469228055),
#  ('blier', 1.791759469228055),
#  ('tsing', 1.791759469228055),
#  ('impulsive', 1.791759469228055),
#  ('orbach', 1.791759469228055),
#  ('dukakis', 1.791759469228055),
#  ('weber', 1.791759469228055),
#  ('nablus', 1.791759469228055),
#  ('palsy', 1.791759469228055),
#  ('thesiger', 1.791759469228055),
#  ('manuel', 1.791759469228055),
#  ('detained', 1.791759469228055),
#  ('hearn', 1.791759469228055),
#  ('mimes', 1.791759469228055),
#  ('airwolf', 1.791759469228055),
#  ('dickinson', 1.791759469228055),
#  ('yonica', 1.791759469228055),
#  ('tamerlane', 1.791759469228055),
#  ('shohei', 1.791759469228055),
#  ('sarafina', 1.791759469228055),
#  ('batgirl', 1.791759469228055),
#  ('hingle', 1.791759469228055),
#  ('everytown', 1.791759469228055),
#  ('meatball', 1.791759469228055),
#  ('yoda', 1.791759469228055),
#  ('binnie', 1.791759469228055),
#  ('inarritu', 1.791759469228055),
#  ('aneta', 1.791759469228055),
#  ('lanchester', 1.791759469228055),
#  ('gleaming', 1.791759469228055),
#  ('daz', 1.791759469228055),
#  ('matsumoto', 1.791759469228055),
#  ('stoolie', 1.791759469228055),
#  ('mariette', 1.791759469228055),
#  ('chabat', 1.791759469228055),
#  ('elam', 1.791759469228055),
#  ('jonah', 1.791759469228055),
#  ('bowler', 1.791759469228055),
#  ('lumet', 1.780198646826979),
#  ('kidman', 1.7757591278816138),
#  ('beautifully', 1.7705385137451697),
#  ('ealing', 1.7657839828247943),
#  ('han', 1.7657839828247943),
#  ('sopranos', 1.7623455840217617),
#  ('elvira', 1.761682013990777),
#  ('nina', 1.7560413866259759),
#  ('maintained', 1.754019141245208),
#  ('tenderness', 1.754019141245208),
#  ('joyous', 1.754019141245208),
#  ('restoration', 1.754019141245208),
#  ('nicky', 1.754019141245208),
#  ('determination', 1.7462970951512977),
#  ('unavailable', 1.742969305058623),
#  ('ringo', 1.742969305058623),
#  ('compliments', 1.742969305058623),
#  ('antidote', 1.742969305058623),
#  ('repulsion', 1.742969305058623),
#  ('jonny', 1.742969305058623),
#  ('chico', 1.742969305058623),
#  ('zelah', 1.739115735742633),
#  ('gripping', 1.7385149547092427),
#  ('paula', 1.7376922479577792),
#  ('deliverance', 1.7376922479577792),
#  ('underrated', 1.7337722115777057),
#  ('doggie', 1.7227665977411035),
#  ('serene', 1.7227665977411035),
#  ('compellingly', 1.7227665977411035),
#  ('resonates', 1.7227665977411035),
#  ('opposites', 1.7227665977411035),
#  ('grifters', 1.7227665977411035),
#  ('snatched', 1.7227665977411035),
#  ('sensitively', 1.7227665977411035),
#  ('hampton', 1.7227665977411035),
#  ('undercurrent', 1.7227665977411035),
#  ('expressionism', 1.7227665977411035),
#  ('analyzed', 1.7227665977411035),
#  ('swashbuckling', 1.7227665977411035),
#  ('miramax', 1.7227665977411035),
#  ('riker', 1.7227665977411035),
#  ('avery', 1.7227665977411035),
#  ('braga', 1.7227665977411035),
#  ('seidl', 1.7227665977411035),
#  ('sooraj', 1.7227665977411035),
#  ('reeve', 1.7190001149456267),
#  ('tierney', 1.7165360479904674),
#  ('enforcer', 1.7147984280919266),
#  ('complexities', 1.7147984280919266),
#  ('franchot', 1.7147984280919266),
#  ('cruz', 1.7147984280919266),
#  ('superb', 1.714017635547868),
#  ('ae', 1.7100814382137879),
#  ('soylent', 1.6999519199749322),
#  ('marisa', 1.698669046162043),
#  ('stadium', 1.698669046162043),
#  ('hedy', 1.69644928942373),
#  ('rugged', 1.69644928942373),
#  ('wai', 1.69644928942373),
#  ('technicolor', 1.6937790608678513),
#  ('seamlessly', 1.6916760106710724),
#  ('delight', 1.6916760106710724),
#  ('companionship', 1.6916760106710724),
#  ('sadness', 1.6916760106710724),
#  ('trading', 1.6916760106710724),
#  ('corinne', 1.6916760106710724),
#  ('amicus', 1.6916760106710724),
#  ('cheryl', 1.6916760106710724),
#  ('sergeants', 1.6916760106710724),
#  ('moriarty', 1.6916760106710724),
#  ('swordplay', 1.6916760106710724),
#  ('demme', 1.6916760106710724),
#  ('gershwin', 1.6885752329928243),
#  ('kline', 1.6847873496758872),
#  ('welles', 1.6802856027649362),
#  ('villaronga', 1.6739764335716716),
#  ('calvert', 1.6739764335716716),
#  ('betrothed', 1.6739764335716716),
#  ('naturalness', 1.6739764335716716),
#  ('menial', 1.6739764335716716),
#  ('govind', 1.6739764335716716),
#  ('farscape', 1.6739764335716716),
#  ('delved', 1.6739764335716716),
#  ('nascent', 1.6739764335716716),
#  ('pip', 1.6739764335716716),
#  ('soppy', 1.6739764335716716),
#  ('lofty', 1.6739764335716716),
#  ('sultan', 1.6739764335716716),
#  ('tugs', 1.6739764335716716),
#  ('preoccupation', 1.6739764335716716),
#  ('chivalry', 1.6739764335716716),
#  ('lavender', 1.6739764335716716),
#  ('shantytown', 1.6739764335716716),
#  ('malco', 1.6739764335716716),
#  ('eiffel', 1.6739764335716716),
#  ('georgian', 1.6739764335716716),
#  ('fervent', 1.6739764335716716),
#  ('centipede', 1.6739764335716716),
#  ('unbreakable', 1.6739764335716716),
#  ('loyalties', 1.6739764335716716),
#  ('malefique', 1.6739764335716716),
#  ('frightens', 1.6739764335716716),
#  ('destinies', 1.6739764335716716),
#  ('bracco', 1.6739764335716716),
#  ('easygoing', 1.6739764335716716),
#  ('seoul', 1.6739764335716716),
#  ('bureaucratic', 1.6739764335716716),
#  ('personification', 1.6739764335716716),
#  ('awestruck', 1.6739764335716716),
#  ('belasco', 1.6739764335716716),
#  ('klugman', 1.6739764335716716),
#  ('maruschka', 1.6739764335716716),
#  ('conte', 1.6739764335716716),
#  ('fabled', 1.6739764335716716),
#  ('outdone', 1.6739764335716716),
#  ('swashbuckler', 1.6739764335716716),
#  ('upstart', 1.6739764335716716),
#  ('heartache', 1.6739764335716716),
#  ('synapse', 1.6739764335716716),
#  ('rue', 1.6739764335716716),
#  ('pleasingly', 1.6739764335716716),
#  ('feyder', 1.6739764335716716),
#  ('yossi', 1.6739764335716716),
#  ('slovenian', 1.6739764335716716),
#  ('karyn', 1.6739764335716716),
#  ('dreamcast', 1.6739764335716716),
#  ('searing', 1.6739764335716716),
#  ('barber', 1.6739764335716716),
#  ('valet', 1.6739764335716716),
#  ('roeper', 1.6739764335716716),
#  ('dragnet', 1.6739764335716716),
#  ('raul', 1.6739764335716716),
#  ('vii', 1.6739764335716716),
#  ('persists', 1.6739764335716716),
#  ('rapaport', 1.6739764335716716),
#  ('mowbray', 1.6739764335716716),
#  ('amrohi', 1.6739764335716716),
#  ('momentous', 1.6739764335716716),
#  ('scanner', 1.6739764335716716),
#  ('lohman', 1.6739764335716716),
#  ('alienate', 1.6625477377480486),
#  ('rainer', 1.6625477377480486),
#  ('timeless', 1.65455834771457),
#  ('sinatra', 1.651575496882505),
#  ('macy', 1.6509869153469727),
#  ('emotive', 1.6486586255873816),
#  ('dystopian', 1.6486586255873816),
#  ('intricacies', 1.6486586255873816),
#  ('juxtaposition', 1.6486586255873816),
#  ('unflinching', 1.6486586255873816),
#  ('donovan', 1.6486586255873816),
#  ('distressed', 1.6486586255873816),
#  ('sneaky', 1.6486586255873816),
#  ('plato', 1.6486586255873816),
#  ('conductor', 1.6486586255873816),
#  ('banjo', 1.6486586255873816),
#  ('hastings', 1.6486586255873816),
#  ('andr', 1.6486586255873816),
#  ('rays', 1.6486586255873816),
#  ('embraces', 1.6486586255873816),
#  ('vanities', 1.6486586255873816),
#  ('infernal', 1.6486586255873816),
#  ('addictions', 1.6486586255873816),
#  ('collaborator', 1.6486586255873816),
#  ('stifling', 1.6486586255873816),
#  ('shivers', 1.6486586255873816),
#  ('centerpiece', 1.6486586255873816),
#  ('sampson', 1.6486586255873816),
#  ('balsam', 1.6486586255873816),
#  ('mulholland', 1.6486586255873816),
#  ('watanabe', 1.6486586255873816),
#  ('tanner', 1.6486586255873816),
#  ('waco', 1.6486586255873816),
#  ('indelible', 1.6486586255873816),
#  ('loveable', 1.6486586255873816),
#  ('gardiner', 1.6486586255873816),
#  ('inevitability', 1.6486586255873816),
#  ('izo', 1.6486586255873816),
#  ('nair', 1.6486586255873816),
#  ('suleiman', 1.6486586255873816),
#  ('stormtroopers', 1.6486586255873816),
#  ('kurosawa', 1.6458055566049752),
#  ('touching', 1.6442846437642686),
#  ('grayson', 1.6433394641097818),
#  ('dustin', 1.6405284995041314),
#  ('hartley', 1.6392908755837814),
#  ('unforgettable', 1.6387901244466276),
#  ('astor', 1.6376087894007967),
#  ('clara', 1.6376087894007967),
#  ('illusions', 1.6376087894007967),
#  ('settling', 1.6376087894007967),
#  ('yuen', 1.6376087894007967),
#  ('piggy', 1.6376087894007967),
#  ('liu', 1.6376087894007967),
#  ('longs', 1.6376087894007967),
#  ('einstein', 1.6376087894007967),
#  ('una', 1.6376087894007967),
#  ('cate', 1.6376087894007967),
#  ('chu', 1.6376087894007967),
#  ('batista', 1.6376087894007967),
#  ('favorites', 1.6321293236361711),
#  ('lyle', 1.6314168191528755),
#  ('connelly', 1.6314168191528755),
#  ('jaffe', 1.6314168191528755),
#  ('regal', 1.6274564179367788),
#  ('merrill', 1.6274564179367788),
#  ('liza', 1.6274564179367788),
#  ('diver', 1.6274564179367788),
#  ('extraordinary', 1.6268296551459696),
#  ('sullivan', 1.6251862694022394),
#  ('eagle', 1.622683139184121),
#  ('scarlett', 1.622683139184121),
#  ('layered', 1.622683139184121),
#  ('mesmerizing', 1.6189166563886441),
#  ('stewart', 1.6184296236260645),
#  ('shanghai', 1.616818019731723),
#  ('iran', 1.6158688027643908),
#  ('brilliantly', 1.6070253660287164),
#  ('heartwarming', 1.6007042324653458),
#  ('wrenching', 1.5998684614179497),
#  ('fairbanks', 1.5988558031035636),
#  ('delirious', 1.5976034547870976),
#  ('johansson', 1.5976034547870976),
#  ('captivated', 1.5960148921019597),
#  ('relaxed', 1.5960148921019597),
#  ('fritz', 1.5960148921019597),
#  ('conflicted', 1.5939337258981352),
#  ('maturity', 1.5939337258981352),
#  ('gently', 1.5939337258981352),
#  ('showcases', 1.5939337258981352),
#  ('realist', 1.5910887737659039),
#  ('planets', 1.5910887737659039),
#  ('albums', 1.5910887737659039),
#  ('sweetheart', 1.5910887737659039),
#  ('poppins', 1.5910887737659039),
#  ('mischievous', 1.5910887737659039),
#  ('nielsen', 1.5910887737659039),
#  ('watson', 1.5885312276147867),
#  ('fateful', 1.586965056582042),
#  ('humane', 1.586965056582042),
#  ('akira', 1.586965056582042),
#  ('trey', 1.586965056582042),
#  ('election', 1.583004655365945),
#  ('palma', 1.5820389382459858),
#  ('wei', 1.580450375560848),
#  ('spall', 1.580450375560848),
#  ('jafar', 1.580450375560848),
#  ('affectionate', 1.580450375560848),
#  ('lan', 1.580450375560848),
#  ('jos', 1.580450375560848),
#  ('rouge', 1.580450375560848),
#  ('michell', 1.580450375560848),
#  ('macgregor', 1.580450375560848),
#  ('friendship', 1.5780217162007213),
#  ('lang', 1.5773495978825998),
#  ('rowlands', 1.5773495978825998),
#  ('understated', 1.5766480896111095),
#  ('simmons', 1.5743465926228302),
#  ('macmahon', 1.5686159179138452),
#  ('pereira', 1.5686159179138452),
#  ('merge', 1.5686159179138452),
#  ('madge', 1.5686159179138452),
#  ('newfound', 1.5686159179138452),
#  ('blondell', 1.5686159179138452),
#  ('balances', 1.5686159179138452),
#  ('complements', 1.5686159179138452),
#  ('gretchen', 1.5686159179138452),
#  ('ettore', 1.5686159179138452),
#  ('migration', 1.5686159179138452),
#  ('crowe', 1.5686159179138452),
#  ('edmond', 1.5686159179138452),
#  ('okada', 1.5686159179138452),
#  ('medley', 1.5686159179138452),
#  ('plains', 1.5686159179138452),
#  ('mussolini', 1.5686159179138452),
#  ('rumble', 1.5686159179138452),
#  ('assurance', 1.5686159179138452),
#  ('tides', 1.5686159179138452),
#  ('etched', 1.5686159179138452),
#  ('globalization', 1.5686159179138452),
#  ('dictator', 1.5686159179138452),
#  ('parter', 1.5686159179138452),
#  ('brutish', 1.5686159179138452),
#  ('chelsea', 1.5686159179138452),
#  ('strode', 1.5686159179138452),
#  ('morales', 1.5686159179138452),
#  ('bolivian', 1.5686159179138452),
#  ('mendez', 1.5686159179138452),
#  ('momsen', 1.5686159179138452),
#  ('laud', 1.5686159179138452),
#  ('gabriele', 1.5686159179138452),
#  ('bouchet', 1.5686159179138452),
#  ('mecca', 1.5686159179138452),
#  ('pappy', 1.5686159179138452),
#  ('heretic', 1.5686159179138452),
#  ('wonderful', 1.5662862721310362),
#  ('cloth', 1.5621850275835547),
#  ('ritter', 1.5614984501449811),
#  ('magnificent', 1.5575660817272603),
#  ('finest', 1.556515510979758),
#  ('jackie', 1.556193397915288),
#  ('elliott', 1.5553706911638245),
#  ('blends', 1.5533484457830569),
#  ('coen', 1.5533484457830569),
#  ('sherry', 1.5533484457830569),
#  ('irs', 1.5533484457830569),
#  ('postman', 1.5533484457830569),
#  ('gertrude', 1.5533484457830569),
#  ('celie', 1.5533484457830569),
#  ('conveys', 1.5518087995974639),
#  ('benefits', 1.5488132906176655),
#  ('cena', 1.5488132906176655),
#  ('diego', 1.5488132906176655),
#  ('shahid', 1.5488132906176655),
#  ('nathan', 1.545359055749578),
#  ('buffalo', 1.545359055749578),
#  ('adoptive', 1.540445040947149),
#  ('tragedies', 1.540445040947149),
#  ('reproduced', 1.540445040947149),
#  ('thier', 1.540445040947149),
#  ('evolves', 1.540445040947149),
#  ('adversity', 1.540445040947149),
#  ('purchases', 1.540445040947149),
#  ('celebratory', 1.540445040947149),
#  ('availability', 1.540445040947149),
#  ('rounders', 1.540445040947149),
#  ('lifelike', 1.540445040947149),
#  ('rumours', 1.540445040947149),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]
# Out:
# [('boll', -4.966335035199676),
#  ('uwe', -4.620058798481842),
#  ('thunderbirds', -4.119037174812472),
#  ('beowulf', -4.102643365036796),
#  ('dahmer', -3.979681653901961),
#  ('wayans', -3.9219733362813143),
#  ('ajay', -3.8607297110405954),
#  ('grendel', -3.8607297110405954),
#  ('awfulness', -3.6506582412937383),
#  ('seagal', -3.6408702349275757),
#  ('steaming', -3.624340932976365),
#  ('welch', -3.597312260588446),
#  ('deathstalker', -3.5409593240373143),
#  ('sabretooth', -3.417726683613366),
#  ('interminable', -3.417726683613366),
#  ('forwarding', -3.3843902633457743),
#  ('devgan', -3.349904087274605),
#  ('gamera', -3.3232358401924436),
#  ('varma', -3.2771447329921766),
#  ('picker', -3.2771447329921766),
#  ('razzie', -3.2771447329921766),
#  ('dreck', -3.264486336120253),
#  ('unwatchable', -3.253277251585533),
#  ('stinker', -3.2037621870581527),
#  ('nada', -3.1986731175506815),
#  ('nostril', -3.1570004211501135),
#  ('giamatti', -3.1570004211501135),
#  ('kirkland', -3.1570004211501135),
#  ('aag', -3.1135153092103742),
#  ('hartnett', -3.1135153092103742)]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = total_counts.keys()

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros((1, vocab_size))

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'bromwell': 0,
#  'high': 1,
#  'is': 2,
#  'a': 3,
#  'cartoon': 4,
#  'comedy': 5,
#  '': 6,
#  'it': 7,
#  'ran': 8,
#  'at': 9,
#  'the': 10,
#  'same': 11,
#  'time': 12,
#  'as': 13,
#  'some': 14,
#  'other': 15,
#  'programs': 16,
#  'about': 17,
#  'school': 18,
#  'life': 19,
#  'such': 20,
#  'teachers': 21,
#  'my': 22,
#  'years': 23,
#  'in': 24,
#  'teaching': 25,
#  'profession': 26,
#  'lead': 27,
#  'me': 28,
#  'to': 29,
#  'believe': 30,
#  'that': 31,
#  's': 32,
#  'satire': 33,
#  'much': 34,
#  'closer': 35,
#  'reality': 36,
#  'than': 37,
#  'scramble': 38,
#  'survive': 39,
#  'financially': 40,
#  'insightful': 41,
#  'students': 42,
#  'who': 43,
#  'can': 44,
#  'see': 45,
#  'right': 46,
#  'through': 47,
#  'their': 48,
#  'pathetic': 49,
#  'pomp': 50,
#  'pettiness': 51,
#  'of': 52,
#  'whole': 53,
#  'situation': 54,
#  'all': 55,
#  'remind': 56,
#  'schools': 57,
#  'i': 58,
#  'knew': 59,
#  'and': 60,
#  'when': 61,
#  'saw': 62,
#  'episode': 63,
#  'which': 64,
#  'student': 65,
#  'repeatedly': 66,
#  'tried': 67,
#  'burn': 68,
#  'down': 69,
#  'immediately': 70,
#  'recalled': 71,
#  'classic': 72,
#  'line': 73,
#  'inspector': 74,
#  'm': 75,
#  'here': 76,
#  'sack': 77,
#  'one': 78,
#  'your': 79,
#  'welcome': 80,
#  'expect': 81,
#  'many': 82,
#  'adults': 83,
#  'age': 84,
#  'think': 85,
#  'far': 86,
#  'fetched': 87,
#  'what': 88,
#  'pity': 89,
#  'isn': 90,
#  't': 91,
#  'story': 92,
#  'man': 93,
#  'has': 94,
#  'unnatural': 95,
#  'feelings': 96,
#  'for': 97,
#  'pig': 98,
#  'starts': 99,
#  'out': 100,
#  'with': 101,
#  'opening': 102,
#  'scene': 103,
#  'terrific': 104,
#  'example': 105,
#  'absurd': 106,
#  'formal': 107,
#  'orchestra': 108,
#  'audience': 109,
#  'turned': 110,
#  'into': 111,
#  'an': 112,
#  'insane': 113,
#  'violent': 114,
#  'mob': 115,
#  'by': 116,
#  'crazy': 117,
#  'chantings': 118,
#  'singers': 119,
#  'unfortunately': 120,
#  'stays': 121,
#  'no': 122,
#  'general': 123,
#  'narrative': 124,
#  'eventually': 125,
#  'making': 126,
#  'just': 127,
#  'too': 128,
#  'off': 129,
#  'putting': 130,
#  'even': 131,
#  'those': 132,
#  'from': 133,
#  'era': 134,
#  'should': 135,
#  'be': 136,
#  'cryptic': 137,
#  'dialogue': 138,
#  'would': 139,
#  'make': 140,
#  'shakespeare': 141,
#  'seem': 142,
#  'easy': 143,
#  'third': 144,
#  'grader': 145,
#  'on': 146,
#  'technical': 147,
#  'level': 148,
#  'better': 149,
#  'you': 150,
#  'might': 151,
#  'good': 152,
#  'cinematography': 153,
#  'future': 154,
#  'great': 155,
#  'vilmos': 156,
#  'zsigmond': 157,
#  'stars': 158,
#  'sally': 159,
#  'kirkland': 160,
#  'frederic': 161,
#  'forrest': 162,
#  'seen': 163,
#  'briefly': 164,
#  'homelessness': 165,
#  'or': 166,
#  'houselessness': 167,
#  'george': 168,
#  'carlin': 169,
#  'stated': 170,
#  'been': 171,
#  'issue': 172,
#  'but': 173,
#  'never': 174,
#  'plan': 175,
#  'help': 176,
#  'street': 177,
#  'were': 178,
#  'once': 179,
#  'considered': 180,
#  'human': 181,
#  'did': 182,
#  'everything': 183,
#  'going': 184,
#  'work': 185,
#  'vote': 186,
#  'matter': 187,
#  'most': 188,
#  'people': 189,
#  'homeless': 190,
#  'lost': 191,
#  'cause': 192,
#  'while': 193,
#  'worrying': 194,
#  'things': 195,
#  'racism': 196,
#  'war': 197,
#  'iraq': 198,
#  'pressuring': 199,
#  'kids': 200,
#  'succeed': 201,
#  'technology': 202,
#  'elections': 203,
#  'inflation': 204,
#  'if': 205,
#  'they': 206,
#  'll': 207,
#  'next': 208,
#  'end': 209,
#  'up': 210,
#  'streets': 211,
#  'br': 212,
#  'given': 213,
#  'bet': 214,
#  'live': 215,
#  'month': 216,
#  'without': 217,
#  'luxuries': 218,
#  'had': 219,
#  'home': 220,
#  'entertainment': 221,
#  'sets': 222,
#  'bathroom': 223,
#  'pictures': 224,
#  'wall': 225,
#  'computer': 226,
#  'treasure': 227,
#  'like': 228,
#  'goddard': 229,
#  'bolt': 230,
#  'lesson': 231,
#  'mel': 232,
#  'brooks': 233,
#  'directs': 234,
#  'plays': 235,
#  'rich': 236,
#  'world': 237,
#  'until': 238,
#  'deciding': 239,
#  'sissy': 240,
#  'rival': 241,
#  'jeffery': 242,
#  'tambor': 243,
#  'he': 244,
#  'thirty': 245,
#  'days': 246,
#  'succeeds': 247,
#  'do': 248,
#  'wants': 249,
#  'project': 250,
#  'more': 251,
#  'buildings': 252,
#  'where': 253,
#  'thrown': 254,
#  'bracelet': 255,
#  'his': 256,
#  'leg': 257,
#  'monitor': 258,
#  'every': 259,
#  'move': 260,
#  'step': 261,
#  'sidewalk': 262,
#  'nickname': 263,
#  'pepto': 264,
#  'vagrant': 265,
#  'after': 266,
#  'written': 267,
#  'forehead': 268,
#  'meets': 269,
#  'characters': 270,
#  'including': 271,
#  'woman': 272,
#  'name': 273,
#  'molly': 274,
#  'lesley': 275,
#  'ann': 276,
#  'warren': 277,
#  'ex': 278,
#  'dancer': 279,
#  'got': 280,
#  'divorce': 281,
#  'before': 282,
#  'losing': 283,
#  'her': 284,
#  'pals': 285,
#  'sailor': 286,
#  'howard': 287,
#  'morris': 288,
#  'fumes': 289,
#  'teddy': 290,
#  'wilson': 291,
#  'are': 292,
#  'already': 293,
#  'used': 294,
#  're': 295,
#  'survivors': 296,
#  'not': 297,
#  'reaching': 298,
#  'mutual': 299,
#  'agreements': 300,
#  'being': 301,
#  'fight': 302,
#  'flight': 303,
#  'kill': 304,
#  'killed': 305,
#  'love': 306,
#  'connection': 307,
#  'between': 308,
#  'wasn': 309,
#  'necessary': 310,
#  'plot': 311,
#  'found': 312,
#  'stinks': 313,
#  'observant': 314,
#  'films': 315,
#  'prior': 316,
#  'shows': 317,
#  'tender': 318,
#  'side': 319,
#  'compared': 320,
#  'slapstick': 321,
#  'blazing': 322,
#  'saddles': 323,
#  'young': 324,
#  'frankenstein': 325,
#  'spaceballs': 326,
#  'show': 327,
#  'having': 328,
#  'something': 329,
#  'valuable': 330,
#  'day': 331,
#  'hand': 332,
#  'stupid': 333,
#  'don': 334,
#  'know': 335,
#  'money': 336,
#  'maybe': 337,
#  'give': 338,
#  'instead': 339,
#  'using': 340,
#  'monopoly': 341,
#  'this': 342,
#  'film': 343,
#  'will': 344,
#  'inspire': 345,
#  'others': 346,
#  'airport': 347,
#  'brand': 348,
#  'new': 349,
#  'luxury': 350,
#  'plane': 351,
#  'loaded': 352,
#  'paintings': 353,
#  'belonging': 354,
#  'businessman': 355,
#  'philip': 356,
#  'stevens': 357,
#  'james': 358,
#  'stewart': 359,
#  'flying': 360,
#  'them': 361,
#  'bunch': 362,
#  'vip': 363,
#  'estate': 364,
#  'preparation': 365,
#  'opened': 366,
#  'public': 367,
#  'museum': 368,
#  'also': 369,
#  'board': 370,
#  'daughter': 371,
#  'julie': 372,
#  'kathleen': 373,
#  'quinlan': 374,
#  'son': 375,
#  'jetliner': 376,
#  'takes': 377,
#  'planned': 378,
#  'mid': 379,
#  'air': 380,
#  'hi': 381,
#  'jacked': 382,
#  'co': 383,
#  'pilot': 384,
#  'chambers': 385,
#  'robert': 386,
#  'foxworth': 387,
#  'two': 388,
#  'accomplice': 389,
#  'banker': 390,
#  'monte': 391,
#  'markham': 392,
#  'michael': 393,
#  'pataki': 394,
#  'knock': 395,
#  'passengers': 396,
#  'crew': 397,
#  'sleeping': 398,
#  'gas': 399,
#  'steal': 400,
#  'cargo': 401,
#  'land': 402,
#  'disused': 403,
#  'strip': 404,
#  'isolated': 405,
#  'island': 406,
#  'descent': 407,
#  'almost': 408,
#  'hits': 409,
#  'oil': 410,
#  'rig': 411,
#  'ocean': 412,
#  'loses': 413,
#  'control': 414,
#  'sending': 415,
#  'crashing': 416,
#  'sea': 417,
#  'sinks': 418,
#  'bottom': 419,
#  'bang': 420,
#  'middle': 421,
#  'bermuda': 422,
#  'triangle': 423,
#  'short': 424,
#  'supply': 425,
#  'water': 426,
#  'leaking': 427,
#  'flown': 428,
#  'over': 429,
#  'miles': 430,
#  'course': 431,
#  'problems': 432,
#  'mount': 433,
#  'survivor': 434,
#  'await': 435,
#  'fast': 436,
#  'running': 437,
#  'known': 438,
#  'under': 439,
#  'slightly': 440,
#  'different': 441,
#  'tile': 442,
#  'second': 443,
#  'sequel': 444,
#  'smash': 445,
#  'hit': 446,
#  'disaster': 447,
#  'thriller': 448,
#  'was': 449,
#  'directed': 450,
#  'jerry': 451,
#  'jameson': 452,
#  'again': 453,
#  'predecessors': 454,
#  'say': 455,
#  'any': 456,
#  'sort': 457,
#  'forgotten': 458,
#  'entertaining': 459,
#  'although': 460,
#  'necessarily': 461,
#  'reasons': 462,
#  'three': 463,
#  'have': 464,
#  'so': 465,
#  'actually': 466,
#  'liked': 467,
#  'best': 468,
#  'favourite': 469,
#  'nice': 470,
#  'jacking': 471,
#  'then': 472,
#  'didn': 473,
#  'sinking': 474,
#  'makers': 475,
#  'trying': 476,
#  'cross': 477,
#  'original': 478,
#  'another': 479,
#  'popular': 480,
#  'flick': 481,
#  'period': 482,
#  'poseidon': 483,
#  'adventure': 484,
#  'submerged': 485,
#  'stark': 486,
#  'dilemma': 487,
#  'facing': 488,
#  'trapped': 489,
#  'inside': 490,
#  'either': 491,
#  'suffocate': 492,
#  'runs': 493,
#  'drown': 494,
#  'floods': 495,
#  'doors': 496,
#  'decent': 497,
#  'idea': 498,
#  'could': 499,
#  'made': 500,
#  'little': 501,
#  'bad': 502,
#  'unsympathetic': 503,
#  'character': 504,
#  'dull': 505,
#  'lethargic': 506,
#  'set': 507,
#  'pieces': 508,
#  'real': 509,
#  'lack': 510,
#  'danger': 511,
#  'suspense': 512,
#  'tension': 513,
#  'means': 514,
#  'missed': 515,
#  'opportunity': 516,
#  'rather': 517,
#  'sluggish': 518,
#  'keeps': 519,
#  'entertained': 520,
#  'odd': 521,
#  'minutes': 522,
#  'happens': 523,
#  'there': 524,
#  'urgency': 525,
#  'thought': 526,
#  'navy': 527,
#  'become': 528,
#  'involved': 529,
#  'pick': 530,
#  'few': 531,
#  'shots': 532,
#  'huge': 533,
#  'ships': 534,
#  'helicopters': 535,
#  'lacking': 536,
#  'kennedy': 537,
#  'jinxed': 538,
#  'airline': 539,
#  'worker': 540,
#  'joe': 541,
#  'patroni': 542,
#  'back': 543,
#  'only': 544,
#  'gets': 545,
#  'couple': 546,
#  'scenes': 547,
#  'barely': 548,
#  'says': 549,
#  'anything': 550,
#  'preferring': 551,
#  'look': 552,
#  'worried': 553,
#  'background': 554,
#  'video': 555,
#  'theatrical': 556,
#  'version': 557,
#  'run': 558,
#  'us': 559,
#  'tv': 560,
#  'versions': 561,
#  'add': 562,
#  'extra': 563,
#  'hour': 564,
#  'footage': 565,
#  'credits': 566,
#  'sequence': 567,
#  'flashbacks': 568,
#  'flesh': 569,
#  'longer': 570,
#  'rescue': 571,
#  'discovery': 572,
#  'dead': 573,
#  'bodies': 574,
#  'navigator': 575,
#  'am': 576,
#  'sure': 577,
#  'sit': 578,
#  'near': 579,
#  'cut': 580,
#  'expected': 581,
#  'dated': 582,
#  'badly': 583,
#  'horrible': 584,
#  'fashions': 585,
#  'interior': 586,
#  'design': 587,
#  'choices': 588,
#  'toy': 589,
#  'model': 590,
#  'effects': 591,
#  'aren': 592,
#  'along': 593,
#  'sequels': 594,
#  'pride': 595,
#  'place': 596,
#  'razzie': 597,
#  'award': 598,
#  'hall': 599,
#  'shame': 600,
#  'lots': 601,
#  'worse': 602,
#  'reckon': 603,
#  'harsh': 604,
#  'action': 605,
#  'pace': 606,
#  'slow': 607,
#  'excitement': 608,
#  'generated': 609,
#  'pretty': 610,
#  'properly': 611,
#  'production': 612,
#  'values': 613,
#  'alright': 614,
#  'nothing': 615,
#  'spectacular': 616,
#  'acting': 617,
#  'oscar': 618,
#  'winner': 619,
#  'jack': 620,
#  'lemmon': 621,
#  'said': 622,
#  'since': 623,
#  'mistake': 624,
#  'star': 625,
#  'looks': 626,
#  'old': 627,
#  'frail': 628,
#  'lee': 629,
#  'grant': 630,
#  'drunk': 631,
#  'sir': 632,
#  'christopher': 633,
#  'plenty': 634,
#  'familiar': 635,
#  'faces': 636,
#  'orientated': 637,
#  'ideas': 638,
#  'behind': 639,
#  'bit': 640,
#  'silly': 641,
#  'bland': 642,
#  'direction': 643,
#  'doesn': 644,
#  'though': 645,
#  'sunken': 646,
#  'shouldn': 647,
#  'boring': 648,
#  'followed': 649,
#  'concorde': 650,
#  'brilliant': 651,
#  'dramatic': 652,
#  'hobo': 653,
#  'lady': 654,
#  'ever': 655,
#  'clothes': 656,
#  'warehouse': 657,
#  'none': 658,
#  'corn': 659,
#  'face': 660,
#  'take': 661,
#  'lawyers': 662,
#  'superb': 663,
#  'accused': 664,
#  'turncoat': 665,
#  'selling': 666,
#  'boss': 667,
#  'dishonest': 668,
#  'lawyer': 669,
#  'shrugs': 670,
#  'indifferently': 671,
#  'funny': 672,
#  'words': 673,
#  'jeffrey': 674,
#  'favorite': 675,
#  'later': 676,
#  'larry': 677,
#  'sanders': 678,
#  'fantastic': 679,
#  'mad': 680,
#  'millionaire': 681,
#  'crush': 682,
#  'ghetto': 683,
#  'malevolent': 684,
#  'usual': 685,
#  'hospital': 686,
#  'invade': 687,
#  'demolition': 688,
#  'site': 689,
#  'classics': 690,
#  'legs': 691,
#  'big': 692,
#  'diggers': 693,
#  'fighting': 694,
#  'bleeds': 695,
#  'movie': 696,
#  'each': 697,
#  'quite': 698,
#  'often': 699,
#  'lacked': 700,
#  'couldn': 701,
#  'put': 702,
#  'finger': 703,
#  'first': 704,
#  'charisma': 705,
#  'part': 706,
#  'leading': 707,
#  'actress': 708,
#  'inevitably': 709,
#  'translated': 710,
#  'chemistry': 711,
#  'she': 712,
#  'shared': 713,
#  'screen': 714,
#  'romantic': 715,
#  'came': 716,
#  'across': 717,
#  'merely': 718,
#  'actors': 719,
#  'play': 720,
#  'very': 721,
#  'well': 722,
#  'director': 723,
#  'miscalculated': 724,
#  'needed': 725,
#  'screenplay': 726,
#  'exactly': 727,
#  'chef': 728,
#  'seemed': 729,
#  'enamored': 730,
#  'culinary': 731,
#  'skills': 732,
#  'restaurant': 733,
#  'ultimately': 734,
#  'himself': 735,
#  'youthful': 736,
#  'exploits': 737,
#  'anybody': 738,
#  'else': 739,
#  'convinced': 740,
#  'princess': 741,
#  'disappointed': 742,
#  'forget': 743,
#  'nominated': 744,
#  'judge': 745,
#  'yourself': 746,
#  'easily': 747,
#  'underrated': 748,
#  'inn': 749,
#  'cannon': 750,
#  'its': 751,
#  'flawed': 752,
#  'does': 753,
#  'realistic': 754,
#  'view': 755,
#  'unlike': 756,
#  'how': 757,
#  'citizen': 758,
#  'kane': 759,
#  'gave': 760,
#  'lounge': 761,
#  'titanic': 762,
#  'italians': 763,
#  'idiots': 764,
#  'jokes': 765,
#  'fall': 766,
#  'flat': 767,
#  'still': 768,
#  'lovable': 769,
#  'way': 770,
#  'comedies': 771,
#  'pull': 772,
#  'traditionally': 773,
#  'reviled': 774,
#  'members': 775,
#  'society': 776,
#  'truly': 777,
#  'impressive': 778,
#  'fisher': 779,
#  'king': 780,
#  'crap': 781,
#  'complaint': 782,
#  'cast': 783,
#  'someone': 784,
#  'writer': 785,
#  'sorry': 786,
#  'everyone': 787,
#  'supposed': 788,
#  'art': 789,
#  'wow': 790,
#  'handed': 791,
#  'guns': 792,
#  'screening': 793,
#  'blow': 794,
#  'brains': 795,
#  'watch': 796,
#  'photographic': 797,
#  'excellent': 798,
#  'painful': 799,
#  'absence': 800,
#  'sound': 801,
#  'track': 802,
#  'brutal': 803,
#  'loooonnnnng': 804,
#  'long': 805,
#  'sitting': 806,
#  'talking': 807,
#  'especially': 808,
#  'complaining': 809,
#  'really': 810,
#  'hard': 811,
#  'getting': 812,
#  'performances': 813,
#  'dark': 814,
#  'sombre': 815,
#  'uninspired': 816,
#  'stuff': 817,
#  'thing': 818,
#  'maureen': 819,
#  'stapleton': 820,
#  'red': 821,
#  'dress': 822,
#  'dancing': 823,
#  'otherwise': 824,
#  'ripoff': 825,
#  'bergman': 826,
#  'fan': 827,
#  'f': 828,
#  'anyone': 829,
#  'enjoyed': 830,
#  'hours': 831,
#  'lying': 832,
#  'typical': 833,
#  'less': 834,
#  'movies': 835,
#  'followable': 836,
#  'leslie': 837,
#  'rated': 838,
#  'moments': 839,
#  'fleshed': 840,
#  'probably': 841,
#  'room': 842,
#  'worth': 843,
#  'price': 844,
#  'rent': 845,
#  'overall': 846,
#  'job': 847,
#  'characteristic': 848,
#  'speaking': 849,
#  'directly': 850,
#  'actor': 851,
#  'fume': 852,
#  'both': 853,
#  'played': 854,
#  'parts': 855,
#  'parents': 856,
#  'took': 857,
#  'theater': 858,
#  'interiors': 859,
#  'watched': 860,
#  'we': 861,
#  'walked': 862,
#  'recently': 863,
#  'lived': 864,
#  'rest': 865,
#  'pretentious': 866,
#  'ponderous': 867,
#  'painfully': 868,
#  'piece': 869,
#  'wine': 870,
#  'cheese': 871,
#  'tripe': 872,
#  'woody': 873,
#  'allen': 874,
#  'directors': 875,
#  'worst': 876,
#  'career': 877,
#  'unmistakable': 878,
#  'style': 879,
#  'ingmar': 880,
#  'berman': 881,
#  'gives': 882,
#  'angular': 883,
#  'muted': 884,
#  'insight': 885,
#  'lives': 886,
#  'family': 887,
#  'wrought': 888,
#  'psychological': 889,
#  'damage': 890,
#  'caused': 891,
#  'estrangement': 892,
#  'non': 893,
#  'halitosis': 894,
#  'whatever': 895,
#  'intentionally': 896,
#  'comic': 897,
#  'relief': 898,
#  'music': 899,
#  'drenched': 900,
#  'shadowy': 901,
#  'pathos': 902,
#  'defined': 903,
#  'expressionist': 904,
#  'nature': 905,
#  'improvisational': 906,
#  'method': 907,
#  'illicit': 908,
#  'pronounced': 909,
#  'depth': 910,
#  'meaning': 911,
#  'truth': 912,
#  'beyond': 913,
#  'simply': 914,
#  'sympathy': 915,
#  'felt': 916,
#  'contempt': 917,
#  'parade': 918,
#  'shuffling': 919,
#  'whining': 920,
#  'nicotine': 921,
#  'stained': 922,
#  'martyrs': 923,
#  'perpetual': 924,
#  'quest': 925,
#  'identity': 926,
#  'amid': 927,
#  'backdrop': 928,
#  'cosmopolitan': 929,
#  'affluence': 930,
#  'baked': 931,
#  'brie': 932,
#  'intelligentsia': 933,
#  'looms': 934,
#  'fart': 935,
#  'speaks': 936,
#  'affected': 937,
#  'platitudes': 938,
#  'elevated': 939,
#  'language': 940,
#  'cigarettes': 941,
#  'struggling': 942,
#  'desperate': 943,
#  'find': 944,
#  'understanding': 945,
#  'goes': 946,
#  'point': 947,
#  'want': 948,
#  'slap': 949,
#  'resolution': 950,
#  'interminable': 951,
#  'introspective': 952,
#  'babble': 953,
#  'drama': 954,
#  'taken': 955,
#  'extreme': 956,
#  'ability': 957,
#  'connect': 958,
#  'chose': 959,
#  'immersed': 960,
#  'themselves': 961,
#  'feel': 962,
#  'left': 963,
#  'reason': 964,
#  'self': 965,
#  'indulgent': 966,
#  'spiritually': 967,
#  'draining': 968,
#  'insistence': 969,
#  'promoting': 970,
#  'message': 971,
#  'prozac': 972,
#  'prose': 973,
#  'distorted': 974,
#  'techniques': 975,
#  'jettisons': 976,
#  'past': 977,
#  'relevance': 978,
#  'highly': 979,
#  'recommend': 980,
#  'feeling': 981,
#  'happy': 982,
#  'need': 983,
#  'death': 984,
#  'let': 985,
#  'pretend': 986,
#  'happened': 987,
#  'comedic': 988,
#  'robin': 989,
#  'williams': 990,
#  'nor': 991,
#  'quirky': 992,
#  'recent': 993,
#  'fame': 994,
#  'hybrid': 995,
#  'dramatization': 996,
#  'mixed': 997,
#  'per': 998,
#  'se': 999,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    # TODO: count how many times each word is used in the given review and store the results in layer_0
    words = review.split(' ')
    for word in words:
        layer_0[0,word2index[word]]=total_counts[word]

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[1.60000e+01, 4.32200e+03, 2.14656e+05, ..., 0.00000e+00,
#         0.00000e+00, 3.27192e+05]])

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    if label == 'POSITIVE':
        return 1
    else:
        return 0

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Store the number of nodes in input, hidden, and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights
        
        # TODO: initialize self.weights_0_1 as a matrix of zeros. These are the weights between
        #       the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((input_nodes, hidden_nodes))
        
        # TODO: initialize self.weights_1_2 as a matrix of random values. 
        #       These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                        (self.hidden_nodes, self.output_nodes))
        
        # TODO: Create the input layer, a two-dimensional matrix with shape 
        #       1 x input_nodes, with all values initialized to zero
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):
        # TODO: You can copy most of the code you wrote for update_input_layer 
        #       earlier in this notebook. 
        #
        #       However, MAKE SURE YOU CHANGE ALL VARIABLES TO REFERENCE
        #       THE VERSIONS STORED IN THIS OBJECT, NOT THE GLOBAL OBJECTS.
        #       For example, replace "layer_0 *= 0" with "self.layer_0 *= 0"
        self.layer_0 *= 0
        for word in review.split(' '):
            if word in self.word2index:
                self.layer_0[0,self.word2index[word]]+=1
                
    def get_target_for_label(self,label):
        # TODO: Copy the code you wrote for get_target_for_label 
        #       earlier in this notebook. 
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        # TODO: Return the result of calculating the sigmoid activation function
        #       shown in the lectures
        return 1./(1.+np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        # TODO: Return the derivative of the sigmoid activation function, 
        #       where "output" is the original output from the sigmoid fucntion 
        return output*(1-output)

    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            # TODO: Get the next review and its correct label
            self.update_input_layer(training_reviews[i])
            label= self.get_target_for_label(training_labels[i])
            
            # TODO: Implement the forward pass through the network. 
            #       That means use the given review to update the input layer, 
            #       then calculate values for the hidden layer,
            #       and finally calculate the output layer.
            # 
            #       Do not use an activation function for the hidden layer,
            #       but use the sigmoid activation function for the output layer.
            hidden_input = np.dot(self.layer_0, self.weights_0_1)
            hidden_output = hidden_input
            output_input = np.dot(hidden_output, self.weights_1_2)
            output_output = self.sigmoid(output_input)
            
            # TODO: Implement the back propagation pass here. 
            #       That means calculate the error for the forward pass's prediction
            #       and update the weights in the network according to their
            #       contributions toward the error, as calculated via the
            #       gradient descent and back propagation algorithms you 
            #       learned in class.
            # output_error     = -(label*np.log(output_output) + (1-label)*np.log(1-output_output))
            output_error     = output_output-label
            output_erroritem = output_error*self.sigmoid_output_2_derivative(output_output)
            hidden_erroritem = np.dot(output_erroritem, self.weights_1_2.T)
            
            del_weight_1_2 = self.learning_rate*np.dot(hidden_output.T, output_erroritem)
            del_weight_0_1 = self.learning_rate*np.dot(self.layer_0.T,  hidden_erroritem)
            
            self.weights_1_2 = self.weights_1_2 - del_weight_1_2
            self.weights_0_1 = self.weights_0_1 - del_weight_0_1
            
            # TODO: Keep track of correct predictions. To determine if the prediction was
            #       correct, check that the absolute value of the output error 
            #       is less than 0.5. If so, add one to the correct_so_far count.
            if output_output >= 0.5 and label==1:
                correct_so_far += 1
            if output_output < 0.5 and label==0:
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # TODO: Run a forward pass through the network, like you did in the
        #       "train" function. That means use the given review to 
        #       update the input layer, then calculate values for the hidden layer,
        #       and finally calculate the output layer.
        #
        #       Note: The review passed into this function for prediction 
        #             might come from anywhere, so you should convert it 
        #             to lower case prior to using it.
        self.update_input_layer(review)
        hidden_input = np.dot(self.layer_0, self.weights_0_1)
        hidden_output = self.sigmoid(hidden_input)
        output_input = np.dot(hidden_output, self.weights_1_2)
        output_output = self.sigmoid(output_input)
        
        # TODO: The output layer should now contain a prediction. 
        #       Return `POSITIVE` for predictions greater-than-or-equal-to `0.5`, 
        #       and `NEGATIVE` otherwise.
        if output_output>=0.5:
            return 'POSITIVE'
        else:
            return 'NEGATIVE'

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:18.8% Speed(reviews/sec):913.0 #Correct:94 #Tested:189 Testing Accuracy:49.7%
# Progress:40.6% Speed(reviews/sec):998.4 #Correct:203 #Tested:407 Testing Accuracy:49.8%
# Progress:61.6% Speed(reviews/sec):1013. #Correct:308 #Tested:617 Testing Accuracy:49.9%
# Progress:82.5% Speed(reviews/sec):1020. #Correct:413 #Tested:826 Testing Accuracy:50.0%
# Progress:99.9% Speed(reviews/sec):1025. #Correct:500 #Tested:1000 Testing Accuracy:50.0%

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):374.2 #Correct:1273 #Trained:2501 Training Accuracy:50.8%
# Progress:20.8% Speed(reviews/sec):373.6 #Correct:2609 #Trained:5001 Training Accuracy:52.1%
# Progress:31.2% Speed(reviews/sec):362.3 #Correct:4047 #Trained:7501 Training Accuracy:53.9%
# Progress:41.6% Speed(reviews/sec):329.1 #Correct:5584 #Trained:10001 Training Accuracy:55.8%
# Progress:52.0% Speed(reviews/sec):328.1 #Correct:7177 #Trained:12501 Training Accuracy:57.4%
# Progress:62.5% Speed(reviews/sec):335.7 #Correct:8735 #Trained:15001 Training Accuracy:58.2%
# Progress:72.9% Speed(reviews/sec):338.7 #Correct:10330 #Trained:17501 Training Accuracy:59.0%
# Progress:83.3% Speed(reviews/sec):338.7 #Correct:12031 #Trained:20001 Training Accuracy:60.1%
# Progress:93.7% Speed(reviews/sec):336.0 #Correct:13710 #Trained:22501 Training Accuracy:60.9%
# Progress:99.9% Speed(reviews/sec):338.0 #Correct:14797 #Trained:24000 Training Accuracy:61.6%

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):382.0 #Correct:1251 #Trained:2501 Training Accuracy:50.0%
# Progress:20.8% Speed(reviews/sec):381.5 #Correct:2501 #Trained:5001 Training Accuracy:50.0%
# Progress:31.2% Speed(reviews/sec):381.6 #Correct:3751 #Trained:7501 Training Accuracy:50.0%
# Progress:41.6% Speed(reviews/sec):374.4 #Correct:5001 #Trained:10001 Training Accuracy:50.0%
# Progress:52.0% Speed(reviews/sec):376.2 #Correct:6251 #Trained:12501 Training Accuracy:50.0%
# Progress:62.5% Speed(reviews/sec):376.7 #Correct:7501 #Trained:15001 Training Accuracy:50.0%
# Progress:72.9% Speed(reviews/sec):376.6 #Correct:8751 #Trained:17501 Training Accuracy:50.0%
# Progress:83.3% Speed(reviews/sec):376.1 #Correct:10001 #Trained:20001 Training Accuracy:50.0%
# Progress:93.7% Speed(reviews/sec):374.6 #Correct:11251 #Trained:22501 Training Accuracy:50.0%
# Progress:99.9% Speed(reviews/sec):374.7 #Correct:12000 #Trained:24000 Training Accuracy:50.0%

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):383.1 #Correct:1251 #Trained:2501 Training Accuracy:50.0%
# Progress:20.8% Speed(reviews/sec):380.0 #Correct:2501 #Trained:5001 Training Accuracy:50.0%
# Progress:31.2% Speed(reviews/sec):357.5 #Correct:3751 #Trained:7501 Training Accuracy:50.0%
# Progress:41.6% Speed(reviews/sec):363.3 #Correct:5001 #Trained:10001 Training Accuracy:50.0%
# Progress:52.0% Speed(reviews/sec):362.2 #Correct:6251 #Trained:12501 Training Accuracy:50.0%
# Progress:62.5% Speed(reviews/sec):362.2 #Correct:7501 #Trained:15001 Training Accuracy:50.0%
# Progress:72.9% Speed(reviews/sec):368.1 #Correct:8751 #Trained:17501 Training Accuracy:50.0%
# Progress:83.3% Speed(reviews/sec):372.5 #Correct:10001 #Trained:20001 Training Accuracy:50.0%
# Progress:93.7% Speed(reviews/sec):375.9 #Correct:11251 #Trained:22501 Training Accuracy:50.0%
# Progress:99.9% Speed(reviews/sec):377.7 #Correct:12000 #Trained:24000 Training Accuracy:50.0%

# %% [markdown]
# With a learning rate of `0.001`, the network should finally have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
