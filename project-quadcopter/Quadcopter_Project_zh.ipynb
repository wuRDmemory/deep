# %% [markdown]
# # 项目：指导四轴飞行器学会飞行
#
# 设计一个能够使四轴飞行器飞行的智能体，然后使用你选择的强化学习算法训练它！
#
# 请尝试运用你在这一单元中学到的知识，看看哪个方法效果最好，当然你也可以自己想出创新型方法并测试它们。
# ## 说明
#
# 请查看目录下的文件，以更好地了解项目结构。
#
# - `task.py`：在本文件中定义你的任务（环境）。
# - `agents/`：本文件夹中包含强化学习智能体。
#     - `policy_search.py`：我们为你提供了一个智能体模板。
#     - `agent.py`：在本文件中开发你的智能体。
# - `physics_sim.py`：本文件中包含四轴飞行器模拟器。**请勿修改本文件**。
#
# 在本项目中，你需要在 `task.py` 中定义你的任务。尽管我们为你提供了一个任务示例，来帮助你开始项目，但你也可以随意更改这个文件。在这个 notebook 中，你还将学习更多有关修改这个文件的知识。
#
# 你还需要在 `agent.py` 中设计一个强化学习智能体，来完成你选择的任务。
#
# 我们也鼓励你创建其他文件，来帮助你整理代码。比如，你也许可以通过定义一个 `model.py` 文件来定义其他你需要的神经网络结构。
#
# ## 控制四轴飞行器
#
# 在下方的代码中，我们提供了一个智能体示例，来示范如何使用模拟器来控制四轴飞行器。这个智能体比你在 notebook 中需要测试的智能体（在 `agents/policy_search.py` 中）更加简单！
#
# 这个智能体通过设置飞行器四个轴上的转速来控制飞行器。`Basic_Agent` 类中提供的智能体将会随机为四个轴指定动作。这四个速度将通过 `act` 方法以四个浮点数列表的形式返回。
#
# 在本项目中，你将在 `agents/agent.py` 中实现的智能体会以更加智能的方法进行指定的动作。

# %% [markdown]
# ### plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_run(results, standalone=True):
    if standalone:
        plt.subplots(figsize=(15, 15))
    
    #查看四轴飞行器的位置变化
    plt.subplot(3, 3, 1)
    plt.title('Position')
    plt.plot(results['time'], results['x'], label='x')
    plt.plot(results['time'], results['y'], label='y')
    plt.plot(results['time'], results['z'], label='z')
    plt.xlabel('time, seconds')
    plt.ylabel('Position')
    plt.grid(True)
    if standalone:
        plt.legend()

    #四轴飞行器的速度
    plt.subplot(3, 3, 2)
    plt.title('Velocity')
    plt.plot(results['time'], results['x_velocity'], label='x_hat')
    plt.plot(results['time'], results['y_velocity'], label='y_hat')
    plt.plot(results['time'], results['z_velocity'], label='z_hat')
    plt.xlabel('time, seconds')
    plt.ylabel('Velocity')
    plt.grid(True)
    if standalone:
        plt.legend()
    
    #绘制欧拉角 (Euler angles)（四轴飞行器围绕 x，y 和 z 轴的旋转）的图表
    plt.subplot(3, 3, 3)
    plt.title('Orientation')
    plt.plot(results['time'], results['phi'], label='phi')
    plt.plot(results['time'], results['theta'], label='theta')
    plt.plot(results['time'], results['psi'], label='psi')
    plt.xlabel('time, seconds')
    plt.grid(True)
    if standalone:
        plt.legend()
    
    #绘制每个欧拉角的速度（每秒的弧度）图
    plt.subplot(3, 3, 4)
    plt.title('Angular Velocity')
    plt.plot(results['time'], results['phi_velocity'], label='phi')
    plt.plot(results['time'], results['theta_velocity'], label='theta')
    plt.plot(results['time'], results['psi_velocity'], label='psi')
    plt.xlabel('time, seconds')
    plt.grid(True)
    if standalone:
        plt.legend()

    #最后，你可以使用下方代码来输出智能体选择的动作。
    plt.subplot(3, 3, 5)
    plt.title('Rotor Speed')
    plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1')
    plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2')
    plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3')
    plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4')
    plt.xlabel('time, seconds')
    plt.ylabel('Rotor Speed, revolutions / second')
    plt.grid(True)
    if standalone:
        plt.legend()

    if standalone:
        plt.tight_layout()
        plt.show()

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D


def plot_point3d(ax, x, y, z, **kwargs):
    ax.scatter([x], [y], [z], **kwargs)
    ax.text(x, y, z, "({:.1f}, {:.1f}, {:.1f})".format(x, y, z))


def show_flight_path(results, target=None):
    results = np.array(results)
    
    fig = plt.figure(figsize=(10,10))
    ax = fig.gca(projection='3d')
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Z-axis')

    ax.plot3D(results[:, 0], results[:, 1], results[:, 2], 'gray')
    
    if target is not None:
        plot_point3d(ax, *target[0:3], c='y', marker='x', s=100, label='target')
        
    plot_point3d(ax, *results[0, 0:3], c='g', marker='o', s=50, label='start')
    plot_point3d(ax, *results[-1, 0:3], c='r', marker='o', s=50, label='end')
    
    ax.legend()

# %% [markdown]
# ### random Agent

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# 运行下方代码，让智能体指定动作来控制四轴飞行器。
#
# 请随意更改我们提供的 `runtime`，`init_pose`，`init_velocities` 和 `init_angle_velocities` 值来更改四轴飞行器的初始条件。
#
# 下方的 `labels` 列表为模拟数据的注释。所有的信息都储存在 `data.txt` 文档中，并保存在 `results` 目录下。

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %%
plot_run(results)

# %%
path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=None)

# %% [markdown]
# 在指定任务之前，你需要在模拟器中衍生环境状态。运行下方代码来在模拟结束时输出以下变量值：
#
# - `task.sim.pose`：四周飞行器在 ($x,y,z$) 坐标系中的位置和欧拉角。
# - `task.sim.v`：四轴飞行器在 ($x,y,z$) 坐标系中的速度。
# - `task.sim.angular_v`：三个欧拉角的弧度/每秒。

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [15.24552794  3.53106014 29.32040361  0.15679701  5.90828451  0.        ]
# [9.06068806 2.7157625  4.19548971]
# [ 0.09612157 -0.00523393  0.        ]

# %% [markdown]
# 在 `task.py` 中的任务示例中，我们使用了四轴飞行器六个维度的动作来构建每个时间步的环境状态。然而，你也可以按照自己的意愿更改任务，你可以添加速度信息来扩大状态向量，也可以使用任何动作、速度和角速度的组合，并构造适用于你的任务的环境状态。
#
# ## 任务
#
# 在 `task.py` 中，我们为你提供了一个任务示例。请在新窗口中打开这个文件。
#
# 使用 `__init__()` 方法来初始化指定本任务所需的几个变量。
#
# - 模拟器作为 `PhysicsSim` 类（来自 `physics_sim.py` 文件）的示例进行初始化。
# - 受到 DDPG 论文中研究方法的启发，我们使用了重复调用动作的方法。对于智能体的每一个时间步，我们将利用 `action_repeats` 时间步来进行模拟。如果你并不熟悉这种方法，可以阅读 [DDPG 论文](https://arxiv.org/abs/1509.02971)的结论部分。
# - 我们设置了状态向量中每个分量的数值。在任务示例中，我们只设置了六个维度的动作信息。为了设定向量大小（`state_size`），我们必须考虑重复的动作。
# - 任务环境通常是一个四维动作空间，每个轴有一个输入（`action_size=4`）。你可以设置每个输入的最小值（`action_low`）和最大值（`action_high`）。
# - 我们在文件中提供的任务示例将使智能体达到目标位置。我们将目标位置设置为一个变量。
#
# `reset()` 方法将重置模拟器。每当阶段结束时，智能体都将调用此方法。你可以查看下方代码中的例子。
#
# `step()` 方法是最重要的一个方法。它将接收智能体选择的动作 `rotor_speeds`，并准备好下一个状态，同时返回给智能体。接着，你将通过 `get_reward()` 计算奖励值。当超过规定时间，或是四轴飞行器到达模拟器边缘时，这一阶段将视作结束。
#
# 接下来，你将学习如何测试这个任务中智能体的性能。
#
# ## 智能体
#
# `agents/policy_search.py` 文件中提供的智能体示例使用了非常简单的线性策略，将动作向量视作状态向量和矩阵权重的点积直接进行计算。接着，它通过添加一些高斯噪声来随机干扰参数，以产生不同的策略。根据每个阶段获得的平均奖励值（`score`），它将记录迄今为止发现的最佳参数集以及分数的变化状态，并据此调整比例因子来扩大或减少噪音。
#
# 请运行下方代码来查看任务示例中智能体的性能。

# %%
import sys
import pandas as p

# %%
from agents.policy_search import PolicySearch_Agent
from task import Task

labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

num_episodes = 1
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        # 状态->动作
        action = agent.act(state) 
        # 执行动作，得到下一时刻的状态和奖励
        next_state, reward, done = task.step(action)
        if i_episode == num_episodes:
            to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
            for ii in range(len(labels)):
                results[labels[ii]].append(to_write[ii])
        # 更新
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode =    1, score =  -2.104 (best =  -2.104), noise_scale = 0.05

# %%
plot_run(results)

path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=target_pos)

# %% [markdown]
# 这个智能体的性能想必十分糟糕！现在轮到你出场了！
#
# ## 定义任务，设计并训练你的智能体！
#
# 修改 `task.py` 文件来指定你所选择的任务。如果你不确定选择什么任务，你可以教你的四轴飞行器起飞、盘旋、着陆或是达到指定位置。
#
#
# 在指定任务后，使用 `agents/policy_search.py` 中的智能体示例作为模板，来在 `agents/agent.py` 中定义你自己的智能体。你可以随意从智能体示例中借用你需要的元素，包括如何模块化你的代码（使用 `act()`，`learn()` 和 `reset_episode_vars()` 等辅助方法）。
#
# 请注意，你指定的第一个智能体和任务**极有可能**无法顺利进行学习。你将需要改进不同的超参数和奖励函数，直到你能够获得不错的结果。
#
# 在开发智能体的时候，你还需要关注它的性能。参考下方代码，建立一个机制来存储每个阶段的总奖励值。如果阶段奖励值在逐渐上升，说明你的智能体正在学习。

# %%
import numpy as np
import random
from collections import namedtuple, deque
from physics_sim import PhysicsSim
from agents.agent import UserAgent

# %%
## TODO: Train your agent here.
from agents.policy_search import PolicySearch_Agent
from task import UserTask

labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

num_episodes = 500
target_pos = np.array([0., 0., 100.0])
init_pos = np.array([0., 0., 10., 0, 0, 0])
task = UserTask(init_pose=init_pos, runtime=10, target_pos=target_pos)
agent = UserAgent(task) 
reward_record = []

print(">>> start training")
for i_episode in range(1, num_episodes+1):
    # 这里面包含task和sim的reset
    state = agent.reset_episode() # start a new episode
    while True:
        # 状态->动作
        action = agent.act(state) 
        # 执行动作，得到下一时刻的状态和奖励
        next_state, reward, done = task.step(action)
        if i_episode == num_episodes:
            to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
            for ii in range(len(labels)):
                results[labels[ii]].append(to_write[ii])
        # 更新
        agent.step(action, reward, next_state, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, pose {:7.3f}, vel {:7.3f}, score = {:7.3f} (best = {:7.3f})".format(
                i_episode, task.sim.pose[2], task.sim.v[2], agent.score, agent.best_score))  # [debug]
            break
        sys.stdout.flush()
    reward_record.append(agent.score)
# Out:
# >>> agent param
# >>> gamma 0.99 tau 0.001
# >>> theta 0.15 sigma 0.25
# >>> start training
# Episode =    1, pose   0.000, vel -12.264, score = 111.806 (best = 111.806)
# Episode =    2, pose   0.000, vel -14.677, score = 121.254 (best = 121.254)
# Episode =    3, pose   0.000, vel -15.630, score =  75.957 (best = 121.254)
# Episode =    4, pose   0.000, vel -13.453, score =  73.732 (best = 121.254)
# Episode =    5, pose   0.000, vel -11.441, score =  92.614 (best = 121.254)
# Episode =    6, pose   0.000, vel -15.349, score =  73.688 (best = 121.254)
# Episode =    7, pose   0.000, vel -14.857, score =  73.700 (best = 121.254)
# Episode =    8, pose   0.000, vel -14.344, score =  61.689 (best = 121.254)
# Episode =    9, pose   0.000, vel -14.011, score =  83.841 (best = 121.254)
# Episode =   10, pose   0.000, vel -14.435, score =  61.665 (best = 121.254)
# Episode =   11, pose   0.000, vel -14.105, score =  61.653 (best = 121.254)
# Episode =   12, pose   0.000, vel -13.733, score =  61.670 (best = 121.254)
# Episode =   13, pose   0.000, vel -13.822, score =  61.723 (best = 121.254)
# Episode =   14, pose   0.000, vel -14.111, score =  61.709 (best = 121.254)
# Episode =   15, pose   0.000, vel -13.868, score =  63.776 (best = 121.254)
# Episode =   16, pose   0.000, vel -13.971, score =  73.764 (best = 121.254)
# Episode =   17, pose   0.000, vel -14.745, score =  61.700 (best = 121.254)
# Episode =   18, pose   0.000, vel -14.315, score =  71.710 (best = 121.254)
# Episode =   19, pose   0.000, vel -15.326, score =  83.854 (best = 121.254)
# Episode =   20, pose   0.000, vel -14.269, score =  79.571 (best = 121.254)
# Episode =   21, pose   0.000, vel -14.882, score =  81.723 (best = 121.254)
# Episode =   22, pose   0.000, vel -15.686, score =  81.716 (best = 121.254)
# Episode =   23, pose   0.000, vel -14.484, score =  73.861 (best = 121.254)
# Episode =   24, pose   0.000, vel -14.155, score =  71.711 (best = 121.254)
# Episode =   25, pose   0.000, vel -14.527, score =  73.850 (best = 121.254)
# Episode =   26, pose   0.000, vel -13.858, score =  76.049 (best = 121.254)
# Episode =   27, pose   0.000, vel -13.995, score =  66.103 (best = 121.254)
# Episode =   28, pose   0.000, vel -14.560, score =  66.073 (best = 121.254)
# Episode =   29, pose   0.000, vel -13.869, score =  63.963 (best = 121.254)
# Episode =   30, pose   0.000, vel -14.439, score =  71.703 (best = 121.254)
# Episode =   31, pose   0.000, vel -14.103, score =  61.732 (best = 121.254)
# Episode =   32, pose   0.000, vel -14.326, score =  73.848 (best = 121.254)
# Episode =   33, pose   0.000, vel -13.828, score =  83.779 (best = 121.254)
# Episode =   34, pose   0.000, vel -14.416, score =  83.788 (best = 121.254)
# Episode =   35, pose   0.000, vel -14.510, score =  83.816 (best = 121.254)
# Episode =   36, pose   0.000, vel -14.138, score =  63.830 (best = 121.254)
# Episode =   37, pose   0.000, vel -14.459, score =  73.828 (best = 121.254)
# Episode =   38, pose   0.000, vel -14.043, score =  73.825 (best = 121.254)
# Episode =   39, pose   0.000, vel -13.963, score =  63.840 (best = 121.254)
# Episode =   40, pose   0.000, vel -13.894, score =  63.863 (best = 121.254)
# Episode =   41, pose   0.000, vel -13.733, score =  63.884 (best = 121.254)
# Episode =   42, pose   0.000, vel -14.499, score =  63.868 (best = 121.254)
# Episode =   43, pose   0.000, vel -14.034, score =  75.989 (best = 121.254)
# Episode =   44, pose   0.000, vel -14.918, score =  85.988 (best = 121.254)
# Episode =   45, pose   0.000, vel -14.743, score =  85.996 (best = 121.254)
# Episode =   46, pose   0.000, vel -14.087, score =  66.046 (best = 121.254)
# Episode =   47, pose   0.000, vel -13.632, score =  66.061 (best = 121.254)
# Episode =   48, pose   0.000, vel -14.478, score =  88.053 (best = 121.254)
# Episode =   49, pose   0.000, vel -13.978, score =  78.166 (best = 121.254)
# Episode =   50, pose   0.000, vel -14.594, score =  66.088 (best = 121.254)
# Episode =   51, pose   0.000, vel -14.520, score =  66.110 (best = 121.254)
# Episode =   52, pose   0.000, vel -13.277, score =  68.246 (best = 121.254)
# Episode =   53, pose   0.000, vel -14.401, score =  90.276 (best = 121.254)
# Episode =   54, pose   0.000, vel -14.361, score =  78.241 (best = 121.254)
# Episode =   55, pose   0.000, vel -13.494, score =  90.211 (best = 121.254)
# Episode =   56, pose   0.000, vel -13.672, score =  75.936 (best = 121.254)
# Episode =   57, pose   0.000, vel -13.354, score =  85.893 (best = 121.254)
# Episode =   58, pose   0.000, vel -13.882, score =  85.967 (best = 121.254)
# Episode =   59, pose   0.000, vel -14.067, score =  66.007 (best = 121.254)
# Episode =   60, pose   0.000, vel -13.536, score =  78.184 (best = 121.254)
# Episode =   61, pose   0.000, vel -13.032, score =  91.985 (best = 121.254)
# Episode =   62, pose   0.000, vel -14.646, score =  89.742 (best = 121.254)
# Episode =   63, pose   0.000, vel -15.048, score =  67.699 (best = 121.254)
# Episode =   64, pose   0.000, vel -14.079, score =  87.706 (best = 121.254)
# Episode =   65, pose   0.000, vel -15.608, score =  65.713 (best = 121.254)
# Episode =   66, pose   0.000, vel -15.777, score =  65.722 (best = 121.254)
# Episode =   67, pose   0.000, vel -15.144, score =  65.713 (best = 121.254)
# Episode =   68, pose   0.000, vel -15.057, score =  85.695 (best = 121.254)
# Episode =   69, pose   0.000, vel -15.042, score =  85.653 (best = 121.254)
# Episode =   70, pose   0.000, vel -14.342, score =  63.591 (best = 121.254)
# Episode =   71, pose   0.000, vel -14.096, score =  61.560 (best = 121.254)
# Episode =   72, pose   0.000, vel -14.449, score =  83.603 (best = 121.254)
# Episode =   73, pose   0.000, vel -13.839, score =  71.521 (best = 121.254)
# Episode =   74, pose   0.000, vel -15.443, score =  81.517 (best = 121.254)
# Episode =   75, pose   0.000, vel -15.026, score =  81.474 (best = 121.254)
# Episode =   76, pose   0.000, vel -15.408, score =  71.588 (best = 121.254)
# Episode =   77, pose   0.000, vel -15.476, score =  71.618 (best = 121.254)
# Episode =   78, pose   0.000, vel -13.738, score =  61.629 (best = 121.254)
# Episode =   79, pose   0.000, vel -14.481, score =  71.672 (best = 121.254)
# Episode =   80, pose   0.000, vel -14.510, score =  81.677 (best = 121.254)
# Episode =   81, pose   0.000, vel -14.855, score =  57.383 (best = 121.254)
# Episode =   82, pose   0.000, vel -15.327, score =  79.449 (best = 121.254)
# Episode =   83, pose   0.000, vel -14.731, score =  67.246 (best = 121.254)
# Episode =   84, pose   0.000, vel -15.673, score =  57.155 (best = 121.254)
# Episode =   85, pose   0.000, vel -15.434, score =  57.112 (best = 121.254)
# Episode =   86, pose   0.000, vel -14.084, score =  81.272 (best = 121.254)
# Episode =   87, pose   0.000, vel -14.399, score =  73.429 (best = 121.254)
# Episode =   88, pose   0.000, vel -15.044, score =  65.591 (best = 121.254)
# Episode =   89, pose   0.000, vel -14.795, score =  89.871 (best = 121.254)
# Episode =   90, pose   0.000, vel -14.497, score =  82.512 (best = 121.254)
# Episode =   91, pose   0.000, vel -12.818, score =  78.153 (best = 121.254)
# Episode =   92, pose   0.000, vel -15.575, score =  65.093 (best = 121.254)
# Episode =   93, pose   0.000, vel -11.983, score =  83.675 (best = 121.254)
# Episode =   94, pose   0.000, vel -15.691, score =  83.743 (best = 121.254)
# Episode =   95, pose   0.000, vel -13.538, score =  83.833 (best = 121.254)
# Episode =   96, pose   0.000, vel -14.138, score =  61.780 (best = 121.254)
# Episode =   97, pose   0.000, vel -15.007, score =  79.519 (best = 121.254)
# Episode =   98, pose   0.000, vel -14.207, score =  69.489 (best = 121.254)
# Episode =   99, pose   0.000, vel -14.558, score =  69.577 (best = 121.254)
# Episode =  100, pose   0.000, vel -14.661, score =  71.676 (best = 121.254)
# Episode =  101, pose   0.000, vel -13.961, score =  71.622 (best = 121.254)
# Episode =  102, pose   0.000, vel -13.874, score =  61.640 (best = 121.254)
# Episode =  103, pose   0.000, vel -15.660, score =  83.767 (best = 121.254)
# Episode =  104, pose   0.000, vel -14.009, score =  63.856 (best = 121.254)
# Episode =  105, pose   0.000, vel -13.225, score =  85.941 (best = 121.254)
# Episode =  106, pose   0.000, vel -13.819, score =  63.849 (best = 121.254)
# Episode =  107, pose   0.000, vel -15.266, score =  73.812 (best = 121.254)
# Episode =  108, pose   0.000, vel -13.929, score =  78.218 (best = 121.254)
# Episode =  109, pose   0.000, vel -14.354, score =  88.248 (best = 121.254)
# Episode =  110, pose   0.000, vel -14.405, score =  73.934 (best = 121.254)
# Episode =  111, pose   0.000, vel -13.418, score =  88.199 (best = 121.254)
# Episode =  112, pose   0.000, vel -12.982, score =  92.519 (best = 121.254)
# Episode =  113, pose   0.000, vel -13.635, score =  71.640 (best = 121.254)
# Episode =  114, pose   0.000, vel -13.296, score =  63.887 (best = 121.254)
# Episode =  115, pose   0.000, vel -14.914, score =  59.520 (best = 121.254)
# Episode =  116, pose   0.000, vel -14.914, score =  81.724 (best = 121.254)
# Episode =  117, pose   0.000, vel -15.279, score =  73.889 (best = 121.254)
# Episode =  118, pose   0.000, vel -13.759, score =  65.920 (best = 121.254)
# Episode =  119, pose   0.000, vel -14.042, score =  94.267 (best = 121.254)
# Episode =  120, pose   0.000, vel -12.773, score =  61.265 (best = 121.254)
# Episode =  121, pose   0.000, vel -14.842, score =  57.306 (best = 121.254)
# Episode =  122, pose   0.000, vel -14.201, score =  54.976 (best = 121.254)
# Episode =  123, pose   0.000, vel -13.713, score =  85.862 (best = 121.254)
# Episode =  124, pose   0.000, vel -14.862, score =  59.378 (best = 121.254)
# Episode =  125, pose   0.000, vel -14.264, score =  85.623 (best = 121.254)
# Episode =  126, pose   0.000, vel -15.696, score =  81.617 (best = 121.254)
# Episode =  127, pose   0.000, vel -11.875, score =  85.480 (best = 121.254)
# Episode =  128, pose   0.000, vel -16.064, score =  73.562 (best = 121.254)
# Episode =  129, pose   0.000, vel -16.681, score =  76.940 (best = 121.254)
# Episode =  130, pose   0.000, vel -15.981, score =  77.163 (best = 121.254)
# Episode =  131, pose   0.000, vel -12.356, score =  85.740 (best = 121.254)
# Episode =  132, pose   0.000, vel -14.571, score =  63.817 (best = 121.254)
# Episode =  133, pose   0.000, vel -14.087, score =  57.210 (best = 121.254)
# Episode =  134, pose   0.000, vel -12.976, score =  61.563 (best = 121.254)
# Episode =  135, pose   0.000, vel -12.755, score =  70.091 (best = 121.254)
# Episode =  136, pose   0.000, vel -16.373, score =  77.357 (best = 121.254)
# Episode =  137, pose   0.000, vel -13.095, score =  80.172 (best = 121.254)
# Episode =  138, pose   0.000, vel -13.430, score =  77.855 (best = 121.254)
# Episode =  139, pose   0.000, vel -13.446, score =  78.008 (best = 121.254)
# Episode =  140, pose   0.000, vel -14.469, score =  85.623 (best = 121.254)
# Episode =  141, pose   0.000, vel -13.746, score =  61.279 (best = 121.254)
# Episode =  142, pose   0.000, vel -17.497, score =  66.965 (best = 121.254)
# Episode =  143, pose   0.000, vel -13.860, score =  71.843 (best = 121.254)
# Episode =  144, pose   0.000, vel -12.512, score = 117.942 (best = 121.254)
# Episode =  145, pose   0.000, vel -15.849, score =  92.433 (best = 121.254)
# Episode =  146, pose   0.000, vel -17.762, score = 124.184 (best = 124.184)
# Episode =  147, pose   0.000, vel -15.012, score =  71.608 (best = 124.184)
# Episode =  148, pose   0.000, vel -16.990, score = 114.891 (best = 124.184)
# Episode =  149, pose   0.000, vel -16.653, score = 106.956 (best = 124.184)
# Episode =  150, pose   0.000, vel -14.424, score =  65.301 (best = 124.184)
# Episode =  151, pose   0.000, vel -16.858, score =  66.880 (best = 124.184)
# Episode =  152, pose   0.000, vel -14.984, score =  71.146 (best = 124.184)
# Episode =  153, pose   0.000, vel -14.818, score =  71.475 (best = 124.184)
# Episode =  154, pose   0.000, vel -14.402, score =  71.336 (best = 124.184)
# Episode =  155, pose   0.000, vel -14.981, score =  83.273 (best = 124.184)
# Episode =  156, pose   0.000, vel -12.905, score =  59.269 (best = 124.184)
# Episode =  157, pose   0.000, vel -12.333, score =  57.022 (best = 124.184)
# Episode =  158, pose   0.000, vel -15.406, score =  77.109 (best = 124.184)
# Episode =  159, pose   0.000, vel -14.669, score =  77.248 (best = 124.184)
# Episode =  160, pose   0.000, vel -17.073, score =  81.248 (best = 124.184)
# Episode =  161, pose   0.000, vel -15.780, score =  79.259 (best = 124.184)
# Episode =  162, pose   0.000, vel -16.934, score =  67.069 (best = 124.184)
# Episode =  163, pose   0.000, vel -15.458, score =  56.840 (best = 124.184)
# Episode =  164, pose   0.000, vel -16.971, score =  54.852 (best = 124.184)
# Episode =  165, pose   0.000, vel -13.194, score =  88.112 (best = 124.184)
# Episode =  166, pose   0.000, vel -14.849, score =  71.453 (best = 124.184)
# Episode =  167, pose   0.000, vel -17.648, score =  79.044 (best = 124.184)
# Episode =  168, pose   0.000, vel -13.335, score =  85.050 (best = 124.184)
# Episode =  169, pose   0.000, vel -15.424, score =  64.458 (best = 124.184)
# Episode =  170, pose   0.000, vel -14.454, score = 108.860 (best = 124.184)
# Episode =  171, pose   0.000, vel -16.135, score = 107.312 (best = 124.184)
# Episode =  172, pose   0.000, vel -20.627, score = 124.182 (best = 124.184)
# Episode =  173, pose   0.000, vel -16.129, score =  77.325 (best = 124.184)
# Episode =  174, pose   0.000, vel -23.630, score = 241.123 (best = 241.123)
# Episode =  175, pose   0.000, vel -13.832, score =  98.657 (best = 241.123)
# Episode =  176, pose   0.000, vel -16.285, score = 100.767 (best = 241.123)
# Episode =  177, pose   0.000, vel -12.119, score = 131.848 (best = 241.123)
# Episode =  178, pose   0.000, vel -18.711, score =  77.115 (best = 241.123)
# Episode =  179, pose   0.000, vel -21.652, score = 108.072 (best = 241.123)
# Episode =  180, pose   0.000, vel -16.149, score = 148.848 (best = 241.123)
# Episode =  181, pose   0.000, vel  -9.826, score = 132.987 (best = 241.123)
# Episode =  182, pose   0.000, vel -17.601, score =  92.914 (best = 241.123)
# Episode =  183, pose   0.000, vel -17.061, score = 103.406 (best = 241.123)
# Episode =  184, pose   0.000, vel -16.506, score =  81.613 (best = 241.123)
# Episode =  185, pose   0.000, vel -15.790, score =  88.682 (best = 241.123)
# Episode =  186, pose   0.000, vel -13.537, score =  60.742 (best = 241.123)
# Episode =  187, pose   0.000, vel -14.957, score =  68.507 (best = 241.123)
# Episode =  188, pose   0.000, vel -14.156, score =  78.201 (best = 241.123)
# Episode =  189, pose   0.000, vel -12.859, score =  55.012 (best = 241.123)
# Episode =  190, pose   0.000, vel -17.406, score =  74.559 (best = 241.123)
# Episode =  191, pose   0.000, vel -16.239, score =  64.544 (best = 241.123)
# Episode =  192, pose   0.000, vel -14.644, score =  81.347 (best = 241.123)
# Episode =  193, pose   0.000, vel -16.393, score =  65.026 (best = 241.123)
# Episode =  194, pose   0.000, vel -19.146, score =  75.214 (best = 241.123)
# Episode =  195, pose   0.000, vel -16.299, score =  65.119 (best = 241.123)
# Episode =  196, pose   0.000, vel -15.591, score =  65.215 (best = 241.123)
# Episode =  197, pose   0.000, vel -13.186, score =  98.892 (best = 241.123)
# Episode =  198, pose   0.000, vel -14.959, score =  67.631 (best = 241.123)
# Episode =  199, pose   0.000, vel  -9.813, score = 102.893 (best = 241.123)
# Episode =  200, pose   0.000, vel -14.463, score =  75.348 (best = 241.123)
# Episode =  201, pose   0.000, vel -16.045, score =  79.099 (best = 241.123)
# Episode =  202, pose   0.000, vel -12.641, score =  79.755 (best = 241.123)
# Episode =  203, pose   0.000, vel -10.686, score =  72.081 (best = 241.123)
# Episode =  204, pose   0.000, vel  -8.952, score =  76.157 (best = 241.123)
# Episode =  205, pose   0.000, vel -15.122, score =  71.305 (best = 241.123)
# Episode =  206, pose   0.000, vel -12.707, score =  81.325 (best = 241.123)
# Episode =  207, pose   0.000, vel -15.913, score =  61.286 (best = 241.123)
# Episode =  208, pose   0.000, vel -16.388, score =  56.651 (best = 241.123)
# Episode =  209, pose   0.000, vel -16.557, score =  80.739 (best = 241.123)
# Episode =  210, pose   0.000, vel -15.483, score =  72.652 (best = 241.123)
# Episode =  211, pose   0.000, vel -13.396, score =  88.310 (best = 241.123)
# Episode =  212, pose   0.000, vel -17.249, score =  66.758 (best = 241.123)
# Episode =  213, pose   0.000, vel -14.506, score =  58.730 (best = 241.123)
# Episode =  214, pose   0.000, vel -14.543, score =  98.960 (best = 241.123)
# Episode =  215, pose   0.000, vel -13.172, score =  93.451 (best = 241.123)
# Episode =  216, pose   0.000, vel -16.573, score =  97.695 (best = 241.123)
# Episode =  217, pose   0.000, vel -13.700, score =  85.772 (best = 241.123)
# Episode =  218, pose   0.000, vel -17.723, score =  63.224 (best = 241.123)
# Episode =  219, pose   0.000, vel -16.374, score =  75.770 (best = 241.123)
# Episode =  220, pose   0.000, vel -12.913, score =  80.799 (best = 241.123)
# Episode =  221, pose   0.000, vel -16.869, score = 129.640 (best = 241.123)
# Episode =  222, pose   0.000, vel -20.336, score = 141.389 (best = 241.123)
# Episode =  223, pose   0.000, vel -16.405, score = 136.705 (best = 241.123)
# Episode =  224, pose   0.000, vel  -8.975, score =  92.357 (best = 241.123)
# Episode =  225, pose   0.000, vel -16.741, score =  52.971 (best = 241.123)
# Episode =  226, pose   0.000, vel -12.050, score =  85.338 (best = 241.123)
# Episode =  227, pose   0.000, vel -17.137, score =  79.417 (best = 241.123)
# Episode =  228, pose   0.000, vel  -8.511, score =  73.477 (best = 241.123)
# Episode =  229, pose   0.000, vel -17.134, score =  75.354 (best = 241.123)
# Episode =  230, pose   0.000, vel -17.350, score =  72.904 (best = 241.123)
# Episode =  231, pose   0.000, vel -13.423, score =  93.546 (best = 241.123)
# Episode =  232, pose   0.000, vel -13.564, score =  79.868 (best = 241.123)
# Episode =  233, pose   0.000, vel -15.459, score =  91.976 (best = 241.123)
# Episode =  234, pose   0.000, vel -16.193, score =  68.663 (best = 241.123)
# Episode =  235, pose   0.000, vel -14.353, score =  70.636 (best = 241.123)
# Episode =  236, pose   0.000, vel -17.673, score =  72.662 (best = 241.123)
# Episode =  237, pose   0.000, vel -15.992, score =  56.637 (best = 241.123)
# Episode =  238, pose   0.000, vel -13.496, score =  52.777 (best = 241.123)
# Episode =  239, pose   0.000, vel -13.897, score =  64.787 (best = 241.123)
# Episode =  240, pose   0.000, vel -18.051, score =  68.532 (best = 241.123)
# Episode =  241, pose   0.000, vel -20.010, score =  44.462 (best = 241.123)
# Episode =  242, pose   0.000, vel -20.414, score =  44.449 (best = 241.123)
# Episode =  243, pose   0.000, vel -21.178, score =  54.497 (best = 241.123)
# Episode =  244, pose   0.000, vel -18.426, score =  44.419 (best = 241.123)
# Episode =  245, pose   0.000, vel -18.278, score =  56.444 (best = 241.123)
# Episode =  246, pose   0.000, vel -14.508, score =  66.790 (best = 241.123)
# Episode =  247, pose   0.000, vel -16.752, score =  46.459 (best = 241.123)
# Episode =  248, pose   0.000, vel -12.977, score =  76.671 (best = 241.123)
# Episode =  249, pose   0.000, vel -15.876, score =  81.059 (best = 241.123)
# Episode =  250, pose   0.000, vel -13.371, score =  82.837 (best = 241.123)
# Episode =  251, pose   0.000, vel -20.005, score =  66.472 (best = 241.123)
# Episode =  252, pose   0.000, vel -17.147, score =  56.444 (best = 241.123)
# Episode =  253, pose   0.000, vel -16.642, score =  66.449 (best = 241.123)
# Episode =  254, pose   0.000, vel -21.584, score =  64.356 (best = 241.123)
# Episode =  255, pose   0.000, vel -18.879, score =  58.400 (best = 241.123)
# Episode =  256, pose   0.000, vel -19.840, score =  46.353 (best = 241.123)
# Episode =  257, pose   0.000, vel -17.864, score =  48.417 (best = 241.123)
# Episode =  258, pose   0.000, vel -20.395, score =  44.318 (best = 241.123)
# Episode =  259, pose   0.000, vel -21.616, score =  54.328 (best = 241.123)
# Episode =  260, pose   0.000, vel -20.073, score =  66.364 (best = 241.123)
# Episode =  261, pose   0.000, vel -16.443, score =  60.459 (best = 241.123)
# Episode =  262, pose   0.000, vel -14.414, score =  86.539 (best = 241.123)
# Episode =  263, pose   0.000, vel  -6.886, score = 104.106 (best = 241.123)
# Episode =  264, pose   0.000, vel -15.771, score =  56.886 (best = 241.123)
# Episode =  265, pose   0.000, vel -13.440, score =  60.810 (best = 241.123)
# Episode =  266, pose   0.000, vel -13.416, score =  76.847 (best = 241.123)
# Episode =  267, pose   0.000, vel -16.402, score =  92.755 (best = 241.123)
# Episode =  268, pose   0.000, vel -18.077, score =  92.813 (best = 241.123)
# Episode =  269, pose   0.000, vel  -9.360, score =  92.580 (best = 241.123)
# Episode =  270, pose   0.000, vel  -9.432, score =  92.797 (best = 241.123)
# Episode =  271, pose   0.000, vel -19.256, score =  48.749 (best = 241.123)
# Episode =  272, pose   0.000, vel -12.778, score =  64.472 (best = 241.123)
# Episode =  273, pose   0.000, vel  -4.279, score = 107.254 (best = 241.123)
# Episode =  274, pose   0.000, vel -14.473, score =  46.407 (best = 241.123)
# Episode =  275, pose   0.000, vel -16.247, score =  48.382 (best = 241.123)
# Episode =  276, pose   0.000, vel -18.257, score =  48.427 (best = 241.123)
# Episode =  277, pose   0.000, vel -15.657, score =  70.739 (best = 241.123)
# Episode =  278, pose   0.000, vel -12.224, score =  84.393 (best = 241.123)
# Episode =  279, pose   0.000, vel -20.215, score =  46.517 (best = 241.123)
# Episode =  280, pose   0.000, vel -13.076, score =  72.486 (best = 241.123)
# Episode =  281, pose   0.000, vel -11.424, score =  80.443 (best = 241.123)
# Episode =  282, pose   0.000, vel -21.202, score =  42.235 (best = 241.123)
# Episode =  283, pose   0.000, vel -14.709, score =  74.443 (best = 241.123)
# Episode =  284, pose   0.000, vel -14.388, score =  60.433 (best = 241.123)
# Episode =  285, pose   0.000, vel -14.610, score =  56.519 (best = 241.123)
# Episode =  286, pose   0.000, vel -17.694, score =  60.686 (best = 241.123)
# Episode =  287, pose   0.000, vel -13.673, score =  73.390 (best = 241.123)
# Episode =  288, pose   0.000, vel -11.995, score =  90.759 (best = 241.123)
# Episode =  289, pose   0.000, vel -16.822, score =  80.615 (best = 241.123)
# Episode =  290, pose   0.000, vel -18.679, score =  60.522 (best = 241.123)
# Episode =  291, pose   0.000, vel -18.365, score =  94.916 (best = 241.123)
# Episode =  292, pose   0.000, vel -13.973, score =  96.235 (best = 241.123)
# Episode =  293, pose   0.000, vel -10.252, score =  50.852 (best = 241.123)
# Episode =  294, pose   0.000, vel -19.859, score =  75.413 (best = 241.123)
# Episode =  295, pose   0.000, vel -17.846, score =  48.741 (best = 241.123)
# Episode =  296, pose   0.000, vel -16.112, score =  89.235 (best = 241.123)
# Episode =  297, pose   0.000, vel -15.140, score =  72.364 (best = 241.123)
# Episode =  298, pose   0.000, vel -13.740, score = 102.122 (best = 241.123)
# Episode =  299, pose   0.000, vel -14.257, score =  66.897 (best = 241.123)
# Episode =  300, pose   0.000, vel -14.083, score =  79.951 (best = 241.123)
# Episode =  301, pose   0.000, vel -13.649, score =  82.945 (best = 241.123)
# Episode =  302, pose   0.000, vel -14.045, score =  83.595 (best = 241.123)
# Episode =  303, pose   0.000, vel -14.769, score =  96.731 (best = 241.123)
# Episode =  304, pose   0.000, vel  -7.692, score =  83.138 (best = 241.123)
# Episode =  305, pose   0.000, vel -15.228, score = 144.351 (best = 241.123)
# Episode =  306, pose   0.000, vel -14.137, score =  75.648 (best = 241.123)
# Episode =  307, pose   0.000, vel -11.641, score =  85.322 (best = 241.123)
# Episode =  308, pose   0.000, vel -14.403, score =  69.166 (best = 241.123)
# Episode =  309, pose   0.000, vel -16.241, score =  81.435 (best = 241.123)
# Episode =  310, pose   0.000, vel -16.698, score =  70.836 (best = 241.123)
# Episode =  311, pose   0.000, vel -16.928, score =  56.813 (best = 241.123)
# Episode =  312, pose   0.000, vel -14.756, score =  79.129 (best = 241.123)
# Episode =  313, pose   0.000, vel -14.422, score =  63.822 (best = 241.123)
# Episode =  314, pose   0.000, vel -13.483, score =  71.557 (best = 241.123)
# Episode =  315, pose   0.000, vel -16.055, score =  60.733 (best = 241.123)
# Episode =  316, pose   0.000, vel -20.492, score =  63.080 (best = 241.123)
# Episode =  317, pose   0.000, vel -13.024, score =  57.180 (best = 241.123)
# Episode =  318, pose   0.000, vel -14.991, score =  89.214 (best = 241.123)
# Episode =  319, pose   0.000, vel -12.819, score =  67.309 (best = 241.123)
# Episode =  320, pose   0.000, vel -17.393, score =  94.900 (best = 241.123)
# Episode =  321, pose   0.000, vel -16.948, score =  63.070 (best = 241.123)
# Episode =  322, pose   0.000, vel -16.796, score =  50.901 (best = 241.123)
# Episode =  323, pose   0.000, vel -18.581, score =  70.465 (best = 241.123)
# Episode =  324, pose   0.000, vel -16.917, score =  48.691 (best = 241.123)
# Episode =  325, pose   0.000, vel -16.060, score =  65.019 (best = 241.123)
# Episode =  326, pose   0.000, vel -13.667, score =  94.156 (best = 241.123)
# Episode =  327, pose   0.000, vel -13.895, score =  61.322 (best = 241.123)
# Episode =  328, pose   0.000, vel -14.639, score = 100.058 (best = 241.123)
# Episode =  329, pose   0.000, vel -13.622, score =  90.753 (best = 241.123)
# Episode =  330, pose   0.000, vel -14.720, score =  52.711 (best = 241.123)
# Episode =  331, pose   0.000, vel -13.762, score =  69.163 (best = 241.123)
# Episode =  332, pose   0.000, vel -11.669, score =  54.936 (best = 241.123)
# Episode =  333, pose   0.000, vel  -9.499, score =  98.790 (best = 241.123)
# Episode =  334, pose   0.000, vel -15.393, score =  48.615 (best = 241.123)
# Episode =  335, pose   0.000, vel -19.293, score =  62.890 (best = 241.123)
# Episode =  336, pose   0.000, vel -11.346, score = 104.046 (best = 241.123)
# Episode =  337, pose   0.000, vel -13.387, score =  82.937 (best = 241.123)
# Episode =  338, pose   0.000, vel -12.993, score = 103.099 (best = 241.123)
# Episode =  339, pose   0.000, vel -14.453, score =  83.515 (best = 241.123)
# Episode =  340, pose   0.000, vel -17.099, score =  79.314 (best = 241.123)
# Episode =  341, pose   0.000, vel -11.059, score =  86.205 (best = 241.123)
# Episode =  342, pose   0.000, vel  -9.141, score =  69.856 (best = 241.123)
# Episode =  343, pose   0.000, vel -14.134, score = 105.458 (best = 241.123)
# Episode =  344, pose   0.000, vel -16.566, score =  76.768 (best = 241.123)
# Episode =  345, pose   0.000, vel -14.004, score =  57.211 (best = 241.123)
# Episode =  346, pose   0.000, vel -17.385, score =  55.179 (best = 241.123)
# Episode =  347, pose   0.000, vel -14.594, score =  67.070 (best = 241.123)
# Episode =  348, pose   0.000, vel -13.310, score =  71.287 (best = 241.123)
# Episode =  349, pose   0.000, vel -10.615, score =  85.210 (best = 241.123)
# Episode =  350, pose   0.000, vel -17.663, score =  75.032 (best = 241.123)
# Episode =  351, pose   0.000, vel -12.781, score =  68.630 (best = 241.123)
# Episode =  352, pose   0.000, vel -13.441, score = 104.250 (best = 241.123)
# Episode =  353, pose   0.000, vel -13.156, score =  69.469 (best = 241.123)
# Episode =  354, pose   0.000, vel -18.367, score = 128.828 (best = 241.123)
# Episode =  355, pose   0.000, vel -10.552, score =  80.307 (best = 241.123)
# Episode =  356, pose   0.000, vel -14.689, score =  87.648 (best = 241.123)
# Episode =  357, pose   0.000, vel -13.765, score =  96.595 (best = 241.123)
# Episode =  358, pose   0.000, vel -14.088, score =  71.355 (best = 241.123)
# Episode =  359, pose   0.000, vel -16.688, score =  73.648 (best = 241.123)
# Episode =  360, pose   0.000, vel -18.216, score =  72.831 (best = 241.123)
# Episode =  361, pose   0.000, vel -14.441, score =  82.842 (best = 241.123)
# Episode =  362, pose   0.000, vel -16.610, score =  63.030 (best = 241.123)
# Episode =  363, pose   0.000, vel -13.703, score = 154.772 (best = 241.123)
# Episode =  364, pose   0.000, vel -14.715, score = 106.974 (best = 241.123)
# Episode =  365, pose   0.000, vel -15.134, score = 136.844 (best = 241.123)
# Episode =  366, pose   0.000, vel -10.345, score =  78.946 (best = 241.123)
# Episode =  367, pose   0.000, vel -12.949, score =  89.780 (best = 241.123)
# Episode =  368, pose   0.000, vel -16.608, score =  80.464 (best = 241.123)
# Episode =  369, pose   0.000, vel -13.367, score =  88.924 (best = 241.123)
# Episode =  370, pose   0.000, vel -13.733, score =  76.377 (best = 241.123)
# Episode =  371, pose   0.000, vel -13.198, score =  95.990 (best = 241.123)
# Episode =  372, pose   0.000, vel -13.463, score = 127.447 (best = 241.123)
# Episode =  373, pose   0.000, vel -19.105, score =  68.240 (best = 241.123)
# Episode =  374, pose   0.000, vel -11.140, score =  82.237 (best = 241.123)
# Episode =  375, pose   0.000, vel -12.784, score =  94.746 (best = 241.123)
# Episode =  376, pose   0.000, vel -10.488, score =  75.787 (best = 241.123)
# Episode =  377, pose   0.000, vel -12.675, score =  83.574 (best = 241.123)
# Episode =  378, pose   0.000, vel  -9.890, score =  87.958 (best = 241.123)
# Episode =  379, pose   0.000, vel -11.853, score = 112.015 (best = 241.123)
# Episode =  380, pose   0.000, vel -18.735, score =  72.111 (best = 241.123)
# Episode =  381, pose   0.000, vel  -8.849, score =  90.285 (best = 241.123)
# Episode =  382, pose   0.000, vel -15.373, score =  97.094 (best = 241.123)
# Episode =  383, pose   0.000, vel -10.253, score =  85.313 (best = 241.123)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-12ef34741ac7> in <module>
#      29                 results[labels[ii]].append(to_write[ii])
#      30         # 更新
# ---> 31         agent.step(action, reward, next_state, done)
#      32         state = next_state
#      33         if done:
#
# ~/Projects/deep/project-quadcopter/agents/agent.py in step(self, action, reward, next_state, done)
#     124         if (len(self.memory) > self.batch_size):
#     125             experience = self.memory.sample()
# --> 126             self.learn(experience)
#     127
#     128         self.last_state = next_state
#
# ~/Projects/deep/project-quadcopter/agents/agent.py in learn(self, experience)
#     149
#     150         # 训练critic
# --> 151         self.critic_local.model.train_on_batch(x=[states, actions], y=Q_current_label)
#     152
#     153         # 训练actor
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
## TODO: Plot the rewards.

plot_run(results)

path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=target_pos)

# %%
# plot best policy
best_w = agent.best_w
agent.actor_local.model.set_weights(best_w[0])
agent.critic_local.model.set_weights(best_w[1])

all_reward = 0
best_results = {x : [] for x in labels}

state = agent.reset_episode() # start a new episode
while True:
    # 状态->动作
    action = agent.act(state) 
    # 执行动作，得到下一时刻的状态和奖励
    next_state, reward, done = task.step(action)
    state = next_state
    all_reward += reward
    
    to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
    for ii in range(len(labels)):
        best_results[labels[ii]].append(to_write[ii])
    
    if done:
        print("pose {:7.3f}, vel {:7.3f}, score = {:7.3f}".format(
            task.sim.pose[2], task.sim.v[2], all_reward))  # [debug]    
        break
    sys.stdout.flush()
    
plot_run(best_results)
path = [[best_results['x'][i], best_results['y'][i], best_results['z'][i]] for i in range(len(best_results['x']))]
show_flight_path(path, target=target_pos)
# Out:
# pose  86.046, vel  10.769, score = 382.723

# %% [markdown]
# ## 绘制阶段奖励
#
# 请绘制智能体在每个阶段中获得的总奖励，这可以是单次运行的奖励值，也可以是多次运行的平均值。

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_rewards(rewards):

    plt.title('rewards')
    plt.xlabel('episode')
    plt.ylabel('rewards')
    
    plt.plot(rewards['episode'], rewards['reward'], label='reward/episode')
    plt.legend()
    _ = plt.ylim()

# %%
## TODO: Plot the rewards.
plot_rewards(rewards)

# %% [markdown]
# ## 回顾
#
# **问题 1**：请描述你在 `task.py` 中指定的任务。你如何设计奖励函数？
#
# **回答**：
#
#
# **问题 2**：请简要描述你的智能体，你可以参考以下问题：
#
# - 你尝试了哪些学习算法？哪个效果最好？
# - 你最终选择了哪些超参数（比如 $\alpha$，$\gamma$，$\epsilon$ 等）？
# - 你使用了什么样的神经网络结构（如果有的话）？请说明层数、大小和激活函数等信息。
#
# **回答**：
#
#
#
# **问题 3**：根据你绘制的奖励图，描述智能体的学习状况。
#
# - 学习该任务是简单还是困难？
# - 该学习曲线中是否存在循序渐进或急速上升的部分？
# - 该智能体的最终性能有多好？（比如最后十个阶段的平均奖励值）
#
# **回答**：
#
#
#
# **问题 4**：请简要总结你的本次项目经历。你可以参考以下问题：
#
# - 本次项目中最困难的部分是什么？（例如开始项目、运行 ROS、绘制、特定的任务等。）
# - 关于四轴飞行器和你的智能体的行为，你是否有一些有趣的发现？
#
# **回答**：

# %% [markdown]
# ### (可选)Plot Actor 及 Critic 结构
# 建议使用 ```from keras.utils import plot_model``` 来显示模型结构；
