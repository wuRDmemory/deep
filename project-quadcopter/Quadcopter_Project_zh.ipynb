# %% [markdown]
# # 项目：指导四轴飞行器学会飞行
#
# 设计一个能够使四轴飞行器飞行的智能体，然后使用你选择的强化学习算法训练它！
#
# 请尝试运用你在这一单元中学到的知识，看看哪个方法效果最好，当然你也可以自己想出创新型方法并测试它们。
# ## 说明
#
# 请查看目录下的文件，以更好地了解项目结构。
#
# - `task.py`：在本文件中定义你的任务（环境）。
# - `agents/`：本文件夹中包含强化学习智能体。
#     - `policy_search.py`：我们为你提供了一个智能体模板。
#     - `agent.py`：在本文件中开发你的智能体。
# - `physics_sim.py`：本文件中包含四轴飞行器模拟器。**请勿修改本文件**。
#
# 在本项目中，你需要在 `task.py` 中定义你的任务。尽管我们为你提供了一个任务示例，来帮助你开始项目，但你也可以随意更改这个文件。在这个 notebook 中，你还将学习更多有关修改这个文件的知识。
#
# 你还需要在 `agent.py` 中设计一个强化学习智能体，来完成你选择的任务。
#
# 我们也鼓励你创建其他文件，来帮助你整理代码。比如，你也许可以通过定义一个 `model.py` 文件来定义其他你需要的神经网络结构。
#
# ## 控制四轴飞行器
#
# 在下方的代码中，我们提供了一个智能体示例，来示范如何使用模拟器来控制四轴飞行器。这个智能体比你在 notebook 中需要测试的智能体（在 `agents/policy_search.py` 中）更加简单！
#
# 这个智能体通过设置飞行器四个轴上的转速来控制飞行器。`Basic_Agent` 类中提供的智能体将会随机为四个轴指定动作。这四个速度将通过 `act` 方法以四个浮点数列表的形式返回。
#
# 在本项目中，你将在 `agents/agent.py` 中实现的智能体会以更加智能的方法进行指定的动作。

# %% [markdown]
# ### plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_run(results, standalone=True):
    if standalone:
        plt.subplots(figsize=(15, 15))
    
    #查看四轴飞行器的位置变化
    plt.subplot(3, 3, 1)
    plt.title('Position')
    plt.plot(results['time'], results['x'], label='x')
    plt.plot(results['time'], results['y'], label='y')
    plt.plot(results['time'], results['z'], label='z')
    plt.xlabel('time, seconds')
    plt.ylabel('Position')
    plt.grid(True)
    if standalone:
        plt.legend()

    #四轴飞行器的速度
    plt.subplot(3, 3, 2)
    plt.title('Velocity')
    plt.plot(results['time'], results['x_velocity'], label='x_hat')
    plt.plot(results['time'], results['y_velocity'], label='y_hat')
    plt.plot(results['time'], results['z_velocity'], label='z_hat')
    plt.xlabel('time, seconds')
    plt.ylabel('Velocity')
    plt.grid(True)
    if standalone:
        plt.legend()
    
    #绘制欧拉角 (Euler angles)（四轴飞行器围绕 x，y 和 z 轴的旋转）的图表
    plt.subplot(3, 3, 3)
    plt.title('Orientation')
    plt.plot(results['time'], results['phi'], label='phi')
    plt.plot(results['time'], results['theta'], label='theta')
    plt.plot(results['time'], results['psi'], label='psi')
    plt.xlabel('time, seconds')
    plt.grid(True)
    if standalone:
        plt.legend()
    
    #绘制每个欧拉角的速度（每秒的弧度）图
    plt.subplot(3, 3, 4)
    plt.title('Angular Velocity')
    plt.plot(results['time'], results['phi_velocity'], label='phi')
    plt.plot(results['time'], results['theta_velocity'], label='theta')
    plt.plot(results['time'], results['psi_velocity'], label='psi')
    plt.xlabel('time, seconds')
    plt.grid(True)
    if standalone:
        plt.legend()

    #最后，你可以使用下方代码来输出智能体选择的动作。
    plt.subplot(3, 3, 5)
    plt.title('Rotor Speed')
    plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1')
    plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2')
    plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3')
    plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4')
    plt.xlabel('time, seconds')
    plt.ylabel('Rotor Speed, revolutions / second')
    plt.grid(True)
    if standalone:
        plt.legend()

    if standalone:
        plt.tight_layout()
        plt.show()

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D


def plot_point3d(ax, x, y, z, **kwargs):
    ax.scatter([x], [y], [z], **kwargs)
    ax.text(x, y, z, "({:.1f}, {:.1f}, {:.1f})".format(x, y, z))


def show_flight_path(results, target=None):
    results = np.array(results)
    
    fig = plt.figure(figsize=(10,10))
    ax = fig.gca(projection='3d')
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Z-axis')

    ax.plot3D(results[:, 0], results[:, 1], results[:, 2], 'gray')
    
    if target is not None:
        plot_point3d(ax, *target[0:3], c='y', marker='x', s=100, label='target')
        
    plot_point3d(ax, *results[0, 0:3], c='g', marker='o', s=50, label='start')
    plot_point3d(ax, *results[-1, 0:3], c='r', marker='o', s=50, label='end')
    
    ax.legend()

# %% [markdown]
# ### random Agent

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# 运行下方代码，让智能体指定动作来控制四轴飞行器。
#
# 请随意更改我们提供的 `runtime`，`init_pose`，`init_velocities` 和 `init_angle_velocities` 值来更改四轴飞行器的初始条件。
#
# 下方的 `labels` 列表为模拟数据的注释。所有的信息都储存在 `data.txt` 文档中，并保存在 `results` 目录下。

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %%
plot_run(results)

# %%
path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=None)

# %% [markdown]
# 在指定任务之前，你需要在模拟器中衍生环境状态。运行下方代码来在模拟结束时输出以下变量值：
#
# - `task.sim.pose`：四周飞行器在 ($x,y,z$) 坐标系中的位置和欧拉角。
# - `task.sim.v`：四轴飞行器在 ($x,y,z$) 坐标系中的速度。
# - `task.sim.angular_v`：三个欧拉角的弧度/每秒。

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [ 9.54623454 17.97303258 26.81994945  0.57142372  6.20118684  0.        ]
# [ 3.78163537 10.80170553  3.34760162]
# [ 0.18657271 -0.00892769  0.        ]

# %% [markdown]
# 在 `task.py` 中的任务示例中，我们使用了四轴飞行器六个维度的动作来构建每个时间步的环境状态。然而，你也可以按照自己的意愿更改任务，你可以添加速度信息来扩大状态向量，也可以使用任何动作、速度和角速度的组合，并构造适用于你的任务的环境状态。
#
# ## 任务
#
# 在 `task.py` 中，我们为你提供了一个任务示例。请在新窗口中打开这个文件。
#
# 使用 `__init__()` 方法来初始化指定本任务所需的几个变量。
#
# - 模拟器作为 `PhysicsSim` 类（来自 `physics_sim.py` 文件）的示例进行初始化。
# - 受到 DDPG 论文中研究方法的启发，我们使用了重复调用动作的方法。对于智能体的每一个时间步，我们将利用 `action_repeats` 时间步来进行模拟。如果你并不熟悉这种方法，可以阅读 [DDPG 论文](https://arxiv.org/abs/1509.02971)的结论部分。
# - 我们设置了状态向量中每个分量的数值。在任务示例中，我们只设置了六个维度的动作信息。为了设定向量大小（`state_size`），我们必须考虑重复的动作。
# - 任务环境通常是一个四维动作空间，每个轴有一个输入（`action_size=4`）。你可以设置每个输入的最小值（`action_low`）和最大值（`action_high`）。
# - 我们在文件中提供的任务示例将使智能体达到目标位置。我们将目标位置设置为一个变量。
#
# `reset()` 方法将重置模拟器。每当阶段结束时，智能体都将调用此方法。你可以查看下方代码中的例子。
#
# `step()` 方法是最重要的一个方法。它将接收智能体选择的动作 `rotor_speeds`，并准备好下一个状态，同时返回给智能体。接着，你将通过 `get_reward()` 计算奖励值。当超过规定时间，或是四轴飞行器到达模拟器边缘时，这一阶段将视作结束。
#
# 接下来，你将学习如何测试这个任务中智能体的性能。
#
# ## 智能体
#
# `agents/policy_search.py` 文件中提供的智能体示例使用了非常简单的线性策略，将动作向量视作状态向量和矩阵权重的点积直接进行计算。接着，它通过添加一些高斯噪声来随机干扰参数，以产生不同的策略。根据每个阶段获得的平均奖励值（`score`），它将记录迄今为止发现的最佳参数集以及分数的变化状态，并据此调整比例因子来扩大或减少噪音。
#
# 请运行下方代码来查看任务示例中智能体的性能。

# %%
import sys
import pandas as p

# %%
from agents.policy_search import PolicySearch_Agent
from task import Task

labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

num_episodes = 1
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        # 状态->动作
        action = agent.act(state) 
        # 执行动作，得到下一时刻的状态和奖励
        next_state, reward, done = task.step(action)
        if i_episode == num_episodes:
            to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
            for ii in range(len(labels)):
                results[labels[ii]].append(to_write[ii])
        # 更新
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode =    1, score =  -1.040 (best =  -1.040), noise_scale = 0.05

# %%
plot_run(results)

path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=target_pos)

# %% [markdown]
# 这个智能体的性能想必十分糟糕！现在轮到你出场了！
#
# ## 定义任务，设计并训练你的智能体！
#
# 修改 `task.py` 文件来指定你所选择的任务。如果你不确定选择什么任务，你可以教你的四轴飞行器起飞、盘旋、着陆或是达到指定位置。
#
#
# 在指定任务后，使用 `agents/policy_search.py` 中的智能体示例作为模板，来在 `agents/agent.py` 中定义你自己的智能体。你可以随意从智能体示例中借用你需要的元素，包括如何模块化你的代码（使用 `act()`，`learn()` 和 `reset_episode_vars()` 等辅助方法）。
#
# 请注意，你指定的第一个智能体和任务**极有可能**无法顺利进行学习。你将需要改进不同的超参数和奖励函数，直到你能够获得不错的结果。
#
# 在开发智能体的时候，你还需要关注它的性能。参考下方代码，建立一个机制来存储每个阶段的总奖励值。如果阶段奖励值在逐渐上升，说明你的智能体正在学习。

# %%
import numpy as np
import random
from collections import namedtuple, deque
from physics_sim import PhysicsSim
from agents.agent import UserAgent
from agents.policy_search import PolicySearch_Agent
from task import UserTask

target_pos = np.array([0., 0., 100.0])
init_pos = np.array([0., 0., 10., 0, 0, 0])
task = UserTask(init_pose=init_pos, runtime=10, target_pos=target_pos)

agent = UserAgent(task)
agent.memory.reset()
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# >>> agent param
# >>> gamma 0.99 tau 0.01
# >>> theta 0.15 sigma 0.2

# %%
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}
num_episodes = 1000
reward_record = []

print(">>> start training, memory is {}".format(len(agent.memory)))
for i_episode in range(1, num_episodes+1):
    # 这里面包含task和sim的reset
    state = agent.reset_episode() # start a new episode
    while True:
        # 状态->动作
        action = agent.act(state) 
        # 执行动作，得到下一时刻的状态和奖励
        next_state, reward, done = task.step(action)
        if i_episode == num_episodes:
            to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
            for ii in range(len(labels)):
                results[labels[ii]].append(to_write[ii])
        # 更新
        agent.step(action, reward, next_state, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, pose {:7.3f}, vel {:7.3f}, score = {:7.3f} (best = {:7.3f})".format(
                i_episode, task.sim.pose[2], task.sim.v[2], agent.score, agent.best_score))  # [debug]
            break
        sys.stdout.flush()
#     if i_episode % 50 == 0:
#         # 时不时的把权重变为最好的之后在该权重上进行优化
#         agent.set_best()
    reward_record.append(agent.score)
# Out:
# >>> agent param
# >>> gamma 0.99 tau 0.01
# >>> theta 0.15 sigma 0.2
# >>> start training, memory is 0
# Episode =    1, pose   0.000, vel -18.100, score = 187.237 (best = 187.237)
# Episode =    2, pose   0.000, vel -18.305, score = 201.916 (best = 201.916)
# Episode =    3, pose   0.000, vel -14.696, score = 239.838 (best = 239.838)
# Episode =    4, pose   0.000, vel -14.337, score = 167.926 (best = 239.838)
# Episode =    5, pose   0.000, vel -13.981, score = 129.173 (best = 239.838)
# Episode =    6, pose   0.000, vel -11.894, score = 147.584 (best = 239.838)
# Episode =    7, pose   0.000, vel -14.756, score = 123.708 (best = 239.838)
# Episode =    8, pose   0.000, vel -14.630, score = 124.449 (best = 239.838)
# Episode =    9, pose   0.000, vel -16.000, score = 124.493 (best = 239.838)
# Episode =   10, pose   0.000, vel -14.750, score = 148.515 (best = 239.838)
# Episode =   11, pose   0.000, vel -15.179, score = 182.609 (best = 239.838)
# Episode =   12, pose   0.000, vel -10.691, score = 234.117 (best = 239.838)
# Episode =   13, pose   0.000, vel -15.314, score = 166.907 (best = 239.838)
# Episode =   14, pose   0.000, vel -14.516, score = 148.612 (best = 239.838)
# Episode =   15, pose   0.000, vel -13.928, score = 124.196 (best = 239.838)
# Episode =   16, pose   0.000, vel -14.852, score = 134.084 (best = 239.838)
# Episode =   17, pose   0.000, vel -14.429, score = 119.251 (best = 239.838)
# Episode =   18, pose   0.000, vel -15.034, score = 114.433 (best = 239.838)
# Episode =   19, pose   0.000, vel -15.432, score = 138.936 (best = 239.838)
# Episode =   20, pose   0.000, vel -16.148, score = 119.061 (best = 239.838)
# Episode =   21, pose   0.000, vel -16.510, score = 133.712 (best = 239.838)
# Episode =   22, pose   0.000, vel -16.576, score = 148.396 (best = 239.838)
# Episode =   23, pose   0.000, vel -16.469, score = 148.444 (best = 239.838)
# Episode =   24, pose   0.000, vel -16.342, score = 138.494 (best = 239.838)
# Episode =   25, pose   0.000, vel -16.388, score = 123.880 (best = 239.838)
# Episode =   26, pose   0.000, vel -16.604, score = 143.795 (best = 239.838)
# Episode =   27, pose   0.000, vel -14.954, score = 119.212 (best = 239.838)
# Episode =   28, pose   0.000, vel -13.996, score = 129.171 (best = 239.838)
# Episode =   29, pose   0.000, vel -13.936, score = 133.995 (best = 239.838)
# Episode =   30, pose   0.000, vel -14.235, score = 124.119 (best = 239.838)
# Episode =   31, pose   0.000, vel -14.748, score = 134.157 (best = 239.838)
# Episode =   32, pose   0.000, vel -16.093, score = 144.044 (best = 239.838)
# Episode =   33, pose   0.000, vel -14.404, score = 148.616 (best = 239.838)
# Episode =   34, pose   0.000, vel -15.347, score = 123.837 (best = 239.838)
# Episode =   35, pose   0.000, vel -17.366, score = 143.245 (best = 239.838)
# Episode =   36, pose   0.000, vel -15.111, score = 137.732 (best = 239.838)
# Episode =   37, pose   0.000, vel -18.082, score = 143.522 (best = 239.838)
# Episode =   38, pose   0.000, vel -15.676, score = 162.442 (best = 239.838)
# Episode =   39, pose   0.000, vel -15.999, score = 109.541 (best = 239.838)
# Episode =   40, pose   0.000, vel -17.296, score = 100.309 (best = 239.838)
# Episode =   41, pose   0.000, vel -17.216, score = 104.859 (best = 239.838)
# Episode =   42, pose   0.000, vel -16.371, score = 114.113 (best = 239.838)
# Episode =   43, pose   0.000, vel -15.419, score = 157.057 (best = 239.838)
# Episode =   44, pose   0.000, vel -12.604, score = 281.774 (best = 281.774)
# Episode =   45, pose   0.000, vel -17.914, score = 320.370 (best = 320.370)
# Episode =   46, pose   0.000, vel -16.673, score = 191.122 (best = 320.370)
# Episode =   47, pose   0.000, vel -14.989, score = 205.495 (best = 320.370)
# Episode =   48, pose   0.000, vel -17.112, score = 181.057 (best = 320.370)
# Episode =   49, pose   0.000, vel -15.079, score = 181.204 (best = 320.370)
# Episode =   50, pose   0.000, vel -14.699, score = 171.363 (best = 320.370)
# Episode =   51, pose   0.000, vel -15.074, score = 138.574 (best = 320.370)
# Episode =   52, pose   0.000, vel -14.607, score = 133.945 (best = 320.370)
# Episode =   53, pose   0.000, vel -15.100, score = 163.560 (best = 320.370)
# Episode =   54, pose   0.000, vel -15.559, score = 138.716 (best = 320.370)
# Episode =   55, pose   0.000, vel -15.611, score = 144.088 (best = 320.370)
# Episode =   56, pose   0.000, vel -15.797, score = 134.268 (best = 320.370)
# Episode =   57, pose   0.000, vel -15.693, score = 149.106 (best = 320.370)
# Episode =   58, pose   0.000, vel -16.261, score = 124.437 (best = 320.370)
# Episode =   59, pose   0.000, vel -16.237, score = 144.254 (best = 320.370)
# Episode =   60, pose   0.000, vel -15.631, score = 134.226 (best = 320.370)
# Episode =   61, pose   0.000, vel -14.549, score = 148.891 (best = 320.370)
# Episode =   62, pose   0.000, vel -14.273, score = 124.254 (best = 320.370)
# Episode =   63, pose   0.000, vel -13.418, score = 134.315 (best = 320.370)
# Episode =   64, pose   0.000, vel -12.725, score = 129.139 (best = 320.370)
# Episode =   65, pose   0.000, vel -13.562, score = 148.985 (best = 320.370)
# Episode =   66, pose   0.000, vel -14.097, score = 124.325 (best = 320.370)
# Episode =   67, pose   0.000, vel -13.081, score = 129.133 (best = 320.370)
# Episode =   68, pose   0.000, vel -14.589, score = 139.102 (best = 320.370)
# Episode =   69, pose   0.000, vel -14.653, score = 139.068 (best = 320.370)
# Episode =   70, pose   0.000, vel -15.668, score = 139.033 (best = 320.370)
# Episode =   71, pose   0.000, vel -15.168, score = 139.113 (best = 320.370)
# Episode =   72, pose   0.000, vel -12.004, score = 143.655 (best = 320.370)
# Episode =   73, pose   0.000, vel -15.218, score = 148.814 (best = 320.370)
# Episode =   74, pose   0.000, vel -15.177, score = 128.976 (best = 320.370)
# Episode =   75, pose   0.000, vel -12.792, score = 186.555 (best = 320.370)
# Episode =  156, pose 246.464, vel 1385.917, score = 619.081 (best = 989.587)
# Episode =  157, pose   4.170, vel -123.719, score = 458.012 (best = 989.587)
# Episode =  158, pose 143.981, vel   1.018, score = 986.834 (best = 989.587)
# Episode =  159, pose   0.000, vel -25.332, score = 706.740 (best = 989.587)
# Episode =  160, pose 114.591, vel  15.085, score = 911.067 (best = 989.587)
# Episode =  161, pose   8.524, vel -69.765, score = 593.166 (best = 989.587)
# Episode =  162, pose 100.919, vel   8.618, score = 869.595 (best = 989.587)
# Episode =  163, pose 159.543, vel  10.799, score = 981.141 (best = 989.587)
# Episode =  164, pose   0.000, vel -64.428, score = 295.482 (best = 989.587)
# Episode =  165, pose   0.000, vel -63.328, score = 299.781 (best = 989.587)
# Episode =  166, pose   0.000, vel -15.770, score = 196.165 (best = 989.587)
# Episode =  167, pose   0.000, vel -28.657, score = 212.283 (best = 989.587)
# Episode =  168, pose   0.000, vel -17.944, score = 214.200 (best = 989.587)
# Episode =  169, pose   0.000, vel -18.145, score = 186.261 (best = 989.587)
# Episode =  170, pose   0.000, vel -14.619, score = 171.022 (best = 989.587)
# Episode =  171, pose   0.000, vel -16.484, score = 186.039 (best = 989.587)
# Episode =  172, pose   0.000, vel -15.588, score = 191.186 (best = 989.587)
# Episode =  173, pose   0.000, vel -15.275, score = 181.767 (best = 989.587)
# Episode =  174, pose   0.000, vel -20.714, score = 219.926 (best = 989.587)
# Episode =  175, pose   0.000, vel -16.970, score = 185.985 (best = 989.587)
# Episode =  176, pose   0.000, vel -13.733, score = 195.245 (best = 989.587)
# Episode =  177, pose   0.000, vel -12.886, score = 190.537 (best = 989.587)
# Episode =  178, pose   0.000, vel -13.886, score = 166.414 (best = 989.587)
# Episode =  179, pose   0.000, vel -14.863, score = 181.701 (best = 989.587)
# Episode =  180, pose   0.000, vel -18.330, score = 181.711 (best = 989.587)
# Episode =  181, pose   0.000, vel -20.156, score = 205.810 (best = 989.587)
# Episode =  182, pose   0.000, vel -15.101, score = 186.114 (best = 989.587)
# Episode =  183, pose   0.000, vel -26.607, score = 226.130 (best = 989.587)
# Episode =  184, pose   0.000, vel -19.722, score = 181.698 (best = 989.587)
# Episode =  185, pose   3.445, vel -81.925, score = 410.248 (best = 989.587)
# Episode =  186, pose   0.000, vel -48.627, score = 281.424 (best = 989.587)
# Episode =  187, pose   0.000, vel -18.747, score = 400.154 (best = 989.587)
# Episode =  188, pose   0.000, vel -22.654, score = 581.232 (best = 989.587)
# Episode =  189, pose   0.000, vel -84.499, score = 357.002 (best = 989.587)
# Episode =  190, pose   0.000, vel -21.511, score = 458.224 (best = 989.587)
# Episode =  191, pose  60.342, vel  -4.527, score = 699.473 (best = 989.587)
# Episode =  192, pose   0.000, vel -23.022, score = 606.827 (best = 989.587)
# Episode =  193, pose 136.132, vel  16.226, score = 802.318 (best = 989.587)
# Episode =  194, pose  95.396, vel  -4.110, score = 855.712 (best = 989.587)
# Episode =  195, pose  95.145, vel -17.333, score = 990.727 (best = 990.727)
# Episode =  471, pose   0.000, vel -65.137, score = 833.932 (best = 1009.360)
# Episode =  472, pose 116.313, vel -16.263, score = 998.914 (best = 1009.360)
# Episode =  473, pose 156.510, vel   1.994, score = 998.307 (best = 1009.360)
# Episode =  474, pose   0.000, vel -35.003, score = 726.443 (best = 1009.360)
# Episode =  475, pose 158.297, vel   7.962, score = 1007.820 (best = 1009.360)
# Episode =  476, pose  81.463, vel -19.400, score = 980.061 (best = 1009.360)
# Episode =  477, pose   0.000, vel -26.712, score = 773.084 (best = 1009.360)
# Episode =  478, pose 115.375, vel -14.133, score = 964.408 (best = 1009.360)
# Episode =  479, pose  84.056, vel -22.137, score = 972.279 (best = 1009.360)
# Episode =  480, pose  19.597, vel -34.780, score = 896.184 (best = 1009.360)
# Episode =  481, pose  55.393, vel -29.342, score = 932.272 (best = 1009.360)
# Episode =  482, pose   0.000, vel -27.648, score = 708.931 (best = 1009.360)
# Episode =  483, pose   7.843, vel -38.477, score = 865.922 (best = 1009.360)
# Episode =  484, pose 212.188, vel 823.419, score = 641.769 (best = 1009.360)
# Episode =  485, pose   0.000, vel -39.135, score = 749.598 (best = 1009.360)
# Episode =  486, pose   0.000, vel -40.184, score = 788.995 (best = 1009.360)
# Episode =  487, pose 182.730, vel  21.354, score = 987.346 (best = 1009.360)
# Episode =  488, pose  36.791, vel -33.871, score = 913.833 (best = 1009.360)
# Episode =  489, pose   0.000, vel -33.994, score = 629.183 (best = 1009.360)
# Episode =  490, pose  13.984, vel -227.301, score = 797.719 (best = 1009.360)
# Episode =  491, pose  67.498, vel -26.445, score = 960.010 (best = 1009.360)
# Episode =  492, pose 270.238, vel 210.062, score = 945.697 (best = 1009.360)
# Episode =  493, pose   0.000, vel -31.046, score = 779.445 (best = 1009.360)
# Episode =  494, pose  36.148, vel -25.607, score = 893.595 (best = 1009.360)
# Episode =  495, pose  66.427, vel -21.064, score = 916.473 (best = 1009.360)
# Episode =  496, pose   0.000, vel -35.386, score = 737.212 (best = 1009.360)
# Episode =  497, pose 163.605, vel  13.462, score = 1000.077 (best = 1009.360)
# Episode =  498, pose 139.813, vel  -5.466, score = 1001.289 (best = 1009.360)
# Episode =  499, pose  95.049, vel -19.269, score = 979.757 (best = 1009.360)
# Episode =  500, pose  82.088, vel -24.780, score = 961.566 (best = 1009.360)
# Episode =  501, pose   0.000, vel -29.465, score = 589.308 (best = 1009.360)
# Episode =  502, pose   0.000, vel -25.051, score = 778.474 (best = 1009.360)
# Episode =  503, pose 177.308, vel  36.765, score = 945.075 (best = 1009.360)
# Episode =  504, pose   0.000, vel -36.842, score = 801.772 (best = 1009.360)
# Episode =  505, pose  50.306, vel -25.966, score = 959.047 (best = 1009.360)
# Episode =  506, pose 108.559, vel -51.223, score = 834.138 (best = 1009.360)
# Episode =  507, pose   0.000, vel -29.715, score = 661.414 (best = 1009.360)
# Episode =  508, pose   0.000, vel -63.268, score = 738.293 (best = 1009.360)
# Episode =  509, pose  10.739, vel -37.489, score = 888.295 (best = 1009.360)
# Episode =  510, pose 123.629, vel -11.606, score = 1007.238 (best = 1009.360)
# Episode =  511, pose 144.952, vel  -2.998, score = 1003.121 (best = 1009.360)
# Episode =  512, pose 108.796, vel -15.148, score = 974.263 (best = 1009.360)
# Episode =  513, pose  93.280, vel -18.901, score = 956.923 (best = 1009.360)
# Episode =  514, pose 300.000, vel 3186.070, score = 875.621 (best = 1009.360)
# Episode =  515, pose 168.600, vel  17.377, score = 1011.679 (best = 1011.679)
# Episode =  516, pose 165.236, vel  17.572, score = 994.389 (best = 1011.679)
# Episode =  517, pose 101.079, vel -16.110, score = 990.247 (best = 1011.679)
# Episode =  518, pose 199.179, vel 281.596, score = 859.497 (best = 1011.679)
# Episode =  519, pose  23.983, vel -37.114, score = 900.364 (best = 1011.679)
# Episode =  520, pose   0.000, vel -31.256, score = 797.439 (best = 1011.679)
# Episode =  521, pose   0.000, vel -41.965, score = 864.247 (best = 1011.679)
# Episode =  522, pose   0.000, vel -34.131, score = 728.486 (best = 1011.679)
# Episode =  523, pose   0.000, vel -33.225, score = 619.436 (best = 1011.679)
# Episode =  524, pose   0.000, vel -38.808, score = 829.486 (best = 1011.679)
# Episode =  525, pose 137.749, vel  -4.932, score = 988.723 (best = 1011.679)
# Episode =  526, pose   0.000, vel -37.592, score = 837.292 (best = 1011.679)
# Episode =  527, pose  98.533, vel -35.592, score = 985.690 (best = 1011.679)
# Episode =  528, pose   0.000, vel -29.481, score = 727.724 (best = 1011.679)
# Episode =  529, pose   0.000, vel -34.125, score = 710.358 (best = 1011.679)
# Episode =  530, pose   0.000, vel -34.690, score = 746.537 (best = 1011.679)
# Episode =  531, pose 124.025, vel -12.811, score = 988.108 (best = 1011.679)
# Episode =  532, pose  37.349, vel -32.745, score = 913.465 (best = 1011.679)
# Episode =  533, pose  36.464, vel -32.089, score = 900.163 (best = 1011.679)
# Episode =  534, pose 106.774, vel -16.087, score = 970.435 (best = 1011.679)
# Episode =  535, pose  77.985, vel -39.001, score = 956.891 (best = 1011.679)
# Episode =  536, pose  23.008, vel -113.644, score = 949.600 (best = 1011.679)
# Episode =  537, pose   9.567, vel -40.250, score = 882.464 (best = 1011.679)
# Episode =  538, pose  73.086, vel -114.138, score = 939.155 (best = 1011.679)
# Episode =  539, pose   7.459, vel -26.389, score = 838.186 (best = 1011.679)
# Episode =  540, pose 120.230, vel  14.243, score = 778.747 (best = 1011.679)
# Episode =  541, pose 110.380, vel -16.507, score = 1005.028 (best = 1011.679)
# Episode =  542, pose   0.000, vel -152.450, score = 841.124 (best = 1011.679)
# Episode =  543, pose   0.000, vel -40.567, score = 849.547 (best = 1011.679)
# Episode =  544, pose 133.094, vel  -0.729, score = 937.004 (best = 1011.679)
# Episode =  545, pose  53.526, vel -27.608, score = 924.119 (best = 1011.679)
# Episode =  546, pose 150.316, vel  24.711, score = 997.372 (best = 1011.679)
# Episode =  547, pose   0.000, vel -182.183, score = 755.279 (best = 1011.679)
# Episode =  548, pose   0.000, vel -29.898, score = 717.670 (best = 1011.679)
# Episode =  549, pose 100.591, vel -18.689, score = 979.244 (best = 1011.679)
# Episode =  550, pose  15.479, vel -31.992, score = 695.342 (best = 1011.679)
# Episode =  551, pose 122.191, vel  25.397, score = 684.244 (best = 1011.679)
# Episode =  552, pose  94.192, vel -17.966, score = 945.970 (best = 1011.679)
# Episode =  553, pose 233.348, vel 551.524, score = 765.877 (best = 1011.679)
# Episode =  554, pose  94.283, vel -18.782, score = 943.383 (best = 1011.679)
# Episode =  555, pose  13.943, vel -35.471, score = 884.772 (best = 1011.679)
# Episode =  556, pose  12.547, vel -37.007, score = 913.525 (best = 1011.679)
# Episode =  557, pose  33.430, vel -33.645, score = 927.684 (best = 1011.679)
# Episode =  558, pose   4.691, vel -38.989, score = 843.946 (best = 1011.679)
# Episode =  559, pose   9.424, vel -36.038, score = 869.245 (best = 1011.679)
# Episode =  560, pose 136.906, vel  -7.213, score = 1002.293 (best = 1011.679)
# Episode =  561, pose 153.797, vel   2.798, score = 985.975 (best = 1011.679)
# Episode =  562, pose  44.032, vel -166.232, score = 841.532 (best = 1011.679)
# Episode =  563, pose  58.617, vel -30.439, score = 954.097 (best = 1011.679)
# Episode =  564, pose 114.623, vel -18.635, score = 1004.116 (best = 1011.679)
# Episode =  565, pose 177.896, vel  20.379, score = 994.768 (best = 1011.679)
# Episode =  566, pose  74.750, vel -97.811, score = 878.622 (best = 1011.679)
# Episode =  567, pose  93.102, vel -21.646, score = 1002.234 (best = 1011.679)
# Episode =  568, pose  78.550, vel -26.586, score = 690.132 (best = 1011.679)
# Episode =  569, pose  43.474, vel -148.496, score = 763.857 (best = 1011.679)
# Episode =  570, pose  71.904, vel -108.433, score = 868.442 (best = 1011.679)
# Episode =  571, pose   0.000, vel -38.517, score = 891.767 (best = 1011.679)
# Episode =  572, pose   0.000, vel -27.581, score = 772.751 (best = 1011.679)
# Episode =  573, pose 180.969, vel  17.937, score = 992.946 (best = 1011.679)
# Episode =  574, pose 185.089, vel 386.445, score = 712.303 (best = 1011.679)
# Episode =  575, pose  80.890, vel -23.789, score = 987.840 (best = 1011.679)
# Episode =  576, pose  45.822, vel -30.576, score = 937.349 (best = 1011.679)
# Episode =  577, pose   0.000, vel -34.926, score = 728.753 (best = 1011.679)
# Episode =  578, pose   0.000, vel -185.433, score = 892.497 (best = 1011.679)
# Episode =  579, pose   0.000, vel -39.982, score = 800.024 (best = 1011.679)
# Episode =  580, pose 129.208, vel  -9.054, score = 992.719 (best = 1011.679)
# Episode =  581, pose 106.324, vel -27.461, score = 995.978 (best = 1011.679)
# Episode =  582, pose  78.583, vel -25.127, score = 990.435 (best = 1011.679)
# Episode =  583, pose  42.255, vel -24.736, score = 927.599 (best = 1011.679)
# Episode =  584, pose 107.554, vel -16.351, score = 982.604 (best = 1011.679)
# Episode =  585, pose 108.811, vel -15.843, score = 1006.957 (best = 1011.679)
# Episode =  586, pose   0.000, vel -31.662, score = 787.601 (best = 1011.679)
# Episode =  587, pose 132.934, vel -19.005, score = 972.876 (best = 1011.679)
# Episode =  588, pose  68.723, vel -25.914, score = 968.309 (best = 1011.679)
# Episode =  589, pose  66.106, vel -27.198, score = 960.010 (best = 1011.679)
# Episode =  590, pose 143.480, vel   8.755, score = 951.998 (best = 1011.679)
# Episode =  591, pose 114.456, vel 125.100, score = 645.051 (best = 1011.679)
# Episode =  592, pose   0.000, vel -39.276, score = 887.747 (best = 1011.679)
# Episode =  593, pose 181.803, vel  34.727, score = 996.311 (best = 1011.679)
# Episode =  594, pose   0.000, vel -35.449, score = 777.589 (best = 1011.679)
# Episode =  595, pose 135.508, vel  -5.908, score = 994.502 (best = 1011.679)
# Episode =  596, pose 117.945, vel -13.608, score = 990.103 (best = 1011.679)
# Episode =  597, pose 156.678, vel   6.494, score = 981.311 (best = 1011.679)
# Episode =  598, pose   0.000, vel -39.544, score = 835.078 (best = 1011.679)
# Episode =  599, pose   0.000, vel -22.339, score = 574.890 (best = 1011.679)
# Episode =  600, pose 122.764, vel -10.321, score = 973.773 (best = 1011.679)
# Episode =  601, pose   0.000, vel -369.226, score = 872.351 (best = 1011.679)
# Episode =  602, pose   0.000, vel -40.336, score = 821.862 (best = 1011.679)
# Episode =  603, pose   0.000, vel -85.059, score = 839.087 (best = 1011.679)
# Episode =  604, pose  32.756, vel -32.883, score = 927.347 (best = 1011.679)
# Episode =  605, pose 120.726, vel  -9.915, score = 841.996 (best = 1011.679)
# Episode =  606, pose 104.175, vel -17.295, score = 997.239 (best = 1011.679)
# Episode =  607, pose   0.000, vel -55.461, score = 751.233 (best = 1011.679)
# Episode =  608, pose 300.000, vel 598.793, score = 917.983 (best = 1011.679)
# Episode =  609, pose 167.633, vel  16.558, score = 1002.210 (best = 1011.679)
# Episode =  610, pose  87.737, vel -22.780, score = 986.800 (best = 1011.679)
# Episode =  611, pose  49.340, vel -30.900, score = 925.842 (best = 1011.679)
# Episode =  612, pose   0.000, vel -59.057, score = 780.827 (best = 1011.679)
# Episode =  613, pose   0.000, vel -43.788, score = 643.404 (best = 1011.679)
# Episode =  614, pose  41.804, vel -30.837, score = 936.747 (best = 1011.679)
# Episode =  615, pose 164.931, vel   9.930, score = 996.304 (best = 1011.679)
# Episode =  616, pose   0.000, vel -28.875, score = 802.758 (best = 1011.679)
# Episode =  617, pose   0.000, vel -31.231, score = 765.887 (best = 1011.679)
# Episode =  618, pose  21.865, vel -37.907, score = 937.825 (best = 1011.679)
# Episode =  619, pose 167.203, vel  15.385, score = 1001.700 (best = 1011.679)
# Episode =  620, pose 125.177, vel -10.924, score = 1000.683 (best = 1011.679)
# Episode =  621, pose 133.355, vel  -7.261, score = 971.891 (best = 1011.679)
# Episode =  622, pose   0.000, vel -209.231, score = 714.855 (best = 1011.679)
# Episode =  623, pose 134.544, vel  -8.955, score = 952.652 (best = 1011.679)
# Episode =  624, pose  36.837, vel -24.580, score = 911.332 (best = 1011.679)
# ...
# Episode =  794, pose 134.368, vel  -7.355, score = 990.972 (best = 1011.679)
# Episode =  795, pose   0.000, vel -24.392, score = 806.114 (best = 1011.679)
# Episode =  796, pose  47.061, vel -148.332, score = 823.119 (best = 1011.679)
# Episode =  797, pose  35.814, vel -33.425, score = 924.491 (best = 1011.679)
# Episode =  798, pose   0.000, vel -39.288, score = 877.802 (best = 1011.679)
# Episode =  799, pose  10.706, vel -38.042, score = 937.917 (best = 1011.679)
# Episode =  800, pose   0.000, vel -40.379, score = 786.897 (best = 1011.679)
# Episode =  801, pose   0.000, vel -214.268, score = 779.832 (best = 1011.679)
# Episode =  802, pose  35.373, vel -130.778, score = 952.884 (best = 1011.679)
# Episode =  803, pose   0.000, vel -33.941, score = 708.680 (best = 1011.679)
# Episode =  804, pose 111.324, vel -22.112, score = 848.533 (best = 1011.679)
# Episode =  805, pose   0.000, vel -84.445, score = 719.092 (best = 1011.679)
# Episode =  806, pose  61.392, vel -56.734, score = 942.879 (best = 1011.679)
# Episode =  807, pose  24.248, vel -37.879, score = 929.388 (best = 1011.679)
# Episode =  808, pose   7.008, vel   8.570, score = 879.479 (best = 1011.679)
# Episode =  809, pose 109.748, vel -17.790, score = 937.126 (best = 1011.679)
# Episode =  810, pose  97.004, vel -20.118, score = 1004.658 (best = 1011.679)
# Episode =  811, pose   0.000, vel -25.319, score = 717.099 (best = 1011.679)
# Episode =  812, pose 168.888, vel 213.582, score = 797.671 (best = 1011.679)
# Episode =  813, pose  31.386, vel -35.062, score = 942.351 (best = 1011.679)
# Episode =  814, pose  52.869, vel -22.297, score = 923.285 (best = 1011.679)
# Episode =  815, pose 168.638, vel  15.985, score = 1006.333 (best = 1011.679)
# Episode =  816, pose 149.811, vel  -0.105, score = 1003.581 (best = 1011.679)
# Episode =  817, pose   0.000, vel -34.816, score = 791.305 (best = 1011.679)
# Episode =  818, pose 148.477, vel  -0.284, score = 990.532 (best = 1011.679)
# Episode =  819, pose 103.216, vel -17.388, score = 995.553 (best = 1011.679)
# Episode =  820, pose 119.758, vel -16.683, score = 971.641 (best = 1011.679)
# Episode =  821, pose 119.259, vel  81.329, score = 663.296 (best = 1011.679)
# Episode =  822, pose  45.206, vel -117.470, score = 704.687 (best = 1011.679)
# Episode =  823, pose   0.000, vel -41.601, score = 748.105 (best = 1011.679)
# Episode =  824, pose 165.365, vel  16.013, score = 1005.686 (best = 1011.679)
# Episode =  825, pose   0.000, vel -37.809, score = 733.863 (best = 1011.679)
# Episode =  826, pose   0.000, vel -126.163, score = 863.860 (best = 1011.679)
# Episode =  827, pose   0.000, vel -40.849, score = 930.409 (best = 1011.679)
# Episode =  828, pose 173.342, vel  18.236, score = 985.973 (best = 1011.679)
# Episode =  829, pose  57.824, vel -74.248, score = 689.844 (best = 1011.679)
# Episode =  830, pose 132.484, vel  -9.721, score = 996.102 (best = 1011.679)
# Episode =  831, pose  19.168, vel -26.289, score = 844.640 (best = 1011.679)
# Episode =  832, pose  87.490, vel -22.205, score = 1005.601 (best = 1011.679)
# Episode =  833, pose  44.389, vel -33.716, score = 970.272 (best = 1011.679)
# Episode =  834, pose   6.671, vel -31.548, score = 859.755 (best = 1011.679)
# Episode =  835, pose 143.175, vel  -3.963, score = 996.189 (best = 1011.679)
# Episode =  836, pose   0.000, vel -122.351, score = 704.109 (best = 1011.679)
# Episode =  837, pose  35.186, vel -35.749, score = 922.225 (best = 1011.679)
# Episode =  838, pose   0.000, vel -34.279, score = 763.798 (best = 1011.679)
# Episode =  839, pose  47.811, vel -32.368, score = 996.310 (best = 1011.679)
# Episode =  840, pose 155.197, vel   5.413, score = 1002.884 (best = 1011.679)
# Episode =  841, pose  27.592, vel -33.638, score = 983.817 (best = 1011.679)
# Episode =  842, pose 228.965, vel 648.605, score = 821.807 (best = 1011.679)
# Episode =  843, pose   0.000, vel -43.137, score = 892.827 (best = 1011.679)
# Episode =  844, pose  74.581, vel -24.982, score = 952.994 (best = 1011.679)
# Episode =  845, pose 111.416, vel -18.054, score = 989.128 (best = 1011.679)
# Episode =  846, pose 175.455, vel  21.951, score = 994.215 (best = 1011.679)
# Episode =  847, pose   0.000, vel -36.705, score = 835.923 (best = 1011.679)
# Episode =  848, pose   8.639, vel -39.300, score = 947.941 (best = 1011.679)
# Episode =  849, pose  54.764, vel -30.105, score = 976.405 (best = 1011.679)
# Episode =  850, pose   0.000, vel -25.525, score = 792.753 (best = 1011.679)
# Episode =  851, pose 215.368, vel  91.241, score = 938.330 (best = 1011.679)
# Episode =  852, pose  76.306, vel -21.002, score = 978.767 (best = 1011.679)
# Episode =  853, pose   0.494, vel -171.954, score = 940.649 (best = 1011.679)
# Episode =  854, pose   0.000, vel -32.106, score = 776.002 (best = 1011.679)
# Episode =  855, pose  26.819, vel -33.808, score = 891.616 (best = 1011.679)
# Episode =  856, pose   0.000, vel -31.660, score = 766.050 (best = 1011.679)
# Episode =  857, pose  37.011, vel -32.393, score = 999.331 (best = 1011.679)
# Episode =  858, pose   0.000, vel -31.597, score = 811.788 (best = 1011.679)
# Episode =  859, pose   0.000, vel -30.151, score = 785.836 (best = 1011.679)
# Episode =  860, pose 147.481, vel  -2.611, score = 999.217 (best = 1011.679)
# Episode =  861, pose  34.726, vel -52.001, score = 936.670 (best = 1011.679)
# Episode =  862, pose   0.000, vel -157.310, score = 853.987 (best = 1011.679)
# Episode =  863, pose   0.000, vel -40.536, score = 905.467 (best = 1011.679)
# Episode =  864, pose   0.000, vel -198.889, score = 691.391 (best = 1011.679)
# Episode =  865, pose   0.000, vel -28.449, score = 691.299 (best = 1011.679)
# Episode =  866, pose   0.000, vel -31.012, score = 649.079 (best = 1011.679)
# Episode =  867, pose 167.533, vel  11.054, score = 959.789 (best = 1011.679)
# Episode =  868, pose  80.900, vel -59.749, score = 985.893 (best = 1011.679)
# Episode =  869, pose   0.000, vel -31.096, score = 642.313 (best = 1011.679)
# Episode =  870, pose   0.000, vel -32.191, score = 627.889 (best = 1011.679)
# Episode =  871, pose   0.000, vel -35.157, score = 740.927 (best = 1011.679)
# Episode =  872, pose   0.000, vel -28.992, score = 559.286 (best = 1011.679)
# Episode =  873, pose   0.000, vel -40.137, score = 870.001 (best = 1011.679)
# Episode =  874, pose   0.000, vel -42.724, score = 953.313 (best = 1011.679)
# Episode =  875, pose  96.018, vel -17.473, score = 987.171 (best = 1011.679)
# Episode =  876, pose   0.000, vel -23.975, score = 419.880 (best = 1011.679)
# Episode =  877, pose   0.000, vel -29.325, score = 584.033 (best = 1011.679)
# Episode =  878, pose   0.000, vel -27.610, score = 533.367 (best = 1011.679)
# Episode =  879, pose   0.000, vel -31.197, score = 643.162 (best = 1011.679)
# Episode =  880, pose 125.134, vel -11.793, score = 1013.852 (best = 1013.852)
# Episode =  881, pose  86.489, vel -25.284, score = 796.223 (best = 1013.852)
# Episode =  882, pose   0.000, vel -23.861, score = 406.472 (best = 1013.852)
# Episode =  883, pose   0.000, vel -23.244, score = 430.456 (best = 1013.852)
# Episode =  884, pose   0.000, vel -31.461, score = 677.867 (best = 1013.852)
# Episode =  885, pose   0.000, vel -19.348, score = 303.587 (best = 1013.852)
# Episode =  886, pose   0.000, vel -25.876, score = 495.362 (best = 1013.852)
# Episode =  887, pose   0.000, vel -39.195, score = 820.990 (best = 1013.852)
# Episode =  888, pose  12.224, vel -24.231, score = 857.639 (best = 1013.852)
# Episode =  889, pose   0.000, vel -54.630, score = 829.178 (best = 1013.852)
# Episode =  890, pose   5.299, vel -39.162, score = 917.458 (best = 1013.852)
# Episode =  891, pose   0.000, vel -25.748, score = 478.958 (best = 1013.852)
# Episode =  892, pose   0.000, vel -24.168, score = 433.925 (best = 1013.852)
# Episode =  893, pose 105.082, vel -42.360, score = 911.087 (best = 1013.852)
# Episode =  894, pose   0.000, vel -26.421, score = 761.914 (best = 1013.852)
# Episode =  895, pose   0.000, vel -28.224, score = 547.968 (best = 1013.852)
# Episode =  896, pose   0.000, vel -33.632, score = 722.014 (best = 1013.852)
# Episode =  897, pose  91.960, vel -20.484, score = 999.097 (best = 1013.852)
# Episode =  898, pose   0.000, vel -30.075, score = 625.028 (best = 1013.852)
# Episode =  899, pose   0.000, vel -38.262, score = 683.647 (best = 1013.852)
# Episode =  900, pose 136.588, vel  -3.430, score = 987.201 (best = 1013.852)
# Episode =  901, pose   0.000, vel -23.318, score = 421.755 (best = 1013.852)
# Episode =  902, pose   0.000, vel -36.214, score = 743.503 (best = 1013.852)
# Episode =  903, pose   0.000, vel -185.518, score = 860.274 (best = 1013.852)
# Episode =  904, pose   0.000, vel -34.686, score = 579.514 (best = 1013.852)
# Episode =  905, pose  97.048, vel -17.174, score = 990.527 (best = 1013.852)
# Episode =  906, pose   0.000, vel -33.276, score = 642.208 (best = 1013.852)
# Episode =  907, pose 131.097, vel -14.036, score = 856.292 (best = 1013.852)
# Episode =  908, pose   0.000, vel -27.140, score = 532.113 (best = 1013.852)
# Episode =  909, pose   0.000, vel -27.959, score = 530.606 (best = 1013.852)
# Episode =  910, pose   0.000, vel -28.111, score = 573.446 (best = 1013.852)
# Episode =  911, pose   0.000, vel -23.686, score = 443.925 (best = 1013.852)
# Episode =  912, pose   0.000, vel -25.903, score = 485.674 (best = 1013.852)
# Episode =  913, pose   0.000, vel -33.787, score = 714.772 (best = 1013.852)
# Episode =  914, pose   7.492, vel -37.260, score = 899.768 (best = 1013.852)
# Episode =  915, pose 123.522, vel -17.338, score = 961.251 (best = 1013.852)
# Episode =  916, pose   0.000, vel -39.428, score = 862.625 (best = 1013.852)
# Episode =  917, pose   0.000, vel -31.332, score = 775.037 (best = 1013.852)
# Episode =  918, pose  43.031, vel -33.738, score = 956.138 (best = 1013.852)
# Episode =  919, pose   0.000, vel -30.541, score = 577.356 (best = 1013.852)
# Episode =  920, pose  29.280, vel -36.581, score = 931.720 (best = 1013.852)
# Episode =  921, pose   0.000, vel -37.154, score = 754.206 (best = 1013.852)
# Episode =  922, pose 167.562, vel  14.639, score = 1005.945 (best = 1013.852)
# Episode =  923, pose   0.000, vel -138.508, score = 860.625 (best = 1013.852)
# Episode =  924, pose  84.627, vel -20.929, score = 996.099 (best = 1013.852)
# Episode =  925, pose 152.952, vel   3.824, score = 968.388 (best = 1013.852)
# Episode =  926, pose  60.857, vel -29.288, score = 956.739 (best = 1013.852)
# Episode =  927, pose   0.000, vel -37.911, score = 814.654 (best = 1013.852)
# Episode =  928, pose   0.000, vel -35.614, score = 725.895 (best = 1013.852)
# Episode =  929, pose 128.087, vel -12.384, score = 990.306 (best = 1013.852)
# Episode =  930, pose  57.318, vel -27.770, score = 944.187 (best = 1013.852)
# Episode =  931, pose 210.315, vel 429.643, score = 924.347 (best = 1013.852)
# Episode =  932, pose   0.000, vel -27.517, score = 807.568 (best = 1013.852)
# Episode =  933, pose   0.000, vel -105.110, score = 729.078 (best = 1013.852)
# Episode =  934, pose   0.000, vel -26.809, score = 833.876 (best = 1013.852)
# Episode =  935, pose   0.000, vel -30.808, score = 629.806 (best = 1013.852)
# Episode =  936, pose   6.549, vel -32.234, score = 910.818 (best = 1013.852)
# Episode =  937, pose  96.075, vel -20.349, score = 977.033 (best = 1013.852)
# Episode =  938, pose   0.000, vel -38.581, score = 825.523 (best = 1013.852)
# Episode =  939, pose  50.101, vel -29.705, score = 944.275 (best = 1013.852)
# Episode =  940, pose 142.880, vel  -4.403, score = 991.475 (best = 1013.852)
# Episode =  941, pose   0.000, vel -34.348, score = 663.018 (best = 1013.852)
# Episode =  942, pose 168.372, vel  17.257, score = 997.082 (best = 1013.852)
# Episode =  943, pose   0.000, vel -35.306, score = 696.610 (best = 1013.852)
# Episode =  944, pose  66.492, vel -26.517, score = 957.738 (best = 1013.852)
# Episode =  945, pose   0.000, vel -40.642, score = 851.670 (best = 1013.852)
# Episode =  946, pose  12.320, vel -35.661, score = 908.592 (best = 1013.852)
# Episode =  947, pose  81.412, vel -21.504, score = 959.157 (best = 1013.852)
# Episode =  948, pose  43.121, vel -31.139, score = 940.831 (best = 1013.852)
# Episode =  949, pose   0.000, vel -29.452, score = 681.014 (best = 1013.852)
# Episode =  950, pose   0.000, vel -366.508, score = 963.730 (best = 1013.852)
# Episode =  951, pose  12.141, vel -163.418, score = 648.137 (best = 1013.852)
# Episode =  952, pose  14.471, vel -42.674, score = 881.645 (best = 1013.852)
# Episode =  953, pose 300.000, vel 3420.669, score = 830.117 (best = 1013.852)
# Episode =  954, pose   0.000, vel -38.006, score = 837.928 (best = 1013.852)
# Episode =  955, pose   0.000, vel -32.502, score = 805.290 (best = 1013.852)
# Episode =  956, pose   0.000, vel -159.286, score = 752.502 (best = 1013.852)
# Episode =  957, pose   0.000, vel -33.980, score = 719.549 (best = 1013.852)
# Episode =  958, pose  57.049, vel -29.992, score = 944.737 (best = 1013.852)
# Episode =  959, pose 159.053, vel  12.413, score = 1003.046 (best = 1013.852)
# Episode =  960, pose  43.530, vel -32.771, score = 928.582 (best = 1013.852)
# Episode =  961, pose 166.759, vel  17.829, score = 966.977 (best = 1013.852)
# Episode =  962, pose  69.000, vel -26.674, score = 964.665 (best = 1013.852)
# Episode =  963, pose   0.000, vel -29.634, score = 550.124 (best = 1013.852)
# Episode =  964, pose   0.000, vel -32.272, score = 667.059 (best = 1013.852)
# Episode =  965, pose  51.943, vel -29.807, score = 938.167 (best = 1013.852)
# Episode =  966, pose   0.000, vel -29.128, score = 554.570 (best = 1013.852)
# Episode =  967, pose   0.000, vel -33.574, score = 722.968 (best = 1013.852)
# Episode =  968, pose   0.000, vel -23.469, score = 428.103 (best = 1013.852)
# Episode =  969, pose   0.000, vel -28.842, score = 533.623 (best = 1013.852)
# Episode =  970, pose   0.000, vel -24.707, score = 433.068 (best = 1013.852)
# Episode =  971, pose   3.186, vel -39.810, score = 828.256 (best = 1013.852)
# Episode =  972, pose   0.000, vel -35.934, score = 713.535 (best = 1013.852)
# Episode =  973, pose   5.864, vel -39.414, score = 869.838 (best = 1013.852)
# Episode =  974, pose   0.000, vel -17.822, score = 298.960 (best = 1013.852)
# Episode =  975, pose   0.000, vel -30.797, score = 623.860 (best = 1013.852)
# Episode =  976, pose   0.000, vel -22.414, score = 387.981 (best = 1013.852)
# Episode =  977, pose   0.000, vel -34.458, score = 744.639 (best = 1013.852)
# Episode =  978, pose   0.000, vel -40.365, score = 850.091 (best = 1013.852)
# Episode =  979, pose   0.000, vel -20.472, score = 323.958 (best = 1013.852)
# Episode =  980, pose   0.000, vel -31.646, score = 576.673 (best = 1013.852)
# Episode =  981, pose   4.531, vel -40.396, score = 896.137 (best = 1013.852)
# Episode =  982, pose  52.330, vel -25.177, score = 938.959 (best = 1013.852)
# Episode =  983, pose 149.252, vel   1.020, score = 970.052 (best = 1013.852)
# Episode =  984, pose  40.521, vel -31.327, score = 919.074 (best = 1013.852)
# Episode =  985, pose   0.000, vel -24.344, score = 667.668 (best = 1013.852)
# Episode =  986, pose  16.659, vel -35.605, score = 902.576 (best = 1013.852)
# Episode =  987, pose   0.000, vel -28.892, score = 513.234 (best = 1013.852)
# Episode =  988, pose  55.741, vel -119.304, score = 783.296 (best = 1013.852)
# Episode =  989, pose 104.631, vel -17.060, score = 978.116 (best = 1013.852)
# Episode =  990, pose  12.325, vel -36.405, score = 909.656 (best = 1013.852)
# Episode =  991, pose   0.000, vel -39.584, score = 873.970 (best = 1013.852)
# Episode =  992, pose 166.769, vel  15.350, score = 982.581 (best = 1013.852)
# Episode =  993, pose 253.841, vel 567.989, score = 891.845 (best = 1013.852)
# Episode =  994, pose   0.000, vel -37.096, score = 752.061 (best = 1013.852)
# Episode =  995, pose  10.945, vel -50.753, score = 920.531 (best = 1013.852)
# Episode =  996, pose  74.801, vel -19.969, score = 967.972 (best = 1013.852)
# Episode =  997, pose  43.236, vel -30.065, score = 908.319 (best = 1013.852)
# Episode =  998, pose  38.370, vel -190.153, score = 930.571 (best = 1013.852)
# Episode =  999, pose   0.000, vel -29.400, score = 525.543 (best = 1013.852)
# Episode = 1000, pose   0.000, vel -30.299, score = 593.288 (best = 1013.852)

# %%
## TODO: Plot the rewards.

plot_run(results)

path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=target_pos)

# %%
# plot best policy
best_w = agent.best_w
agent.actor_local.model.set_weights(best_w[0])
agent.critic_local.model.set_weights(best_w[1])

all_reward = 0
best_results = {x : [] for x in labels}

state = agent.reset_episode() # start a new episode
while True:
    # 状态->动作
    action = agent.act(state) 
    # 执行动作，得到下一时刻的状态和奖励
    next_state, reward, done = task.step(action)
    state = next_state
    all_reward += reward
    
    to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
    for ii in range(len(labels)):
        best_results[labels[ii]].append(to_write[ii])
    
    if done:
        print("pose {:7.3f}, vel {:7.3f}, score = {:7.3f}".format(
            task.sim.pose[2], task.sim.v[2], all_reward))  # [debug]    
        break
    sys.stdout.flush()
    
plot_run(best_results)
path = [[best_results['x'][i], best_results['y'][i], best_results['z'][i]] for i in range(len(best_results['x']))]
show_flight_path(path, target=target_pos)
# Out:
# pose  96.582, vel -32.093, score = 982.198

# %% [markdown]
# ## 绘制阶段奖励
#
# 请绘制智能体在每个阶段中获得的总奖励，这可以是单次运行的奖励值，也可以是多次运行的平均值。

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_rewards(rewards):

    plt.title('rewards')
    plt.xlabel('episode')
    plt.ylabel('rewards')
    
    t = np.arange(0, len(rewards))
    print(t.shape[0], len(rewards))
    
    plt.plot(t, np.array(rewards), label='reward/episode')
    
    plt.legend()
    _ = plt.ylim()

# %%
## TODO: Plot the rewards.
plot_rewards(reward_record)
# Out:
# 1000 1000

# %%
best_reward = np.max(reward_record)
last_reward = np.mean(reward_record[-10:])
average_reward = np.mean(reward_record)
print(">>> last ten average reward {last:.3f}/{best:.3f} all average {average:.3f}/{best:.3f}".format(last=last_reward, best=best_reward, average=average_reward ))
# Out:
# >>> last ten average reward 834.668/1013.852 all average 694.483/1013.852

# %% [markdown]
# ## 回顾
#
# **问题 1**：请描述你在 `task.py` 中指定的任务。你如何设计奖励函数？
#
# **回答**：
# 1. 开始的时候直接使用1-0.3*$\delta p$的奖励函数，奖励一直都很小，效果也不好 \
# 2. 尝试使用1-0.003*$\delta p$的奖励函数，奖励增大，训练效果逐渐偏好 \
# 3. 尝试将位置和速度都作为奖励考虑的因素，但是效果反而下降，这个地方不明白为什么 \
# 4. 根据建议，使用非线性映射，将最终的奖励经过tanh函数映射到[-1, 1]的范围，效果也还不错 \
# 5. 最终为了加大对距离误差的惩罚，将惩罚系数设置为0.01，得到如上效果 \
#
#
# **问题 2**：请简要描述你的智能体，你可以参考以下问题：
#
# - 你尝试了哪些学习算法？哪个效果最好？
# - 你最终选择了哪些超参数（比如 $\alpha$，$\gamma$，$\epsilon$ 等）？
# - 你使用了什么样的神经网络结构（如果有的话）？请说明层数、大小和激活函数等信息。
#
# **回答**：
# 1. 采用了推荐的DDPG方法，该方法是一个actor-critic的方法，其中加入了target-Q，memory-replay的方法
# 2. 基本采用DDPG论文中的参数，
# exploration_mu = 0
# exploration_theta = 0.15
# exploration_sigma = 0.2
# gamma = 0.99
# tau = 0.01  # 论文中是0.001，个人在实验的时候觉得应该得到好的参数之后应该稍微快一些把target更新为较好的，但是风险就是如果不好了，也会比较快的变得不好
# 学习率为： actor：0.0001，critic：0.001+weight_decay
#
# 3. 网络结构，基本借鉴DDPG的网络结构，仅仅使用了最后的2层全连接层，actor的结构使用为100->200的结构，初始化都是按照论文中的来
# Actor:
# Dense(units=100, L2 Regularisation) + BatchNorm + ReLu
# Dense(units=200, L2 Regularisation) + BatchNorm + ReLu
# Dense(units=self.action_dim) + Sigmoid
#
# Critic:
# input states:
# Dense(units=200, L2 Regularisation) + BatchNorm + ReLu
# Dense(units=200, L2 Regularisation)
# output states_net
#
# input action:
# Dense(units=200, L2 Regularisation) + BatchNorm + ReLu
# Dense(units=200, L2 Regularisation)
# output action_net
#
# Add(states_net, action_net) + ReLu
#
# 尽量不在state和action的网络的最后一层添加BN和ReLu操作，会让评论家的输出变得不好
#
#
# **问题 3**：根据你绘制的奖励图，描述智能体的学习状况。
#
# - 学习该任务是简单还是困难？
# - 该学习曲线中是否存在循序渐进或急速上升的部分？
# - 该智能体的最终性能有多好？（比如最后十个阶段的平均奖励值）
#
# **回答**：
# 1. 任务还是比较难的，要想让机器人稳定的悬停还是有难度的
# 2. 从学习曲线上看，整体的奖励是循序升高的，局部来看，确实存在一些地方是突然升高的
# 3. 最好的奖励为1000，最后的平均奖励在800左右，比平均的600要高
#
#
# **问题 4**：请简要总结你的本次项目经历。你可以参考以下问题：
#
# - 本次项目中最困难的部分是什么？（例如开始项目、运行 ROS、绘制、特定的任务等。）
# - 关于四轴飞行器和你的智能体的行为，你是否有一些有趣的发现？
#
# **回答**：
# 1. 最困难的是调整参数有时无法立即看到较好的效果，因为网络很有可能会在同样的参数时向着不同的方向优化，有时比较看运气
# 2. 有趣的发现：
#     a. agent还是比较容易陷入局部最优中的，比如训练500次，前面的有效果了，但是后面就很有可能陷入到不好的参数中
#     b. 较低的分数是无法起飞的，大多直接摔下去了

# %% [markdown]
# ### (可选)Plot Actor 及 Critic 结构
# 建议使用 ```from keras.utils import plot_model``` 来显示模型结构；

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
SVG(model_to_dot(agent.actor_local.model).create(prog='dot', format='svg'))

# %%
SVG(model_to_dot(agent.critic_local.model).create(prog='dot', format='svg'))
