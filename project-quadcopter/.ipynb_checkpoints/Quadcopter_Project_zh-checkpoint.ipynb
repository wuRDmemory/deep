# %% [markdown]
# # 项目：指导四轴飞行器学会飞行
#
# 设计一个能够使四轴飞行器飞行的智能体，然后使用你选择的强化学习算法训练它！
#
# 请尝试运用你在这一单元中学到的知识，看看哪个方法效果最好，当然你也可以自己想出创新型方法并测试它们。
# ## 说明
#
# 请查看目录下的文件，以更好地了解项目结构。
#
# - `task.py`：在本文件中定义你的任务（环境）。
# - `agents/`：本文件夹中包含强化学习智能体。
#     - `policy_search.py`：我们为你提供了一个智能体模板。
#     - `agent.py`：在本文件中开发你的智能体。
# - `physics_sim.py`：本文件中包含四轴飞行器模拟器。**请勿修改本文件**。
#
# 在本项目中，你需要在 `task.py` 中定义你的任务。尽管我们为你提供了一个任务示例，来帮助你开始项目，但你也可以随意更改这个文件。在这个 notebook 中，你还将学习更多有关修改这个文件的知识。
#
# 你还需要在 `agent.py` 中设计一个强化学习智能体，来完成你选择的任务。
#
# 我们也鼓励你创建其他文件，来帮助你整理代码。比如，你也许可以通过定义一个 `model.py` 文件来定义其他你需要的神经网络结构。
#
# ## 控制四轴飞行器
#
# 在下方的代码中，我们提供了一个智能体示例，来示范如何使用模拟器来控制四轴飞行器。这个智能体比你在 notebook 中需要测试的智能体（在 `agents/policy_search.py` 中）更加简单！
#
# 这个智能体通过设置飞行器四个轴上的转速来控制飞行器。`Basic_Agent` 类中提供的智能体将会随机为四个轴指定动作。这四个速度将通过 `act` 方法以四个浮点数列表的形式返回。
#
# 在本项目中，你将在 `agents/agent.py` 中实现的智能体会以更加智能的方法进行指定的动作。

# %% [markdown]
# ### plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_run(results, standalone=True):
    if standalone:
        plt.subplots(figsize=(15, 15))
    
    #查看四轴飞行器的位置变化
    plt.subplot(3, 3, 1)
    plt.title('Position')
    plt.plot(results['time'], results['x'], label='x')
    plt.plot(results['time'], results['y'], label='y')
    plt.plot(results['time'], results['z'], label='z')
    plt.xlabel('time, seconds')
    plt.ylabel('Position')
    plt.grid(True)
    if standalone:
        plt.legend()

    #四轴飞行器的速度
    plt.subplot(3, 3, 2)
    plt.title('Velocity')
    plt.plot(results['time'], results['x_velocity'], label='x_hat')
    plt.plot(results['time'], results['y_velocity'], label='y_hat')
    plt.plot(results['time'], results['z_velocity'], label='z_hat')
    plt.xlabel('time, seconds')
    plt.ylabel('Velocity')
    plt.grid(True)
    if standalone:
        plt.legend()
    
    #绘制欧拉角 (Euler angles)（四轴飞行器围绕 x，y 和 z 轴的旋转）的图表
    plt.subplot(3, 3, 3)
    plt.title('Orientation')
    plt.plot(results['time'], results['phi'], label='phi')
    plt.plot(results['time'], results['theta'], label='theta')
    plt.plot(results['time'], results['psi'], label='psi')
    plt.xlabel('time, seconds')
    plt.grid(True)
    if standalone:
        plt.legend()
    
    #绘制每个欧拉角的速度（每秒的弧度）图
    plt.subplot(3, 3, 4)
    plt.title('Angular Velocity')
    plt.plot(results['time'], results['phi_velocity'], label='phi')
    plt.plot(results['time'], results['theta_velocity'], label='theta')
    plt.plot(results['time'], results['psi_velocity'], label='psi')
    plt.xlabel('time, seconds')
    plt.grid(True)
    if standalone:
        plt.legend()

    #最后，你可以使用下方代码来输出智能体选择的动作。
    plt.subplot(3, 3, 5)
    plt.title('Rotor Speed')
    plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1')
    plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2')
    plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3')
    plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4')
    plt.xlabel('time, seconds')
    plt.ylabel('Rotor Speed, revolutions / second')
    plt.grid(True)
    if standalone:
        plt.legend()

    if standalone:
        plt.tight_layout()
        plt.show()

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D


def plot_point3d(ax, x, y, z, **kwargs):
    ax.scatter([x], [y], [z], **kwargs)
    ax.text(x, y, z, "({:.1f}, {:.1f}, {:.1f})".format(x, y, z))


def show_flight_path(results, target=None):
    results = np.array(results)
    
    fig = plt.figure(figsize=(10,10))
    ax = fig.gca(projection='3d')
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Z-axis')

    ax.plot3D(results[:, 0], results[:, 1], results[:, 2], 'gray')
    
    if target is not None:
        plot_point3d(ax, *target[0:3], c='y', marker='x', s=100, label='target')
        
    plot_point3d(ax, *results[0, 0:3], c='g', marker='o', s=50, label='start')
    plot_point3d(ax, *results[-1, 0:3], c='r', marker='o', s=50, label='end')
    
    ax.legend()

# %% [markdown]
# ### random Agent

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# 运行下方代码，让智能体指定动作来控制四轴飞行器。
#
# 请随意更改我们提供的 `runtime`，`init_pose`，`init_velocities` 和 `init_angle_velocities` 值来更改四轴飞行器的初始条件。
#
# 下方的 `labels` 列表为模拟数据的注释。所有的信息都储存在 `data.txt` 文档中，并保存在 `results` 目录下。

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %%
plot_run(results)

# %%
path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=None)

# %% [markdown]
# 在指定任务之前，你需要在模拟器中衍生环境状态。运行下方代码来在模拟结束时输出以下变量值：
#
# - `task.sim.pose`：四周飞行器在 ($x,y,z$) 坐标系中的位置和欧拉角。
# - `task.sim.v`：四轴飞行器在 ($x,y,z$) 坐标系中的速度。
# - `task.sim.angular_v`：三个欧拉角的弧度/每秒。

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [ 15.69412962 -13.94409268  26.01742182   5.93974592   5.67814565
#    0.        ]
# [10.01178598 -8.43932842  1.62005926]
# [-0.17617489 -0.20971055  0.        ]

# %% [markdown]
# 在 `task.py` 中的任务示例中，我们使用了四轴飞行器六个维度的动作来构建每个时间步的环境状态。然而，你也可以按照自己的意愿更改任务，你可以添加速度信息来扩大状态向量，也可以使用任何动作、速度和角速度的组合，并构造适用于你的任务的环境状态。
#
# ## 任务
#
# 在 `task.py` 中，我们为你提供了一个任务示例。请在新窗口中打开这个文件。
#
# 使用 `__init__()` 方法来初始化指定本任务所需的几个变量。
#
# - 模拟器作为 `PhysicsSim` 类（来自 `physics_sim.py` 文件）的示例进行初始化。
# - 受到 DDPG 论文中研究方法的启发，我们使用了重复调用动作的方法。对于智能体的每一个时间步，我们将利用 `action_repeats` 时间步来进行模拟。如果你并不熟悉这种方法，可以阅读 [DDPG 论文](https://arxiv.org/abs/1509.02971)的结论部分。
# - 我们设置了状态向量中每个分量的数值。在任务示例中，我们只设置了六个维度的动作信息。为了设定向量大小（`state_size`），我们必须考虑重复的动作。
# - 任务环境通常是一个四维动作空间，每个轴有一个输入（`action_size=4`）。你可以设置每个输入的最小值（`action_low`）和最大值（`action_high`）。
# - 我们在文件中提供的任务示例将使智能体达到目标位置。我们将目标位置设置为一个变量。
#
# `reset()` 方法将重置模拟器。每当阶段结束时，智能体都将调用此方法。你可以查看下方代码中的例子。
#
# `step()` 方法是最重要的一个方法。它将接收智能体选择的动作 `rotor_speeds`，并准备好下一个状态，同时返回给智能体。接着，你将通过 `get_reward()` 计算奖励值。当超过规定时间，或是四轴飞行器到达模拟器边缘时，这一阶段将视作结束。
#
# 接下来，你将学习如何测试这个任务中智能体的性能。
#
# ## 智能体
#
# `agents/policy_search.py` 文件中提供的智能体示例使用了非常简单的线性策略，将动作向量视作状态向量和矩阵权重的点积直接进行计算。接着，它通过添加一些高斯噪声来随机干扰参数，以产生不同的策略。根据每个阶段获得的平均奖励值（`score`），它将记录迄今为止发现的最佳参数集以及分数的变化状态，并据此调整比例因子来扩大或减少噪音。
#
# 请运行下方代码来查看任务示例中智能体的性能。

# %%
import sys
import pandas as p

# %%
from agents.policy_search import PolicySearch_Agent
from task import Task

labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

num_episodes = 1
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        # 状态->动作
        action = agent.act(state) 
        # 执行动作，得到下一时刻的状态和奖励
        next_state, reward, done = task.step(action)
        if i_episode == num_episodes:
            to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
            for ii in range(len(labels)):
                results[labels[ii]].append(to_write[ii])
        # 更新
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode =    1, score =  -1.396 (best =  -1.396), noise_scale = 0.05

# %%
plot_run(results)

path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=target_pos)

# %% [markdown]
# 这个智能体的性能想必十分糟糕！现在轮到你出场了！
#
# ## 定义任务，设计并训练你的智能体！
#
# 修改 `task.py` 文件来指定你所选择的任务。如果你不确定选择什么任务，你可以教你的四轴飞行器起飞、盘旋、着陆或是达到指定位置。
#
#
# 在指定任务后，使用 `agents/policy_search.py` 中的智能体示例作为模板，来在 `agents/agent.py` 中定义你自己的智能体。你可以随意从智能体示例中借用你需要的元素，包括如何模块化你的代码（使用 `act()`，`learn()` 和 `reset_episode_vars()` 等辅助方法）。
#
# 请注意，你指定的第一个智能体和任务**极有可能**无法顺利进行学习。你将需要改进不同的超参数和奖励函数，直到你能够获得不错的结果。
#
# 在开发智能体的时候，你还需要关注它的性能。参考下方代码，建立一个机制来存储每个阶段的总奖励值。如果阶段奖励值在逐渐上升，说明你的智能体正在学习。

# %%
import numpy as np
import random
from collections import namedtuple, deque
from physics_sim import PhysicsSim
from agents.agent import UserAgent
# Out:
# Using TensorFlow backend.

# %%
## TODO: Train your agent here.
from agents.policy_search import PolicySearch_Agent
from task import UserTask

labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

num_episodes = 500
target_pos = np.array([0., 0., 100.0])
init_pos = np.array([0., 0., 10., 0, 0, 0])
task = UserTask(init_pose=init_pos, runtime=5, target_pos=target_pos)
agent = UserAgent(task) 
reward_record = []

print(">>> start training")
for i_episode in range(1, num_episodes+1):
    # 这里面包含task和sim的reset
    state = agent.reset_episode() # start a new episode
    while True:
        # 状态->动作
        action = agent.act(state) 
        # 执行动作，得到下一时刻的状态和奖励
        next_state, reward, done = task.step(action)
        if i_episode == num_episodes:
            to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
            for ii in range(len(labels)):
                results[labels[ii]].append(to_write[ii])
        # 更新
        agent.step(action, reward, next_state, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, pose {:7.3f}, vel {:7.3f}, score = {:7.3f} (best = {:7.3f})".format(
                i_episode, task.sim.pose[2], task.sim.v[2], agent.score, agent.best_score))  # [debug]
            break
        sys.stdout.flush()
    if i_episode % 50 == 0:
        # 时不时的把权重变为最好的之后在该权重上进行优化
        agent.set_best()
    reward_record.append(agent.score)
# Out:
# >>> agent param
# >>> gamma 0.99 tau 0.01
# >>> theta 0.15 sigma 0.2
# >>> start training
# Episode =    1, pose   0.000, vel -15.620, score = 279.410 (best = 279.410)
# Episode =    2, pose   0.000, vel -15.659, score = 305.795 (best = 305.795)
# Episode =    3, pose   0.000, vel -16.215, score = 260.150 (best = 305.795)
# Episode =    4, pose   0.000, vel -15.731, score = 205.900 (best = 305.795)
# Episode =    5, pose   0.000, vel  -7.717, score = 250.401 (best = 305.795)
# Episode =    6, pose   0.000, vel -15.410, score = 347.134 (best = 347.134)
# Episode =    7, pose   0.000, vel -13.730, score = 176.534 (best = 347.134)
# Episode =    8, pose   0.000, vel -17.222, score = 455.666 (best = 455.666)
# Episode =    9, pose   0.000, vel -13.452, score = 237.427 (best = 455.666)
# Episode =   10, pose   0.000, vel -16.800, score = 196.359 (best = 455.666)
# Episode =   11, pose   0.000, vel -16.230, score = 167.218 (best = 455.666)
# Episode =   12, pose   0.000, vel -16.918, score = 158.099 (best = 455.666)
# Episode =   13, pose   0.000, vel -16.202, score = 125.454 (best = 455.666)
# Episode =   14, pose   0.000, vel -14.297, score = 163.845 (best = 455.666)
# Episode =   15, pose   0.000, vel -11.657, score = 240.970 (best = 455.666)
# Episode =   16, pose   0.000, vel -14.973, score = 131.828 (best = 455.666)
# Episode =   17, pose   0.000, vel -15.388, score = 135.334 (best = 455.666)
# Episode =   18, pose   0.000, vel  -7.352, score = 144.340 (best = 455.666)
# Episode =   19, pose   0.000, vel -14.650, score = 221.299 (best = 455.666)
# Episode =   20, pose   0.000, vel -24.184, score = 271.913 (best = 455.666)
# Episode =   21, pose   0.000, vel -19.602, score = 218.604 (best = 455.666)
# Episode =   22, pose   0.000, vel -16.045, score = 180.154 (best = 455.666)
# Episode =   23, pose   0.000, vel -13.107, score = 196.503 (best = 455.666)
# Episode =   24, pose   0.000, vel -17.270, score = 161.057 (best = 455.666)
# Episode =   25, pose   0.000, vel -17.040, score = 171.029 (best = 455.666)
# Episode =   26, pose   0.000, vel -17.689, score = 148.293 (best = 455.666)
# Episode =   27, pose   0.000, vel -16.208, score = 161.032 (best = 455.666)
# Episode =   28, pose   0.000, vel -15.174, score = 138.309 (best = 455.666)
# Episode =   29, pose   0.000, vel -16.120, score = 151.111 (best = 455.666)
# Episode =   30, pose   0.000, vel -14.459, score = 183.860 (best = 455.666)
# Episode =   31, pose   0.000, vel -14.976, score = 209.583 (best = 455.666)
# Episode =   32, pose   0.000, vel -15.203, score = 171.108 (best = 455.666)
# Episode =   33, pose   0.000, vel -15.517, score = 167.487 (best = 455.666)
# Episode =   34, pose   0.000, vel -14.861, score = 148.295 (best = 455.666)
# Episode =   35, pose   0.000, vel -14.923, score = 158.300 (best = 455.666)
# Episode =   36, pose   0.000, vel -15.042, score = 158.293 (best = 455.666)
# Episode =   37, pose   0.000, vel -16.158, score = 158.264 (best = 455.666)
# Episode =   38, pose   0.000, vel -14.310, score = 170.256 (best = 455.666)
# Episode =   39, pose   0.000, vel -13.680, score = 170.258 (best = 455.666)
# Episode =   40, pose   0.000, vel -16.129, score = 151.081 (best = 455.666)
# Episode =   41, pose   0.000, vel -16.629, score = 157.449 (best = 455.666)
# Episode =   42, pose   0.000, vel -17.421, score = 183.849 (best = 455.666)
# Episode =   43, pose   0.000, vel -15.716, score = 180.255 (best = 455.666)
# Episode =   44, pose   0.000, vel -15.964, score = 176.650 (best = 455.666)
# Episode =   45, pose   0.000, vel -14.370, score = 196.634 (best = 455.666)
# Episode =   46, pose   0.000, vel -13.835, score = 167.410 (best = 455.666)
# Episode =   47, pose   0.000, vel -13.937, score = 183.802 (best = 455.666)
# Episode =   48, pose   0.000, vel -13.880, score = 167.424 (best = 455.666)
# Episode =   49, pose   0.000, vel -13.242, score = 173.763 (best = 455.666)
# Episode =   50, pose   0.000, vel -15.149, score = 186.567 (best = 455.666)
# Episode =   51, pose   0.000, vel -14.852, score = 214.990 (best = 455.666)
# Episode =   52, pose   0.000, vel -19.155, score = 394.147 (best = 455.666)
# Episode =   53, pose   0.000, vel -16.516, score = 170.076 (best = 455.666)
# Episode =   54, pose   0.000, vel -11.751, score = 275.133 (best = 455.666)
# Episode =   55, pose   0.000, vel -21.456, score = 329.300 (best = 455.666)
# Episode =   56, pose   0.000, vel -16.437, score = 193.018 (best = 455.666)
# Episode =   57, pose   0.000, vel -10.677, score = 183.133 (best = 455.666)
# Episode =   58, pose   0.000, vel -11.022, score = 237.955 (best = 455.666)
# Episode =   59, pose   0.000, vel -13.283, score = 209.012 (best = 455.666)
# Episode =   60, pose   0.000, vel -12.527, score = 206.084 (best = 455.666)
# Episode =   61, pose   0.000, vel -12.747, score = 238.159 (best = 455.666)
# Episode =   62, pose   0.000, vel -12.120, score = 273.860 (best = 455.666)
# Episode =   63, pose   0.000, vel -11.619, score = 292.993 (best = 455.666)
# Episode =   64, pose   0.000, vel -14.575, score = 289.390 (best = 455.666)
# Episode =   65, pose   0.000, vel -13.314, score = 240.889 (best = 455.666)
# Episode =   66, pose   0.000, vel -16.585, score = 157.532 (best = 455.666)
# Episode =   67, pose   0.000, vel -18.620, score = 177.569 (best = 455.666)
# Episode =   68, pose   0.000, vel -16.534, score = 167.470 (best = 455.666)
# Episode =   69, pose   0.000, vel -18.747, score = 163.885 (best = 455.666)
# Episode =   70, pose   0.000, vel -15.860, score = 202.167 (best = 455.666)
# Episode =   71, pose   0.000, vel -10.198, score = 291.706 (best = 455.666)
# Episode =   72, pose   0.000, vel -15.656, score = 282.511 (best = 455.666)
# Episode =   73, pose   0.000, vel -21.035, score = 218.409 (best = 455.666)
# Episode =   74, pose   0.000, vel -16.863, score = 173.597 (best = 455.666)
# Episode =   75, pose   0.000, vel -17.446, score = 145.331 (best = 455.666)
# Episode =   76, pose   0.000, vel -13.530, score = 170.716 (best = 455.666)
# Episode =   77, pose   0.000, vel -13.427, score = 131.698 (best = 455.666)
# Episode =   78, pose   0.000, vel -13.524, score = 131.666 (best = 455.666)
# Episode =   79, pose   0.000, vel -14.403, score = 151.617 (best = 455.666)
# Episode =   80, pose   0.000, vel -14.431, score = 173.502 (best = 455.666)
# Episode =   81, pose   0.000, vel -15.858, score = 177.060 (best = 455.666)
# Episode =   82, pose   0.000, vel -16.984, score = 144.399 (best = 455.666)
# Episode =   83, pose   0.000, vel  -9.317, score = 150.793 (best = 455.666)
# Episode =   84, pose   0.000, vel -11.668, score = 145.320 (best = 455.666)
# Episode =   85, pose   0.000, vel -16.271, score = 167.385 (best = 455.666)
# Episode =   86, pose   0.000, vel -19.971, score = 192.976 (best = 455.666)
# Episode =   87, pose   0.000, vel -11.840, score = 151.129 (best = 455.666)
# Episode =   88, pose   0.000, vel -10.951, score = 173.824 (best = 455.666)
# Episode =   89, pose   0.000, vel  -9.963, score = 154.627 (best = 455.666)
# Episode =   90, pose   0.000, vel -16.479, score = 154.610 (best = 455.666)
# Episode =   91, pose   0.000, vel -13.335, score = 208.287 (best = 455.666)
# Episode =   92, pose   0.000, vel -19.888, score = 183.209 (best = 455.666)
# Episode =   93, pose   0.000, vel -19.217, score = 189.523 (best = 455.666)
# Episode =   94, pose   0.000, vel -10.362, score = 235.057 (best = 455.666)
# Episode =   95, pose   0.000, vel -19.000, score = 235.362 (best = 455.666)
# Episode =   96, pose   0.000, vel -12.573, score = 212.316 (best = 455.666)
# Episode =   97, pose   0.000, vel -11.042, score = 202.489 (best = 455.666)
# Episode =   98, pose   0.000, vel -12.704, score = 196.107 (best = 455.666)
# Episode =   99, pose   0.000, vel -10.199, score = 208.751 (best = 455.666)
# Episode =  100, pose   0.000, vel -15.332, score = 183.183 (best = 455.666)
# Episode =  101, pose   0.000, vel -11.813, score = 250.220 (best = 455.666)
# Episode =  102, pose   0.000, vel -13.926, score = 180.393 (best = 455.666)
# Episode =  103, pose   0.000, vel -16.274, score = 190.460 (best = 455.666)
# Episode =  104, pose   0.000, vel -15.032, score = 164.056 (best = 455.666)
# Episode =  105, pose   0.000, vel -15.792, score = 190.443 (best = 455.666)
# Episode =  106, pose   0.000, vel -14.935, score = 180.479 (best = 455.666)
# Episode =  107, pose   0.000, vel -13.591, score = 174.030 (best = 455.666)
# Episode =  108, pose   0.000, vel -15.381, score = 186.825 (best = 455.666)
# Episode =  109, pose   0.000, vel -14.059, score = 196.182 (best = 455.666)
# Episode =  110, pose   0.000, vel -11.181, score = 229.097 (best = 455.666)
# Episode =  111, pose   0.000, vel -13.451, score = 203.305 (best = 455.666)
# Episode =  112, pose   0.000, vel -13.787, score = 221.947 (best = 455.666)
# Episode =  113, pose   0.000, vel -13.311, score = 183.346 (best = 455.666)
# Episode =  114, pose   0.000, vel -14.480, score = 186.896 (best = 455.666)
# Episode =  115, pose   0.000, vel -16.728, score = 170.459 (best = 455.666)
# Episode =  116, pose   0.000, vel -15.488, score = 170.425 (best = 455.666)
# Episode =  117, pose   0.000, vel -16.331, score = 170.443 (best = 455.666)
# Episode =  118, pose   0.000, vel -16.803, score = 196.790 (best = 455.666)
# Episode =  119, pose   0.000, vel -16.601, score = 218.584 (best = 455.666)
# Episode =  120, pose   0.000, vel -11.478, score = 218.420 (best = 455.666)
# Episode =  121, pose   0.000, vel  -9.471, score = 183.570 (best = 455.666)
# Episode =  122, pose   0.000, vel -10.483, score = 208.201 (best = 455.666)
# Episode =  123, pose   0.000, vel -13.723, score = 401.328 (best = 455.666)
# Episode =  124, pose   0.000, vel -17.153, score = 154.405 (best = 455.666)
# Episode =  125, pose   0.000, vel -18.081, score = 346.281 (best = 455.666)
# Episode =  126, pose   0.000, vel  -9.370, score = 419.639 (best = 455.666)
# Episode =  127, pose   0.000, vel -18.219, score = 154.386 (best = 455.666)
# Episode =  128, pose   0.000, vel -15.541, score = 179.759 (best = 455.666)
# Episode =  129, pose   0.000, vel -19.169, score = 505.287 (best = 505.287)
# Episode =  130, pose   0.000, vel -19.254, score = 154.377 (best = 505.287)
# Episode =  131, pose   0.000, vel -18.383, score = 151.668 (best = 505.287)
# Episode =  132, pose   0.000, vel -14.986, score = 188.888 (best = 505.287)
# Episode =  133, pose  36.636, vel   0.929, score = 556.594 (best = 556.594)
# Episode =  134, pose   0.000, vel -22.066, score = 189.566 (best = 556.594)
# Episode =  135, pose   0.000, vel -16.027, score = 286.290 (best = 556.594)
# Episode =  136, pose   0.000, vel -19.734, score = 283.709 (best = 556.594)
# Episode =  137, pose   0.000, vel -14.948, score = 169.768 (best = 556.594)
# Episode =  138, pose   0.000, vel -26.027, score = 215.394 (best = 556.594)
# Episode =  139, pose   0.000, vel -19.601, score = 408.066 (best = 556.594)
# Episode =  140, pose   0.000, vel -18.544, score = 196.427 (best = 556.594)
# Episode =  141, pose  94.795, vel  25.068, score = 558.855 (best = 558.855)
# Episode =  142, pose   0.000, vel  -8.171, score = 362.033 (best = 558.855)
# Episode =  143, pose   0.000, vel -16.130, score = 183.215 (best = 558.855)
# Episode =  144, pose  18.797, vel -12.439, score = 561.071 (best = 561.071)
# Episode =  145, pose   0.000, vel -18.748, score = 163.444 (best = 561.071)
# Episode =  146, pose   0.000, vel -22.435, score = 158.052 (best = 561.071)
# Episode =  147, pose   0.000, vel -21.945, score = 141.673 (best = 561.071)
# Episode =  148, pose   0.000, vel -20.776, score = 167.262 (best = 561.071)
# Episode =  149, pose   0.000, vel -20.149, score = 148.059 (best = 561.071)
# Episode =  150, pose   0.000, vel -18.537, score = 138.067 (best = 561.071)
# Episode =  151, pose   0.000, vel -18.394, score = 189.765 (best = 561.071)
# Episode =  152, pose   0.000, vel  -9.770, score = 270.495 (best = 561.071)
# Episode =  153, pose   0.000, vel  -9.285, score = 218.179 (best = 561.071)
# Episode =  154, pose   0.000, vel -17.807, score = 151.658 (best = 561.071)
# Episode =  155, pose   0.000, vel -19.146, score = 125.209 (best = 561.071)
# Episode =  156, pose   0.000, vel -20.359, score = 125.247 (best = 561.071)
# Episode =  157, pose   0.000, vel -20.986, score = 125.275 (best = 561.071)
# Episode =  158, pose   0.000, vel -21.441, score = 135.241 (best = 561.071)
# Episode =  159, pose   0.000, vel -21.587, score = 135.286 (best = 561.071)
# Episode =  160, pose   0.000, vel -20.889, score = 125.261 (best = 561.071)
# Episode =  161, pose   0.000, vel -20.646, score = 125.239 (best = 561.071)
# Episode =  162, pose   0.000, vel -20.147, score = 125.255 (best = 561.071)
# Episode =  163, pose   0.000, vel -20.788, score = 135.294 (best = 561.071)
# Episode =  164, pose   0.000, vel -20.647, score = 125.287 (best = 561.071)
# Episode =  165, pose   0.000, vel -20.522, score = 125.291 (best = 561.071)
# Episode =  166, pose   0.000, vel -21.011, score = 135.312 (best = 561.071)
# Episode =  167, pose   0.000, vel -21.596, score = 145.333 (best = 561.071)
# Episode =  168, pose   0.000, vel -21.822, score = 145.331 (best = 561.071)
# Episode =  169, pose   0.000, vel -22.262, score = 145.321 (best = 561.071)
# Episode =  170, pose   0.000, vel -23.363, score = 118.941 (best = 561.071)
# Episode =  171, pose   0.000, vel -21.839, score = 145.334 (best = 561.071)
# Episode =  172, pose   0.000, vel -22.018, score = 135.310 (best = 561.071)
# Episode =  173, pose   0.000, vel -21.604, score = 125.284 (best = 561.071)
# Episode =  174, pose   0.000, vel -21.225, score = 125.286 (best = 561.071)
# Episode =  175, pose   0.000, vel -21.676, score = 125.285 (best = 561.071)
# Episode =  176, pose   0.000, vel -19.980, score = 151.614 (best = 561.071)
# Episode =  177, pose   0.000, vel -16.529, score = 147.934 (best = 561.071)
# Episode =  178, pose   0.000, vel -14.280, score = 154.260 (best = 561.071)
# Episode =  179, pose   0.000, vel -11.418, score = 150.584 (best = 561.071)
# Episode =  180, pose   0.000, vel  -7.442, score = 208.365 (best = 561.071)
# Episode =  181, pose  53.346, vel  19.472, score = 539.750 (best = 561.071)
# Episode =  182, pose  86.073, vel  20.302, score = 552.949 (best = 561.071)
# Episode =  183, pose  25.990, vel -18.395, score = 557.803 (best = 561.071)
# Episode =  184, pose   0.000, vel -21.786, score = 389.052 (best = 561.071)
# Episode =  185, pose   0.000, vel -33.726, score = 313.179 (best = 561.071)
# Episode =  186, pose   0.000, vel -25.551, score = 335.034 (best = 561.071)
# Episode =  187, pose   0.000, vel -17.278, score = 425.910 (best = 561.071)
# Episode =  188, pose   0.000, vel -19.182, score = 411.398 (best = 561.071)
# Episode =  189, pose   0.000, vel -27.444, score = 415.227 (best = 561.071)
# Episode =  190, pose   0.000, vel -29.714, score = 358.529 (best = 561.071)
# Episode =  191, pose   0.000, vel -28.619, score = 327.950 (best = 561.071)
# Episode =  192, pose   0.000, vel -30.851, score = 320.121 (best = 561.071)
# Episode =  193, pose   0.000, vel -21.369, score = 297.875 (best = 561.071)
# Episode =  194, pose   0.000, vel -19.997, score = 301.032 (best = 561.071)
# Episode =  195, pose   0.000, vel -19.162, score = 310.817 (best = 561.071)
# Episode =  196, pose   0.000, vel -19.076, score = 279.041 (best = 561.071)
# Episode =  197, pose   0.000, vel -20.578, score = 288.690 (best = 561.071)
# Episode =  198, pose   0.000, vel -18.507, score = 311.144 (best = 561.071)
# Episode =  199, pose   0.000, vel -17.353, score = 312.000 (best = 561.071)
# Episode =  200, pose   0.000, vel -11.505, score = 349.955 (best = 561.071)
# Episode =  201, pose   0.000, vel -18.359, score = 167.093 (best = 561.071)
# Episode =  202, pose   0.000, vel -25.808, score = 442.685 (best = 561.071)
# Episode =  203, pose   0.000, vel -44.010, score = 349.144 (best = 561.071)
# Episode =  204, pose   0.000, vel -53.182, score = 385.461 (best = 561.071)
# Episode =  205, pose   0.000, vel -35.440, score = 502.317 (best = 561.071)
# Episode =  206, pose   2.129, vel -19.203, score = 538.429 (best = 561.071)
# Episode =  207, pose  12.292, vel -14.162, score = 542.976 (best = 561.071)
# Episode =  208, pose  76.377, vel   2.673, score = 560.567 (best = 561.071)
# Episode =  209, pose 131.710, vel  32.231, score = 572.907 (best = 572.907)
# Episode =  210, pose  75.318, vel -22.859, score = 569.618 (best = 572.907)
# Episode =  211, pose 120.517, vel  12.217, score = 573.595 (best = 573.595)
# Episode =  212, pose 300.000, vel 14904.517, score = 565.651 (best = 573.595)
# Episode =  213, pose 136.997, vel  27.455, score = 578.672 (best = 578.672)
# Episode =  214, pose 141.692, vel  36.469, score = 578.389 (best = 578.672)
# Episode =  215, pose 143.644, vel  36.139, score = 577.728 (best = 578.672)
# Episode =  216, pose 148.405, vel  37.408, score = 575.431 (best = 578.672)
# Episode =  217, pose 126.826, vel  18.671, score = 574.888 (best = 578.672)
# Episode =  218, pose 138.009, vel  27.406, score = 578.992 (best = 578.992)
# Episode =  219, pose 125.655, vel  10.181, score = 573.955 (best = 578.992)
# Episode =  220, pose 138.263, vel  28.490, score = 579.520 (best = 579.520)
# Episode =  221, pose 141.895, vel  30.899, score = 576.494 (best = 579.520)
# Episode =  222, pose 130.845, vel  18.748, score = 576.055 (best = 579.520)
# Episode =  223, pose 135.543, vel  24.848, score = 577.058 (best = 579.520)
# Episode =  224, pose 138.898, vel  28.740, score = 578.953 (best = 579.520)
# Episode =  225, pose 112.043, vel  -1.621, score = 575.372 (best = 579.520)
# Episode =  226, pose 300.000, vel 2344.000, score = 533.531 (best = 579.520)
# Episode =  227, pose 132.394, vel  14.582, score = 579.286 (best = 579.520)
# Episode =  228, pose 136.999, vel  26.422, score = 576.432 (best = 579.520)
# Episode =  229, pose 133.311, vel  23.474, score = 576.767 (best = 579.520)
# Episode =  230, pose 300.000, vel 2120.458, score = 532.473 (best = 579.520)
# Episode =  231, pose 300.000, vel 25967.774, score = 472.662 (best = 579.520)
# Episode =  232, pose 300.000, vel 19112.436, score = 458.752 (best = 579.520)
# Episode =  233, pose 132.271, vel  20.697, score = 577.432 (best = 579.520)
# Episode =  234, pose 108.342, vel  -1.477, score = 575.316 (best = 579.520)
# Episode =  235, pose 133.935, vel  21.933, score = 578.041 (best = 579.520)
# Episode =  236, pose 126.278, vel  13.609, score = 574.943 (best = 579.520)
# Episode =  237, pose 108.890, vel  -4.056, score = 576.158 (best = 579.520)
# Episode =  238, pose 134.537, vel  24.629, score = 577.034 (best = 579.520)
# Episode =  239, pose 118.818, vel  10.437, score = 574.801 (best = 579.520)
# Episode =  240, pose  74.378, vel -15.139, score = 567.178 (best = 579.520)
# Episode =  241, pose  73.992, vel -10.951, score = 567.441 (best = 579.520)
# Episode =  242, pose 130.391, vel  27.877, score = 574.996 (best = 579.520)
# Episode =  243, pose 102.642, vel   4.375, score = 569.348 (best = 579.520)
# Episode =  244, pose  67.899, vel -22.508, score = 567.510 (best = 579.520)
# Episode =  245, pose 108.155, vel   8.673, score = 572.729 (best = 579.520)
# Episode =  246, pose 300.000, vel 11116.576, score = 550.799 (best = 579.520)
# Episode =  247, pose 193.336, vel 189.711, score = 571.910 (best = 579.520)
# Episode =  248, pose 136.466, vel  25.767, score = 578.487 (best = 579.520)
# Episode =  249, pose   0.000, vel -42.633, score = 383.992 (best = 579.520)
# Episode =  250, pose   6.109, vel -26.747, score = 552.109 (best = 579.520)
# Episode =  251, pose 139.459, vel  27.667, score = 579.244 (best = 579.520)
# Episode =  252, pose 173.152, vel 113.098, score = 576.293 (best = 579.520)
# Episode =  253, pose 132.229, vel  21.386, score = 576.237 (best = 579.520)
# Episode =  254, pose 300.000, vel 12447.804, score = 451.776 (best = 579.520)
# Episode =  255, pose 300.000, vel 4611.914, score = 544.935 (best = 579.520)
# Episode =  256, pose 154.298, vel  95.002, score = 567.766 (best = 579.520)
# Episode =  257, pose 130.049, vel  28.384, score = 570.374 (best = 579.520)
# Episode =  258, pose 218.022, vel 451.165, score = 528.421 (best = 579.520)
# Episode =  259, pose 102.602, vel 166.520, score = 343.105 (best = 579.520)
# Episode =  260, pose 127.938, vel 344.395, score = 334.519 (best = 579.520)
# Episode =  261, pose  75.027, vel  25.209, score = 306.737 (best = 579.520)
# Episode =  262, pose 146.582, vel 447.885, score = 366.348 (best = 579.520)
# Episode =  263, pose 163.199, vel 756.329, score = 347.748 (best = 579.520)
# Episode =  264, pose 250.736, vel 1807.122, score = 438.965 (best = 579.520)
# Episode =  265, pose 300.000, vel 95899.454, score = 497.122 (best = 579.520)
# Episode =  266, pose 133.004, vel  28.353, score = 573.751 (best = 579.520)
# Episode =  267, pose 149.820, vel  36.344, score = 573.640 (best = 579.520)
# Episode =  268, pose 300.000, vel 5908.976, score = 508.719 (best = 579.520)
# Episode =  269, pose   8.105, vel -31.332, score = 554.037 (best = 579.520)
# Episode =  270, pose   0.000, vel -29.387, score = 451.463 (best = 579.520)
# Episode =  271, pose 133.247, vel  22.967, score = 577.086 (best = 579.520)
# Episode =  272, pose  14.353, vel -30.017, score = 555.241 (best = 579.520)
# Episode =  273, pose   0.000, vel -35.484, score = 329.491 (best = 579.520)
# Episode =  274, pose   0.000, vel -36.769, score = 276.135 (best = 579.520)
# Episode =  275, pose  44.293, vel -32.695, score = 562.494 (best = 579.520)
# Episode =  276, pose   0.000, vel -27.701, score = 511.322 (best = 579.520)
# Episode =  277, pose   0.000, vel -25.760, score = 193.021 (best = 579.520)
# Episode =  278, pose   0.000, vel -29.388, score = 183.039 (best = 579.520)
# Episode =  279, pose   0.000, vel -25.352, score = 180.217 (best = 579.520)
# Episode =  280, pose   0.000, vel -20.132, score = 170.967 (best = 579.520)
# Episode =  281, pose   0.000, vel -24.216, score = 158.135 (best = 579.520)
# Episode =  282, pose   0.000, vel -19.872, score = 154.579 (best = 579.520)
# Episode =  283, pose   0.000, vel -20.243, score = 154.566 (best = 579.520)
# Episode =  284, pose   0.000, vel -38.865, score = 353.835 (best = 579.520)
# Episode =  285, pose   0.000, vel -24.769, score = 190.165 (best = 579.520)
# Episode =  286, pose   0.000, vel -29.855, score = 222.190 (best = 579.520)
# Episode =  287, pose   0.000, vel -31.262, score = 241.295 (best = 579.520)
# Episode =  288, pose   0.000, vel -34.516, score = 311.781 (best = 579.520)
# Episode =  289, pose   0.000, vel -21.405, score = 164.569 (best = 579.520)
# Episode =  290, pose   0.000, vel -19.708, score = 125.376 (best = 579.520)
# Episode =  291, pose   0.000, vel -32.192, score = 208.742 (best = 579.520)
# Episode =  292, pose   0.000, vel -15.450, score = 122.581 (best = 579.520)
# Episode =  293, pose   0.000, vel -11.953, score = 132.587 (best = 579.520)
# Episode =  294, pose   0.000, vel -13.347, score = 122.584 (best = 579.520)
# Episode =  295, pose   0.000, vel -11.213, score = 122.592 (best = 579.520)
# Episode =  296, pose   0.000, vel -12.271, score = 132.584 (best = 579.520)
# Episode =  297, pose   0.000, vel -25.305, score = 145.272 (best = 579.520)
# Episode =  298, pose   0.000, vel -12.260, score = 112.588 (best = 579.520)
# Episode =  299, pose   0.000, vel -29.103, score = 125.226 (best = 579.520)
# Episode =  300, pose   0.000, vel -13.732, score = 122.585 (best = 579.520)
# Episode =  301, pose 134.207, vel  24.073, score = 578.217 (best = 579.520)
# Episode =  302, pose 265.078, vel 2328.503, score = 455.280 (best = 579.520)
# Episode =  303, pose  88.767, vel 119.893, score = 325.043 (best = 579.520)
# Episode =  304, pose 140.856, vel  43.561, score = 564.815 (best = 579.520)
# Episode =  305, pose 130.052, vel  28.330, score = 571.413 (best = 579.520)
# Episode =  306, pose 154.582, vel  63.387, score = 574.055 (best = 579.520)
# Episode =  307, pose 300.000, vel 4042.115, score = 569.346 (best = 579.520)
# Episode =  308, pose 234.633, vel 1026.544, score = 483.766 (best = 579.520)
# Episode =  309, pose  41.557, vel -42.831, score = 311.540 (best = 579.520)
# Episode =  310, pose  19.916, vel -56.337, score = 544.398 (best = 579.520)
# Episode =  311, pose   0.000, vel -42.454, score = 412.472 (best = 579.520)
# Episode =  312, pose   0.000, vel -38.693, score = 300.599 (best = 579.520)
# Episode =  313, pose   0.000, vel -42.958, score = 326.664 (best = 579.520)
# Episode =  314, pose   0.000, vel -41.247, score = 322.065 (best = 579.520)
# Episode =  315, pose   0.000, vel -29.051, score = 419.771 (best = 579.520)
# Episode =  316, pose   0.000, vel -14.062, score = 249.187 (best = 579.520)
# Episode =  317, pose   0.000, vel -26.552, score = 404.554 (best = 579.520)
# Episode =  318, pose   0.000, vel -32.770, score = 395.066 (best = 579.520)
# Episode =  319, pose   0.000, vel -22.891, score = 252.441 (best = 579.520)
# Episode =  320, pose   0.000, vel -22.918, score = 213.687 (best = 579.520)
# Episode =  321, pose   0.000, vel -28.698, score = 229.815 (best = 579.520)
# Episode =  322, pose   0.000, vel -13.642, score = 219.589 (best = 579.520)
# Episode =  323, pose   0.000, vel -13.845, score = 157.758 (best = 579.520)
# Episode =  324, pose   0.000, vel -24.167, score = 226.089 (best = 579.520)
# Episode =  325, pose   0.000, vel -25.609, score = 336.134 (best = 579.520)
# Episode =  326, pose   0.000, vel -11.678, score = 244.950 (best = 579.520)
# Episode =  327, pose   0.000, vel  -8.529, score = 369.744 (best = 579.520)
# Episode =  328, pose   0.000, vel  -6.970, score = 182.987 (best = 579.520)
# Episode =  329, pose   0.000, vel -14.171, score = 204.837 (best = 579.520)
# Episode =  330, pose   0.000, vel -27.941, score = 324.770 (best = 579.520)
# Episode =  331, pose   0.000, vel  -5.656, score = 362.320 (best = 579.520)
# Episode =  332, pose   0.000, vel -19.103, score = 352.099 (best = 579.520)
# Episode =  333, pose   0.000, vel -10.384, score = 389.617 (best = 579.520)
# Episode =  334, pose   0.000, vel -19.836, score = 377.478 (best = 579.520)
# Episode =  335, pose   0.000, vel -14.430, score = 419.579 (best = 579.520)
# Episode =  336, pose   0.000, vel -24.240, score = 389.789 (best = 579.520)
# Episode =  337, pose   0.000, vel -18.420, score = 431.083 (best = 579.520)
# Episode =  338, pose   0.000, vel -23.250, score = 409.860 (best = 579.520)
# Episode =  339, pose   0.000, vel -23.611, score = 426.077 (best = 579.520)
# Episode =  340, pose   0.000, vel -14.033, score = 429.480 (best = 579.520)
# Episode =  341, pose   0.000, vel -29.499, score = 438.471 (best = 579.520)
# Episode =  342, pose   0.196, vel -10.882, score = 553.300 (best = 579.520)
# Episode =  343, pose   0.000, vel -24.839, score = 424.111 (best = 579.520)
# Episode =  344, pose   0.000, vel -29.690, score = 266.776 (best = 579.520)
# Episode =  345, pose   0.000, vel -34.282, score = 253.872 (best = 579.520)
# Episode =  346, pose   0.000, vel -31.706, score = 253.968 (best = 579.520)
# Episode =  347, pose   0.000, vel -14.405, score = 489.084 (best = 579.520)
# Episode =  348, pose   0.000, vel -33.073, score = 441.380 (best = 579.520)
# Episode =  349, pose   0.000, vel -26.522, score = 443.646 (best = 579.520)
# Episode =  350, pose   0.000, vel -21.997, score = 449.759 (best = 579.520)
# Episode =  351, pose 152.165, vel  56.220, score = 577.902 (best = 579.520)
# Episode =  352, pose 226.765, vel 1538.958, score = 398.368 (best = 579.520)
# Episode =  353, pose  36.284, vel -130.059, score = 295.529 (best = 579.520)
# Episode =  354, pose   0.717, vel -380.904, score = 288.327 (best = 579.520)
# Episode =  355, pose   0.000, vel -39.807, score = 275.820 (best = 579.520)
# Episode =  356, pose   0.000, vel -27.299, score = 440.054 (best = 579.520)
# Episode =  357, pose   0.000, vel -10.592, score = 445.116 (best = 579.520)
# Episode =  358, pose   0.000, vel -15.863, score = 448.683 (best = 579.520)
# Episode =  359, pose   0.000, vel  -7.532, score = 359.209 (best = 579.520)
# Episode =  360, pose   0.000, vel -13.560, score = 201.539 (best = 579.520)
# Episode =  361, pose   0.000, vel -16.384, score = 277.898 (best = 579.520)
# Episode =  362, pose   0.000, vel -14.741, score = 195.155 (best = 579.520)
# Episode =  363, pose   0.000, vel -13.686, score = 186.060 (best = 579.520)
# Episode =  364, pose   0.000, vel -12.946, score = 179.709 (best = 579.520)
# Episode =  365, pose   0.000, vel -15.362, score = 176.138 (best = 579.520)
# Episode =  366, pose   0.000, vel -15.925, score = 196.150 (best = 579.520)
# Episode =  367, pose   0.000, vel -14.757, score = 192.436 (best = 579.520)
# Episode =  368, pose   0.000, vel  -7.878, score = 154.112 (best = 579.520)
# Episode =  369, pose   0.000, vel -12.507, score = 112.457 (best = 579.520)
# Episode =  370, pose   0.000, vel -14.920, score = 106.104 (best = 579.520)
# Episode =  371, pose   0.000, vel -17.770, score =  99.753 (best = 579.520)
# Episode =  372, pose   0.000, vel -22.627, score =  93.415 (best = 579.520)
# Episode =  373, pose   0.000, vel -23.184, score =  93.419 (best = 579.520)
# Episode =  374, pose   0.000, vel -22.714, score =  93.417 (best = 579.520)
# Episode =  375, pose   0.000, vel -19.566, score = 109.762 (best = 579.520)
# Episode =  376, pose   0.000, vel -19.766, score = 109.764 (best = 579.520)
# Episode =  377, pose   0.000, vel -21.579, score =  93.410 (best = 579.520)
# Episode =  378, pose   0.000, vel -22.370, score =  93.419 (best = 579.520)
# Episode =  379, pose   0.000, vel -21.701, score =  93.413 (best = 579.520)
# Episode =  380, pose   0.000, vel -21.254, score = 119.770 (best = 579.520)
# Episode =  381, pose   0.000, vel -22.726, score = 119.776 (best = 579.520)
# Episode =  382, pose   0.000, vel -23.739, score =  93.420 (best = 579.520)
# Episode =  383, pose   0.000, vel -23.567, score = 103.417 (best = 579.520)
# Episode =  384, pose   0.000, vel -23.133, score = 103.412 (best = 579.520)
# Episode =  385, pose   0.000, vel -23.287, score =  93.394 (best = 579.520)
# Episode =  386, pose   0.000, vel -23.201, score =  93.393 (best = 579.520)
# Episode =  387, pose   0.000, vel -23.057, score =  93.400 (best = 579.520)
# Episode =  388, pose   0.000, vel -23.025, score =  93.400 (best = 579.520)
# Episode =  389, pose   0.000, vel -23.328, score =  93.400 (best = 579.520)
# Episode =  390, pose   0.000, vel -23.528, score = 103.409 (best = 579.520)
# Episode =  391, pose   0.000, vel -23.703, score = 103.411 (best = 579.520)
# Episode =  392, pose   0.000, vel -23.822, score = 103.416 (best = 579.520)
# Episode =  393, pose   0.000, vel -21.971, score =  93.403 (best = 579.520)
# Episode =  394, pose   0.000, vel -20.767, score = 119.757 (best = 579.520)
# Episode =  395, pose   0.000, vel -21.296, score =  93.397 (best = 579.520)
# Episode =  396, pose   0.000, vel -22.600, score =  93.402 (best = 579.520)
# Episode =  397, pose   0.000, vel -20.640, score = 119.757 (best = 579.520)
# Episode =  398, pose   0.000, vel -17.129, score =  99.743 (best = 579.520)
# Episode =  399, pose   0.000, vel -15.294, score = 132.449 (best = 579.520)
# Episode =  400, pose   0.000, vel -15.164, score = 106.101 (best = 579.520)
# Episode =  401, pose 138.046, vel  27.633, score = 579.396 (best = 579.520)
# Episode =  402, pose   0.000, vel  -5.475, score = 511.438 (best = 579.520)
# Episode =  403, pose   0.000, vel -19.956, score = 365.402 (best = 579.520)
# Episode =  404, pose   0.000, vel -16.577, score = 327.319 (best = 579.520)
# Episode =  405, pose   0.000, vel -11.831, score = 252.361 (best = 579.520)
# Episode =  406, pose   0.000, vel -25.874, score = 316.715 (best = 579.520)
# Episode =  407, pose   0.000, vel  -3.347, score = 281.160 (best = 579.520)
# Episode =  408, pose   0.000, vel -12.656, score = 368.979 (best = 579.520)
# Episode =  409, pose   0.000, vel -14.964, score = 427.877 (best = 579.520)
# Episode =  410, pose   0.000, vel -375.172, score = 446.868 (best = 579.520)
# Episode =  411, pose   0.000, vel -24.109, score = 352.797 (best = 579.520)
# Episode =  412, pose  53.037, vel  -0.395, score = 550.084 (best = 579.520)
# Episode =  413, pose   0.000, vel -21.658, score = 375.463 (best = 579.520)
# Episode =  414, pose   0.000, vel -20.918, score = 277.895 (best = 579.520)
# Episode =  415, pose   0.000, vel -12.498, score = 285.364 (best = 579.520)
# Episode =  416, pose   0.000, vel -12.067, score = 175.948 (best = 579.520)
# Episode =  417, pose   0.000, vel -15.154, score = 106.144 (best = 579.520)
# Episode =  418, pose   0.000, vel  -8.349, score = 154.210 (best = 579.520)
# Episode =  419, pose   0.000, vel -10.682, score = 211.470 (best = 579.520)
# Episode =  420, pose   0.000, vel -15.186, score = 234.269 (best = 579.520)
# Episode =  421, pose   0.000, vel -10.584, score = 198.714 (best = 579.520)
# Episode =  422, pose   0.000, vel -18.191, score = 243.545 (best = 579.520)
# Episode =  423, pose   0.000, vel -11.829, score = 205.182 (best = 579.520)
# Episode =  424, pose   0.000, vel  -9.989, score = 233.845 (best = 579.520)
# Episode =  425, pose   0.000, vel -11.195, score = 194.991 (best = 579.520)
# Episode =  426, pose   0.000, vel -13.150, score = 246.601 (best = 579.520)
# Episode =  427, pose   0.000, vel  -9.447, score = 176.866 (best = 579.520)
# Episode =  428, pose   0.000, vel  -8.948, score = 118.865 (best = 579.520)
# Episode =  429, pose   0.000, vel -11.834, score = 122.521 (best = 579.520)
# Episode =  430, pose   0.000, vel  -9.468, score = 135.211 (best = 579.520)
# Episode =  431, pose   0.000, vel  -7.968, score = 137.876 (best = 579.520)
# Episode =  432, pose   0.000, vel -10.783, score = 198.832 (best = 579.520)
# Episode =  433, pose   0.000, vel -19.648, score = 329.679 (best = 579.520)
# Episode =  434, pose   0.000, vel -13.316, score = 176.047 (best = 579.520)
# Episode =  435, pose   0.000, vel -12.524, score = 188.694 (best = 579.520)
# Episode =  436, pose   0.000, vel  -8.994, score = 217.723 (best = 579.520)
# Episode =  437, pose   0.000, vel -14.057, score = 226.810 (best = 579.520)
# Episode =  438, pose   0.000, vel  -9.287, score = 176.923 (best = 579.520)
# Episode =  439, pose   0.000, vel  -9.997, score = 166.952 (best = 579.520)
# Episode =  440, pose   0.000, vel -10.311, score = 156.958 (best = 579.520)
# Episode =  441, pose   0.000, vel -14.743, score = 177.029 (best = 579.520)
# Episode =  442, pose   0.000, vel -10.917, score = 150.655 (best = 579.520)
# Episode =  443, pose   0.000, vel -10.085, score = 201.369 (best = 579.520)
# Episode =  444, pose   0.000, vel -14.795, score = 271.163 (best = 579.520)
# Episode =  445, pose   0.000, vel -15.661, score = 255.705 (best = 579.520)
# Episode =  446, pose   0.000, vel -10.917, score = 236.622 (best = 579.520)
# Episode =  447, pose   0.000, vel -17.331, score = 247.152 (best = 579.520)
# Episode =  448, pose   0.000, vel -16.094, score = 414.792 (best = 579.520)
# Episode =  449, pose   0.000, vel -18.030, score = 411.184 (best = 579.520)
# Episode =  450, pose   0.000, vel -17.708, score = 338.506 (best = 579.520)
# Episode =  451, pose 136.337, vel  26.804, score = 578.050 (best = 579.520)
# Episode =  452, pose  96.428, vel  71.899, score = 345.746 (best = 579.520)
# Episode =  453, pose   0.000, vel -13.397, score = 375.509 (best = 579.520)
# Episode =  454, pose   0.000, vel -10.241, score = 428.030 (best = 579.520)
# Episode =  455, pose   0.000, vel -24.329, score = 445.739 (best = 579.520)
# Episode =  456, pose   0.000, vel -15.590, score = 125.207 (best = 579.520)
# Episode =  457, pose   0.000, vel -20.156, score = 106.142 (best = 579.520)
# Episode =  458, pose   0.000, vel -20.283, score = 106.147 (best = 579.520)
# Episode =  459, pose   0.000, vel -13.414, score = 141.503 (best = 579.520)
# Episode =  460, pose   0.000, vel  -4.713, score = 169.523 (best = 579.520)
# Episode =  461, pose   0.000, vel -10.663, score = 175.930 (best = 579.520)
# Episode =  462, pose   0.000, vel -18.160, score = 128.827 (best = 579.520)
# Episode =  463, pose   0.000, vel -20.071, score = 106.136 (best = 579.520)
# Episode =  464, pose   0.000, vel -19.113, score = 138.824 (best = 579.520)
# Episode =  465, pose   0.000, vel -19.256, score = 138.819 (best = 579.520)
# Episode =  466, pose   0.000, vel  -5.496, score = 163.022 (best = 579.520)
# Episode =  467, pose   0.000, vel -20.937, score = 116.121 (best = 579.520)
# Episode =  468, pose   0.000, vel -21.645, score =  99.773 (best = 579.520)
# Episode =  469, pose   0.000, vel -24.888, score = 109.795 (best = 579.520)
# Episode =  470, pose   0.000, vel -23.176, score = 119.822 (best = 579.520)
# Episode =  471, pose   0.000, vel -24.675, score = 109.807 (best = 579.520)
# Episode =  472, pose   0.000, vel -24.779, score = 116.163 (best = 579.520)
# Episode =  473, pose   0.000, vel -20.600, score = 145.301 (best = 579.520)
# Episode =  474, pose   0.000, vel  -9.334, score = 239.184 (best = 579.520)
# Episode =  475, pose   0.000, vel -18.563, score = 184.012 (best = 579.520)
# Episode =  476, pose   0.000, vel -28.357, score = 445.375 (best = 579.520)
# Episode =  477, pose   0.000, vel -24.801, score = 118.997 (best = 579.520)
# Episode =  478, pose   0.000, vel  -7.014, score = 177.310 (best = 579.520)
# Episode =  479, pose   0.000, vel -16.422, score = 118.988 (best = 579.520)
# Episode =  480, pose   0.000, vel -21.146, score = 138.975 (best = 579.520)
# Episode =  481, pose   0.000, vel -24.343, score = 139.002 (best = 579.520)
# Episode =  482, pose   0.000, vel  -9.205, score = 148.095 (best = 579.520)
# Episode =  483, pose   0.000, vel -20.976, score = 300.768 (best = 579.520)
# Episode =  484, pose   0.000, vel -18.029, score = 119.015 (best = 579.520)
# Episode =  485, pose   0.000, vel -20.363, score = 135.484 (best = 579.520)
# Episode =  486, pose   0.000, vel -21.312, score = 145.473 (best = 579.520)
# Episode =  487, pose   0.000, vel -22.538, score = 138.994 (best = 579.520)
# Episode =  488, pose   0.000, vel -14.379, score = 131.817 (best = 579.520)
# Episode =  489, pose   0.000, vel -13.507, score = 135.384 (best = 579.520)
# Episode =  490, pose   0.000, vel -13.232, score = 131.824 (best = 579.520)
# Episode =  491, pose   0.000, vel -19.199, score = 139.012 (best = 579.520)
# Episode =  492, pose   0.000, vel -12.126, score = 151.758 (best = 579.520)
# Episode =  493, pose   0.000, vel -14.139, score = 135.423 (best = 579.520)
# Episode =  494, pose   0.000, vel -18.204, score = 151.800 (best = 579.520)
# Episode =  495, pose   0.000, vel -18.311, score = 145.427 (best = 579.520)
# Episode =  496, pose   0.000, vel -19.743, score = 158.209 (best = 579.520)
# Episode =  497, pose   0.000, vel -13.322, score = 167.343 (best = 579.520)
# Episode =  498, pose   0.000, vel  -7.387, score = 202.878 (best = 579.520)
# Episode =  499, pose   0.000, vel -13.715, score = 163.779 (best = 579.520)
# Episode =  500, pose   0.000, vel -14.047, score = 163.774 (best = 579.520)

# %%
## TODO: Plot the rewards.

plot_run(results)

path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=target_pos)

# %%
# plot best policy
best_w = agent.best_w
agent.actor_local.model.set_weights(best_w[0])
agent.critic_local.model.set_weights(best_w[1])

all_reward = 0
best_results = {x : [] for x in labels}

state = agent.reset_episode() # start a new episode
while True:
    # 状态->动作
    action = agent.act(state) 
    # 执行动作，得到下一时刻的状态和奖励
    next_state, reward, done = task.step(action)
    state = next_state
    all_reward += reward
    
    to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
    for ii in range(len(labels)):
        best_results[labels[ii]].append(to_write[ii])
    
    if done:
        print("pose {:7.3f}, vel {:7.3f}, score = {:7.3f}".format(
            task.sim.pose[2], task.sim.v[2], all_reward))  # [debug]    
        break
    sys.stdout.flush()
    
plot_run(best_results)
path = [[best_results['x'][i], best_results['y'][i], best_results['z'][i]] for i in range(len(best_results['x']))]
show_flight_path(path, target=target_pos)
# Out:
# pose 150.065, vel  48.720, score = 577.118

# %% [markdown]
# ## 绘制阶段奖励
#
# 请绘制智能体在每个阶段中获得的总奖励，这可以是单次运行的奖励值，也可以是多次运行的平均值。

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_rewards(rewards):

    plt.title('rewards')
    plt.xlabel('episode')
    plt.ylabel('rewards')
    
    t = np.arange(0, len(rewards))
    
    print(t.shape[0], len(rewards))
    
    plt.plot(t, np.array(rewards), label='reward/episode')
    
    plt.legend()
    _ = plt.ylim()

# %%
## TODO: Plot the rewards.
plot_rewards(reward_record)
# Out:
# 500 500

# %% [markdown]
# ## 回顾
#
# **问题 1**：请描述你在 `task.py` 中指定的任务。你如何设计奖励函数？
#
# **回答**：
#
#
# **问题 2**：请简要描述你的智能体，你可以参考以下问题：
#
# - 你尝试了哪些学习算法？哪个效果最好？
# - 你最终选择了哪些超参数（比如 $\alpha$，$\gamma$，$\epsilon$ 等）？
# - 你使用了什么样的神经网络结构（如果有的话）？请说明层数、大小和激活函数等信息。
#
# **回答**：
#
#
#
# **问题 3**：根据你绘制的奖励图，描述智能体的学习状况。
#
# - 学习该任务是简单还是困难？
# - 该学习曲线中是否存在循序渐进或急速上升的部分？
# - 该智能体的最终性能有多好？（比如最后十个阶段的平均奖励值）
#
# **回答**：
#
#
#
# **问题 4**：请简要总结你的本次项目经历。你可以参考以下问题：
#
# - 本次项目中最困难的部分是什么？（例如开始项目、运行 ROS、绘制、特定的任务等。）
# - 关于四轴飞行器和你的智能体的行为，你是否有一些有趣的发现？
#
# **回答**：

# %% [markdown]
# ### (可选)Plot Actor 及 Critic 结构
# 建议使用 ```from keras.utils import plot_model``` 来显示模型结构；
